# %% [markdown]
# # Authorship Analysis
#
# The _Federalist Papers_ were originally published under the pseudonym "Publius". Although the identity of the authors was a closely guarded secret at the time, most of the papers have since been conclusively attributed to one of Hamilton, Jay, or Madison. The known authorships can be found in `/data/federalist/authorship.csv`.
#
# For 15 papers, however, the authorships remain disputed. (These papers can be identified from the `authorship.csv` file because the "Author" field is blank.) In this analysis, you will use textual data analysis to assign authorships to these disputed papers.

# %%
import pandas as pd
import numpy as np
from random import randint

# %%
scores = []

# %% [markdown]
# ## Question 1
#
# In Information Retrieval, we use TF-IDF (instead of raw term frequencies) to give rare words more weight. If you're looking for "red stockings", then a document with the rare word "stockings" is much more likely to be relevant than a document with the common word "red".
#
# However, for analyzing an author's style, common words like "the" and "on" are actually much more useful than rare words like "hostilities". Rare words depend on context, and different authors writing about the same context will use the same words. For example, both Dr. Seuss and Charles Dickens used the rare words "chimney" and "stockings" in _How the Grinch Stole Christmas_ and _A Christmas Carol_, respectively. But they used common words very differently: Dickens uses the word "upon" over 100 times, while Dr. Seuss does not use "upon" at all.
#
# First, determine the most common 50 words in the _Federalist Papers_ corpus. You should use the `word_counts.csv` that you generated in the Zipf's Law part of this lab. Then, create a data frame of term frequencies for those 50 words in each of the 85 _Federalist Papers_. Your data frame should have 85 rows and 50 columns. The index of the data frame should be the number of the paper (1-85).

# %%
word_counts = pd.read_csv("word_counts.csv", header=None, names=["Word", "Count"])
word_counts = word_counts.sort_values(by="Count", ascending = False).reset_index().reset_index()

# %%
words50 = word_counts.head(50)["Word"].tolist()
words50
# Out:
# ['the',
#  'of',
#  'to',
#  'and',
#  'in',
#  'a',
#  'be',
#  'that',
#  'it',
#  'is',
#  'which',
#  'by',
#  'as',
#  'this',
#  'would',
#  'have',
#  'will',
#  'for',
#  'or',
#  'not',
#  'their',
#  'with',
#  'from',
#  'are',
#  'on',
#  'they',
#  'an',
#  'states',
#  'government',
#  'may',
#  'been',
#  'state',
#  'all',
#  'but',
#  'its',
#  'other',
#  'power',
#  'people',
#  'has',
#  'more',
#  'at',
#  'if',
#  'them',
#  'than',
#  'one',
#  'any',
#  'no',
#  'those',
#  'we',
#  'can']

# %%
allPgs = []
for page in range(1,86):
    vocab = {}
    with open("/data/federalist/%d.txt"%page) as f:
        text = f.read()
        words = text.split()
        fixed = []
        for word in words:
            fixed.append(word.lower().rstrip(';.?!,:)"').lstrip('"(').replace('-','').replace('"',''))
        for word in fixed:
            if (word not in vocab) and (word in words50):
                vocab[word] = 1
            elif (word in vocab) and (word in words50):
                vocab[word] += 1
    allPgs.append(vocab)
    
allPgs
# Out:
# [{'a': 25,
#   'all': 9,
#   'an': 11,
#   'and': 40,
#   'any': 6,
#   'are': 12,
#   'as': 10,
#   'at': 8,
#   'be': 34,
#   'been': 3,
#   'but': 2,
#   'by': 14,
#   'can': 3,
#   'for': 12,
#   'from': 11,
#   'government': 9,
#   'has': 6,
#   'have': 10,
#   'if': 4,
#   'in': 27,
#   'is': 13,
#   'it': 20,
#   'its': 10,
#   'may': 11,
#   'more': 7,
#   'no': 3,
#   'not': 14,
#   'of': 106,
#   'on': 9,
#   'one': 4,
#   'or': 6,
#   'other': 3,
#   'people': 6,
#   'power': 2,
#   'state': 6,
#   'states': 2,
#   'than': 11,
#   'that': 28,
#   'the': 132,
#   'their': 14,
#   'them': 2,
#   'they': 6,
#   'this': 14,
#   'those': 9,
#   'to': 72,
#   'we': 8,
#   'which': 18,
#   'will': 25,
#   'with': 6,
#   'would': 2},
#  {'a': 29,
#   'all': 4,
#   'an': 1,
#   'and': 83,
#   'any': 1,
#   'are': 6,
#   'as': 16,
#   'at': 10,
#   'be': 15,
#   'been': 8,
#   'but': 8,
#   'by': 10,
#   'for': 13,
#   'from': 4,
#   'government': 9,
#   'has': 6,
#   'have': 17,
#   'if': 3,
#   'in': 34,
#   'is': 16,
#   'it': 38,
#   'its': 5,
#   'may': 4,
#   'more': 5,
#   'no': 1,
#   'not': 10,
#   'of': 83,
#   'on': 8,
#   'one': 10,
#   'or': 10,
#   'other': 4,
#   'people': 22,
#   'power': 1,
#   'state': 1,
#   'states': 2,
#   'than': 5,
#   'that': 44,
#   'the': 107,
#   'their': 21,
#   'them': 4,
#   'they': 22,
#   'this': 14,
#   'those': 2,
#   'to': 53,
#   'we': 5,
#   'which': 11,
#   'will': 2,
#   'with': 13,
#   'would': 5},
#  {'a': 13,
#   'all': 4,
#   'an': 3,
#   'and': 60,
#   'any': 5,
#   'are': 8,
#   'as': 24,
#   'at': 1,
#   'be': 31,
#   'been': 2,
#   'but': 7,
#   'by': 18,
#   'can': 3,
#   'for': 11,
#   'from': 15,
#   'government': 15,
#   'has': 5,
#   'have': 7,
#   'if': 7,
#   'in': 25,
#   'is': 7,
#   'it': 21,
#   'its': 1,
#   'may': 6,
#   'more': 13,
#   'no': 2,
#   'not': 13,
#   'of': 62,
#   'on': 6,
#   'one': 8,
#   'or': 32,
#   'other': 7,
#   'people': 8,
#   'power': 3,
#   'state': 8,
#   'states': 11,
#   'than': 8,
#   'that': 20,
#   'the': 93,
#   'their': 11,
#   'them': 8,
#   'they': 5,
#   'this': 6,
#   'those': 6,
#   'to': 56,
#   'which': 11,
#   'will': 24,
#   'with': 10,
#   'would': 2},
#  {'a': 16,
#   'all': 4,
#   'an': 3,
#   'and': 90,
#   'any': 5,
#   'are': 11,
#   'as': 20,
#   'at': 2,
#   'be': 26,
#   'been': 2,
#   'but': 10,
#   'by': 14,
#   'can': 8,
#   'for': 12,
#   'from': 8,
#   'government': 16,
#   'has': 1,
#   'have': 9,
#   'if': 13,
#   'in': 24,
#   'is': 10,
#   'it': 28,
#   'its': 9,
#   'may': 10,
#   'more': 13,
#   'no': 1,
#   'not': 14,
#   'of': 72,
#   'on': 11,
#   'one': 13,
#   'or': 24,
#   'other': 11,
#   'people': 8,
#   'power': 2,
#   'state': 6,
#   'states': 1,
#   'than': 9,
#   'that': 17,
#   'the': 86,
#   'their': 19,
#   'them': 12,
#   'they': 17,
#   'this': 1,
#   'those': 4,
#   'to': 51,
#   'we': 10,
#   'which': 10,
#   'will': 15,
#   'with': 12,
#   'would': 17},
#  {'a': 9,
#   'all': 4,
#   'an': 4,
#   'and': 72,
#   'any': 3,
#   'are': 3,
#   'as': 3,
#   'at': 4,
#   'be': 31,
#   'but': 4,
#   'by': 10,
#   'can': 1,
#   'for': 7,
#   'from': 11,
#   'government': 2,
#   'have': 1,
#   'if': 3,
#   'in': 28,
#   'is': 7,
#   'it': 21,
#   'its': 4,
#   'may': 2,
#   'more': 11,
#   'no': 2,
#   'not': 8,
#   'of': 53,
#   'on': 5,
#   'one': 10,
#   'or': 10,
#   'other': 4,
#   'people': 3,
#   'power': 1,
#   'state': 2,
#   'states': 1,
#   'than': 9,
#   'that': 23,
#   'the': 66,
#   'their': 11,
#   'them': 11,
#   'they': 11,
#   'this': 6,
#   'those': 9,
#   'to': 45,
#   'we': 5,
#   'which': 10,
#   'will': 6,
#   'with': 11,
#   'would': 37},
#  {'a': 52,
#   'all': 6,
#   'an': 12,
#   'and': 81,
#   'are': 18,
#   'as': 19,
#   'at': 6,
#   'be': 18,
#   'been': 13,
#   'but': 5,
#   'by': 12,
#   'can': 2,
#   'for': 13,
#   'from': 16,
#   'government': 2,
#   'has': 10,
#   'have': 27,
#   'if': 5,
#   'in': 60,
#   'is': 8,
#   'it': 11,
#   'its': 1,
#   'may': 3,
#   'more': 10,
#   'not': 17,
#   'of': 168,
#   'on': 5,
#   'one': 3,
#   'or': 19,
#   'other': 10,
#   'people': 4,
#   'power': 4,
#   'state': 6,
#   'states': 7,
#   'than': 6,
#   'that': 24,
#   'the': 189,
#   'their': 15,
#   'them': 3,
#   'they': 13,
#   'this': 11,
#   'those': 7,
#   'to': 61,
#   'we': 5,
#   'which': 24,
#   'will': 6,
#   'with': 15,
#   'would': 6},
#  {'a': 48,
#   'all': 12,
#   'an': 15,
#   'and': 51,
#   'any': 7,
#   'are': 7,
#   'as': 19,
#   'at': 11,
#   'be': 47,
#   'been': 8,
#   'but': 3,
#   'by': 28,
#   'can': 3,
#   'for': 14,
#   'from': 11,
#   'government': 2,
#   'has': 4,
#   'have': 23,
#   'if': 12,
#   'in': 43,
#   'is': 14,
#   'it': 17,
#   'its': 2,
#   'may': 3,
#   'more': 6,
#   'no': 3,
#   'not': 14,
#   'of': 158,
#   'on': 13,
#   'one': 4,
#   'or': 10,
#   'other': 9,
#   'people': 1,
#   'power': 2,
#   'state': 8,
#   'states': 31,
#   'than': 5,
#   'that': 27,
#   'the': 207,
#   'their': 18,
#   'them': 12,
#   'they': 7,
#   'this': 22,
#   'those': 8,
#   'to': 82,
#   'we': 16,
#   'which': 24,
#   'will': 1,
#   'with': 12,
#   'would': 51},
#  {'a': 45,
#   'all': 9,
#   'an': 13,
#   'and': 54,
#   'any': 2,
#   'are': 14,
#   'as': 16,
#   'at': 11,
#   'be': 35,
#   'been': 16,
#   'but': 10,
#   'by': 11,
#   'can': 1,
#   'for': 9,
#   'from': 9,
#   'government': 3,
#   'has': 8,
#   'have': 18,
#   'if': 7,
#   'in': 42,
#   'is': 21,
#   'it': 20,
#   'its': 10,
#   'may': 8,
#   'more': 8,
#   'no': 5,
#   'not': 12,
#   'of': 135,
#   'on': 11,
#   'one': 6,
#   'or': 17,
#   'other': 6,
#   'people': 9,
#   'power': 5,
#   'state': 7,
#   'states': 10,
#   'than': 3,
#   'that': 18,
#   'the': 158,
#   'their': 16,
#   'them': 11,
#   'they': 13,
#   'this': 19,
#   'those': 6,
#   'to': 80,
#   'we': 5,
#   'which': 26,
#   'will': 11,
#   'with': 13,
#   'would': 27},
#  {'a': 47,
#   'all': 8,
#   'an': 13,
#   'and': 45,
#   'any': 4,
#   'are': 14,
#   'as': 19,
#   'at': 10,
#   'be': 26,
#   'been': 15,
#   'but': 6,
#   'by': 13,
#   'can': 1,
#   'for': 10,
#   'from': 7,
#   'government': 17,
#   'has': 12,
#   'have': 24,
#   'if': 7,
#   'in': 37,
#   'is': 16,
#   'it': 24,
#   'its': 5,
#   'may': 5,
#   'more': 6,
#   'no': 2,
#   'not': 13,
#   'of': 155,
#   'on': 9,
#   'one': 12,
#   'or': 11,
#   'other': 5,
#   'people': 3,
#   'power': 3,
#   'state': 7,
#   'states': 12,
#   'than': 1,
#   'that': 25,
#   'the': 170,
#   'their': 14,
#   'them': 5,
#   'they': 20,
#   'this': 15,
#   'those': 6,
#   'to': 71,
#   'we': 6,
#   'which': 25,
#   'will': 7,
#   'with': 14,
#   'would': 8},
#  {'a': 78,
#   'all': 4,
#   'an': 14,
#   'and': 121,
#   'any': 4,
#   'are': 27,
#   'as': 20,
#   'at': 8,
#   'be': 61,
#   'been': 9,
#   'but': 11,
#   'by': 39,
#   'can': 4,
#   'for': 18,
#   'from': 12,
#   'government': 13,
#   'has': 4,
#   'have': 16,
#   'if': 6,
#   'in': 63,
#   'is': 41,
#   'it': 47,
#   'its': 9,
#   'may': 16,
#   'more': 12,
#   'no': 5,
#   'not': 14,
#   'of': 157,
#   'on': 18,
#   'one': 8,
#   'or': 22,
#   'other': 22,
#   'people': 5,
#   'power': 1,
#   'state': 3,
#   'states': 3,
#   'than': 13,
#   'that': 31,
#   'the': 261,
#   'their': 21,
#   'them': 8,
#   'they': 11,
#   'this': 11,
#   'those': 4,
#   'to': 100,
#   'we': 9,
#   'which': 39,
#   'will': 30,
#   'with': 11,
#   'would': 6},
#  {'a': 69,
#   'all': 13,
#   'an': 15,
#   'and': 70,
#   'any': 4,
#   'are': 9,
#   'as': 21,
#   'at': 11,
#   'be': 44,
#   'been': 3,
#   'but': 8,
#   'by': 20,
#   'can': 5,
#   'for': 18,
#   'from': 19,
#   'government': 5,
#   'has': 8,
#   'have': 15,
#   'if': 6,
#   'in': 66,
#   'is': 9,
#   'it': 21,
#   'its': 6,
#   'may': 9,
#   'more': 9,
#   'no': 5,
#   'not': 20,
#   'of': 180,
#   'on': 5,
#   'one': 5,
#   'or': 12,
#   'other': 10,
#   'people': 1,
#   'power': 3,
#   'state': 5,
#   'states': 13,
#   'than': 6,
#   'that': 24,
#   'the': 188,
#   'their': 11,
#   'them': 6,
#   'they': 10,
#   'this': 24,
#   'those': 7,
#   'to': 83,
#   'we': 12,
#   'which': 25,
#   'will': 17,
#   'with': 22,
#   'would': 50},
#  {'a': 47,
#   'all': 5,
#   'an': 11,
#   'and': 62,
#   'any': 7,
#   'are': 15,
#   'as': 19,
#   'at': 13,
#   'be': 40,
#   'been': 8,
#   'but': 8,
#   'by': 15,
#   'can': 2,
#   'for': 8,
#   'from': 19,
#   'government': 8,
#   'has': 13,
#   'have': 13,
#   'if': 7,
#   'in': 54,
#   'is': 22,
#   'it': 26,
#   'its': 8,
#   'may': 3,
#   'more': 5,
#   'no': 2,
#   'not': 6,
#   'of': 141,
#   'on': 12,
#   'one': 5,
#   'or': 7,
#   'other': 14,
#   'people': 4,
#   'power': 1,
#   'state': 12,
#   'states': 10,
#   'than': 4,
#   'that': 27,
#   'the': 176,
#   'their': 14,
#   'them': 6,
#   'they': 8,
#   'this': 17,
#   'those': 3,
#   'to': 82,
#   'we': 5,
#   'which': 23,
#   'will': 11,
#   'with': 18,
#   'would': 22},
#  {'a': 26,
#   'all': 3,
#   'an': 3,
#   'and': 17,
#   'any': 3,
#   'are': 4,
#   'as': 8,
#   'at': 1,
#   'be': 25,
#   'been': 2,
#   'but': 2,
#   'by': 5,
#   'can': 4,
#   'for': 1,
#   'from': 5,
#   'government': 7,
#   'has': 2,
#   'have': 4,
#   'if': 6,
#   'in': 14,
#   'is': 9,
#   'it': 6,
#   'its': 2,
#   'may': 8,
#   'more': 6,
#   'no': 4,
#   'not': 5,
#   'of': 58,
#   'on': 3,
#   'one': 8,
#   'or': 3,
#   'other': 1,
#   'people': 3,
#   'power': 5,
#   'state': 4,
#   'states': 9,
#   'than': 10,
#   'that': 18,
#   'the': 74,
#   'their': 1,
#   'them': 1,
#   'they': 3,
#   'this': 5,
#   'to': 43,
#   'we': 11,
#   'which': 11,
#   'will': 9,
#   'with': 10,
#   'would': 14},
#  {'a': 37,
#   'all': 6,
#   'an': 9,
#   'and': 60,
#   'any': 3,
#   'are': 7,
#   'as': 24,
#   'at': 7,
#   'be': 45,
#   'been': 9,
#   'but': 4,
#   'by': 18,
#   'can': 9,
#   'for': 20,
#   'from': 11,
#   'government': 9,
#   'has': 8,
#   'have': 17,
#   'if': 6,
#   'in': 40,
#   'is': 25,
#   'it': 31,
#   'its': 8,
#   'may': 16,
#   'more': 8,
#   'no': 10,
#   'not': 13,
#   'of': 124,
#   'on': 17,
#   'one': 2,
#   'or': 11,
#   'other': 7,
#   'people': 6,
#   'power': 3,
#   'state': 2,
#   'states': 12,
#   'than': 5,
#   'that': 33,
#   'the': 202,
#   'their': 19,
#   'them': 4,
#   'they': 17,
#   'this': 13,
#   'those': 13,
#   'to': 72,
#   'we': 8,
#   'which': 40,
#   'will': 26,
#   'with': 7,
#   'would': 5},
#  {'a': 69,
#   'all': 21,
#   'an': 18,
#   'and': 74,
#   'any': 3,
#   'are': 22,
#   'as': 15,
#   'at': 24,
#   'be': 44,
#   'been': 14,
#   'but': 8,
#   'by': 32,
#   'can': 14,
#   'for': 18,
#   'from': 22,
#   'government': 13,
#   'has': 14,
#   'have': 31,
#   'if': 7,
#   'in': 73,
#   'is': 48,
#   'it': 30,
#   'its': 8,
#   'may': 7,
#   'more': 6,
#   'no': 6,
#   'not': 16,
#   'of': 196,
#   'on': 10,
#   'one': 1,
#   'or': 38,
#   'other': 6,
#   'people': 5,
#   'power': 9,
#   'state': 6,
#   'states': 11,
#   'than': 10,
#   'that': 38,
#   'the': 253,
#   'their': 7,
#   'them': 4,
#   'they': 15,
#   'this': 24,
#   'those': 10,
#   'to': 117,
#   'we': 24,
#   'which': 55,
#   'will': 19,
#   'with': 19,
#   'would': 13},
#  {'a': 37,
#   'all': 9,
#   'an': 13,
#   'and': 42,
#   'any': 11,
#   'are': 3,
#   'as': 19,
#   'at': 11,
#   'be': 55,
#   'been': 7,
#   'but': 6,
#   'by': 13,
#   'can': 1,
#   'for': 9,
#   'from': 11,
#   'government': 12,
#   'has': 7,
#   'have': 12,
#   'if': 14,
#   'in': 39,
#   'is': 14,
#   'it': 37,
#   'its': 17,
#   'may': 5,
#   'more': 6,
#   'no': 6,
#   'not': 20,
#   'of': 143,
#   'on': 4,
#   'one': 2,
#   'or': 17,
#   'other': 2,
#   'people': 5,
#   'power': 3,
#   'state': 9,
#   'states': 11,
#   'than': 4,
#   'that': 16,
#   'the': 193,
#   'their': 12,
#   'them': 6,
#   'they': 15,
#   'this': 18,
#   'those': 10,
#   'to': 89,
#   'we': 4,
#   'which': 22,
#   'will': 5,
#   'with': 13,
#   'would': 36},
#  {'a': 30,
#   'all': 12,
#   'an': 9,
#   'and': 52,
#   'any': 2,
#   'are': 5,
#   'as': 3,
#   'at': 7,
#   'be': 24,
#   'been': 3,
#   'but': 3,
#   'by': 9,
#   'can': 2,
#   'for': 11,
#   'from': 5,
#   'government': 9,
#   'has': 4,
#   'have': 4,
#   'if': 2,
#   'in': 29,
#   'is': 11,
#   'it': 16,
#   'its': 6,
#   'may': 4,
#   'more': 9,
#   'not': 4,
#   'of': 110,
#   'on': 2,
#   'one': 2,
#   'or': 13,
#   'other': 7,
#   'people': 9,
#   'power': 7,
#   'state': 10,
#   'states': 4,
#   'than': 5,
#   'that': 21,
#   'the': 162,
#   'their': 10,
#   'them': 8,
#   'they': 7,
#   'this': 11,
#   'those': 9,
#   'to': 58,
#   'we': 1,
#   'which': 24,
#   'will': 12,
#   'with': 10,
#   'would': 12},
#  {'a': 37,
#   'all': 8,
#   'an': 5,
#   'and': 79,
#   'any': 2,
#   'are': 2,
#   'as': 14,
#   'at': 4,
#   'be': 6,
#   'been': 4,
#   'but': 7,
#   'by': 33,
#   'for': 7,
#   'from': 10,
#   'government': 7,
#   'have': 5,
#   'in': 41,
#   'is': 10,
#   'it': 26,
#   'its': 9,
#   'more': 10,
#   'no': 2,
#   'not': 6,
#   'of': 135,
#   'on': 16,
#   'one': 6,
#   'or': 4,
#   'other': 2,
#   'people': 2,
#   'power': 1,
#   'state': 1,
#   'states': 2,
#   'than': 7,
#   'that': 21,
#   'the': 240,
#   'their': 23,
#   'them': 2,
#   'they': 12,
#   'this': 17,
#   'those': 5,
#   'to': 54,
#   'we': 3,
#   'which': 12,
#   'will': 1,
#   'with': 12,
#   'would': 6},
#  {'a': 27,
#   'all': 5,
#   'an': 9,
#   'and': 82,
#   'any': 6,
#   'are': 17,
#   'as': 10,
#   'at': 5,
#   'be': 14,
#   'been': 4,
#   'but': 2,
#   'by': 22,
#   'can': 1,
#   'for': 7,
#   'from': 16,
#   'government': 1,
#   'has': 7,
#   'have': 11,
#   'if': 4,
#   'in': 41,
#   'is': 16,
#   'it': 19,
#   'its': 13,
#   'may': 5,
#   'more': 6,
#   'no': 6,
#   'not': 4,
#   'of': 125,
#   'on': 17,
#   'one': 9,
#   'or': 9,
#   'other': 5,
#   'people': 4,
#   'power': 3,
#   'state': 1,
#   'states': 6,
#   'than': 3,
#   'that': 13,
#   'the': 208,
#   'their': 11,
#   'them': 7,
#   'they': 9,
#   'this': 12,
#   'to': 59,
#   'we': 1,
#   'which': 31,
#   'will': 1,
#   'with': 21,
#   'would': 4},
#  {'a': 28,
#   'all': 7,
#   'an': 5,
#   'and': 54,
#   'are': 13,
#   'as': 12,
#   'at': 8,
#   'be': 7,
#   'been': 1,
#   'but': 5,
#   'by': 19,
#   'can': 1,
#   'for': 18,
#   'from': 18,
#   'government': 4,
#   'has': 10,
#   'have': 10,
#   'if': 1,
#   'in': 39,
#   'is': 15,
#   'it': 12,
#   'its': 2,
#   'may': 2,
#   'more': 2,
#   'no': 2,
#   'not': 4,
#   'of': 81,
#   'on': 7,
#   'one': 4,
#   'or': 8,
#   'other': 4,
#   'people': 2,
#   'power': 2,
#   'state': 3,
#   'states': 2,
#   'than': 5,
#   'that': 9,
#   'the': 137,
#   'their': 20,
#   'them': 5,
#   'they': 7,
#   'this': 8,
#   'those': 1,
#   'to': 42,
#   'we': 2,
#   'which': 13,
#   'will': 4,
#   'with': 8,
#   'would': 1},
#  {'a': 64,
#   'all': 3,
#   'an': 10,
#   'and': 49,
#   'any': 6,
#   'are': 8,
#   'as': 18,
#   'at': 4,
#   'be': 40,
#   'been': 11,
#   'but': 2,
#   'by': 22,
#   'can': 9,
#   'for': 5,
#   'from': 16,
#   'government': 9,
#   'has': 9,
#   'have': 9,
#   'if': 11,
#   'in': 48,
#   'is': 27,
#   'it': 17,
#   'its': 12,
#   'may': 11,
#   'more': 3,
#   'no': 12,
#   'not': 8,
#   'of': 151,
#   'on': 6,
#   'one': 1,
#   'or': 21,
#   'other': 6,
#   'people': 7,
#   'power': 5,
#   'state': 14,
#   'states': 12,
#   'than': 4,
#   'that': 24,
#   'the': 184,
#   'their': 8,
#   'them': 3,
#   'they': 7,
#   'this': 17,
#   'those': 9,
#   'to': 55,
#   'we': 9,
#   'which': 20,
#   'will': 6,
#   'with': 15,
#   'would': 12},
#  {'a': 98,
#   'all': 12,
#   'an': 19,
#   'and': 83,
#   'any': 7,
#   'are': 18,
#   'as': 26,
#   'at': 12,
#   'be': 54,
#   'been': 16,
#   'but': 16,
#   'by': 30,
#   'can': 6,
#   'for': 21,
#   'from': 23,
#   'government': 13,
#   'has': 20,
#   'have': 14,
#   'if': 9,
#   'in': 86,
#   'is': 48,
#   'it': 46,
#   'its': 18,
#   'may': 20,
#   'more': 6,
#   'no': 6,
#   'not': 25,
#   'of': 242,
#   'on': 9,
#   'one': 10,
#   'or': 21,
#   'other': 5,
#   'people': 9,
#   'power': 13,
#   'state': 8,
#   'states': 26,
#   'than': 11,
#   'that': 53,
#   'the': 296,
#   'their': 23,
#   'them': 3,
#   'they': 15,
#   'this': 31,
#   'those': 13,
#   'to': 145,
#   'we': 14,
#   'which': 36,
#   'will': 11,
#   'with': 20,
#   'would': 20},
#  {'a': 24,
#   'all': 10,
#   'an': 11,
#   'and': 56,
#   'any': 9,
#   'are': 18,
#   'as': 22,
#   'at': 3,
#   'be': 45,
#   'been': 6,
#   'but': 3,
#   'by': 11,
#   'can': 11,
#   'for': 17,
#   'from': 6,
#   'government': 15,
#   'has': 5,
#   'have': 11,
#   'if': 6,
#   'in': 26,
#   'is': 23,
#   'it': 23,
#   'its': 12,
#   'may': 7,
#   'more': 2,
#   'no': 2,
#   'not': 11,
#   'of': 100,
#   'on': 2,
#   'one': 3,
#   'or': 8,
#   'other': 7,
#   'people': 4,
#   'power': 7,
#   'state': 3,
#   'states': 5,
#   'that': 28,
#   'the': 185,
#   'their': 8,
#   'them': 6,
#   'they': 4,
#   'this': 14,
#   'those': 4,
#   'to': 97,
#   'we': 11,
#   'which': 31,
#   'will': 15,
#   'with': 16,
#   'would': 4},
#  {'a': 51,
#   'all': 8,
#   'an': 9,
#   'and': 59,
#   'any': 6,
#   'are': 10,
#   'as': 13,
#   'at': 7,
#   'be': 52,
#   'been': 4,
#   'but': 6,
#   'by': 14,
#   'can': 4,
#   'for': 10,
#   'from': 11,
#   'government': 4,
#   'has': 9,
#   'have': 12,
#   'if': 13,
#   'in': 56,
#   'is': 10,
#   'it': 23,
#   'its': 4,
#   'may': 4,
#   'more': 1,
#   'no': 5,
#   'not': 13,
#   'of': 120,
#   'on': 11,
#   'one': 8,
#   'or': 12,
#   'other': 6,
#   'people': 5,
#   'power': 2,
#   'state': 5,
#   'states': 5,
#   'than': 4,
#   'that': 33,
#   'the': 149,
#   'their': 13,
#   'them': 5,
#   'they': 5,
#   'this': 23,
#   'those': 2,
#   'to': 91,
#   'we': 4,
#   'which': 15,
#   'will': 8,
#   'with': 5,
#   'would': 25},
#  {'a': 44,
#   'all': 7,
#   'an': 7,
#   'and': 46,
#   'any': 4,
#   'are': 14,
#   'as': 24,
#   'at': 11,
#   'be': 52,
#   'been': 6,
#   'but': 4,
#   'by': 22,
#   'can': 3,
#   'for': 11,
#   'from': 12,
#   'government': 10,
#   'has': 5,
#   'have': 11,
#   'if': 5,
#   'in': 40,
#   'is': 17,
#   'it': 26,
#   'its': 9,
#   'may': 4,
#   'more': 2,
#   'no': 2,
#   'not': 8,
#   'of': 126,
#   'on': 11,
#   'one': 2,
#   'or': 15,
#   'other': 8,
#   'people': 5,
#   'power': 4,
#   'state': 8,
#   'states': 10,
#   'than': 4,
#   'that': 31,
#   'the': 175,
#   'their': 11,
#   'them': 8,
#   'they': 9,
#   'this': 20,
#   'those': 6,
#   'to': 90,
#   'we': 8,
#   'which': 15,
#   'will': 10,
#   'with': 8,
#   'would': 21},
#  {'a': 53,
#   'all': 8,
#   'an': 22,
#   'and': 49,
#   'any': 10,
#   'are': 6,
#   'as': 18,
#   'at': 12,
#   'be': 54,
#   'been': 8,
#   'but': 11,
#   'by': 21,
#   'can': 5,
#   'for': 21,
#   'from': 11,
#   'government': 9,
#   'has': 6,
#   'have': 16,
#   'if': 16,
#   'in': 64,
#   'is': 25,
#   'it': 43,
#   'its': 4,
#   'may': 10,
#   'more': 3,
#   'no': 4,
#   'not': 23,
#   'of': 148,
#   'on': 7,
#   'one': 5,
#   'or': 12,
#   'other': 2,
#   'people': 9,
#   'power': 9,
#   'state': 7,
#   'states': 7,
#   'than': 5,
#   'that': 42,
#   'the': 201,
#   'their': 10,
#   'them': 2,
#   'they': 12,
#   'this': 15,
#   'those': 5,
#   'to': 95,
#   'we': 11,
#   'which': 21,
#   'will': 11,
#   'with': 9,
#   'would': 16},
#  {'a': 30,
#   'all': 4,
#   'an': 5,
#   'and': 33,
#   'any': 8,
#   'are': 10,
#   'as': 11,
#   'at': 4,
#   'be': 34,
#   'been': 6,
#   'but': 5,
#   'by': 14,
#   'can': 11,
#   'for': 7,
#   'from': 5,
#   'government': 16,
#   'has': 3,
#   'have': 5,
#   'if': 5,
#   'in': 30,
#   'is': 14,
#   'it': 21,
#   'its': 16,
#   'may': 4,
#   'more': 8,
#   'no': 3,
#   'not': 2,
#   'of': 93,
#   'on': 4,
#   'one': 2,
#   'or': 14,
#   'other': 2,
#   'people': 8,
#   'power': 2,
#   'state': 9,
#   'states': 2,
#   'than': 7,
#   'that': 38,
#   'the': 149,
#   'their': 6,
#   'them': 2,
#   'they': 5,
#   'this': 9,
#   'those': 4,
#   'to': 63,
#   'we': 6,
#   'which': 19,
#   'will': 34,
#   'with': 6,
#   'would': 3},
#  {'a': 33,
#   'all': 15,
#   'an': 13,
#   'and': 35,
#   'any': 2,
#   'are': 6,
#   'as': 10,
#   'at': 7,
#   'be': 41,
#   'been': 4,
#   'but': 4,
#   'by': 7,
#   'can': 12,
#   'for': 15,
#   'from': 6,
#   'government': 16,
#   'has': 5,
#   'have': 11,
#   'if': 10,
#   'in': 40,
#   'is': 14,
#   'it': 18,
#   'its': 9,
#   'may': 7,
#   'more': 9,
#   'no': 6,
#   'not': 8,
#   'of': 97,
#   'on': 1,
#   'one': 4,
#   'or': 8,
#   'other': 4,
#   'people': 12,
#   'power': 7,
#   'state': 13,
#   'states': 5,
#   'than': 3,
#   'that': 20,
#   'the': 166,
#   'their': 13,
#   'them': 5,
#   'they': 8,
#   'this': 7,
#   'those': 4,
#   'to': 66,
#   'we': 4,
#   'which': 14,
#   'will': 13,
#   'with': 9,
#   'would': 12},
#  {'a': 50,
#   'all': 4,
#   'an': 14,
#   'and': 59,
#   'any': 6,
#   'are': 10,
#   'as': 26,
#   'at': 11,
#   'be': 50,
#   'been': 6,
#   'but': 7,
#   'by': 10,
#   'can': 11,
#   'for': 17,
#   'from': 13,
#   'government': 8,
#   'has': 5,
#   'have': 7,
#   'if': 15,
#   'in': 41,
#   'is': 31,
#   'it': 42,
#   'its': 6,
#   'may': 7,
#   'more': 2,
#   'no': 5,
#   'not': 9,
#   'of': 154,
#   'on': 3,
#   'one': 4,
#   'or': 17,
#   'other': 1,
#   'people': 9,
#   'power': 11,
#   'state': 5,
#   'states': 6,
#   'than': 2,
#   'that': 30,
#   'the': 222,
#   'their': 14,
#   'them': 12,
#   'they': 7,
#   'this': 14,
#   'those': 4,
#   'to': 112,
#   'we': 5,
#   'which': 16,
#   'will': 11,
#   'with': 12,
#   'would': 19},
#  {'a': 38,
#   'all': 5,
#   'an': 7,
#   'and': 45,
#   'any': 8,
#   'are': 7,
#   'as': 22,
#   'at': 6,
#   'be': 49,
#   'been': 10,
#   'but': 11,
#   'by': 14,
#   'can': 12,
#   'for': 23,
#   'from': 8,
#   'government': 14,
#   'has': 10,
#   'have': 11,
#   'if': 4,
#   'in': 49,
#   'is': 15,
#   'it': 29,
#   'its': 24,
#   'may': 9,
#   'more': 3,
#   'no': 5,
#   'not': 7,
#   'of': 113,
#   'on': 8,
#   'one': 5,
#   'or': 20,
#   'other': 7,
#   'people': 4,
#   'power': 8,
#   'state': 6,
#   'states': 5,
#   'than': 3,
#   'that': 31,
#   'the': 164,
#   'their': 8,
#   'them': 2,
#   'they': 10,
#   'this': 17,
#   'those': 5,
#   'to': 76,
#   'we': 5,
#   'which': 20,
#   'will': 11,
#   'with': 12,
#   'would': 22},
#  {'a': 24,
#   'all': 9,
#   'an': 12,
#   'and': 44,
#   'any': 5,
#   'are': 18,
#   'as': 20,
#   'at': 5,
#   'be': 36,
#   'been': 5,
#   'but': 8,
#   'by': 9,
#   'can': 2,
#   'for': 6,
#   'from': 10,
#   'government': 10,
#   'has': 1,
#   'have': 11,
#   'if': 3,
#   'in': 49,
#   'is': 23,
#   'it': 27,
#   'its': 8,
#   'may': 10,
#   'more': 1,
#   'no': 3,
#   'not': 12,
#   'of': 105,
#   'on': 5,
#   'one': 2,
#   'or': 13,
#   'other': 7,
#   'people': 6,
#   'power': 13,
#   'state': 10,
#   'states': 2,
#   'than': 6,
#   'that': 30,
#   'the': 162,
#   'their': 10,
#   'them': 8,
#   'they': 10,
#   'this': 13,
#   'those': 9,
#   'to': 82,
#   'we': 6,
#   'which': 20,
#   'will': 6,
#   'with': 11,
#   'would': 5},
#  {'a': 36,
#   'all': 6,
#   'an': 15,
#   'and': 41,
#   'any': 6,
#   'are': 2,
#   'as': 4,
#   'at': 2,
#   'be': 30,
#   'been': 4,
#   'but': 10,
#   'by': 10,
#   'can': 1,
#   'for': 4,
#   'from': 9,
#   'government': 3,
#   'has': 2,
#   'have': 5,
#   'if': 6,
#   'in': 40,
#   'is': 16,
#   'it': 24,
#   'its': 3,
#   'may': 2,
#   'no': 7,
#   'not': 15,
#   'of': 91,
#   'on': 14,
#   'one': 4,
#   'or': 11,
#   'other': 5,
#   'people': 2,
#   'power': 16,
#   'state': 10,
#   'states': 21,
#   'than': 1,
#   'that': 32,
#   'the': 150,
#   'their': 4,
#   'them': 8,
#   'they': 4,
#   'this': 16,
#   'those': 1,
#   'to': 47,
#   'we': 2,
#   'which': 23,
#   'will': 3,
#   'with': 5,
#   'would': 23},
#  {'a': 44,
#   'all': 8,
#   'an': 8,
#   'and': 44,
#   'any': 7,
#   'are': 8,
#   'as': 14,
#   'at': 2,
#   'be': 32,
#   'been': 11,
#   'but': 15,
#   'by': 14,
#   'can': 2,
#   'for': 9,
#   'from': 9,
#   'government': 7,
#   'has': 3,
#   'have': 13,
#   'if': 8,
#   'in': 33,
#   'is': 26,
#   'it': 39,
#   'its': 13,
#   'may': 10,
#   'more': 1,
#   'not': 13,
#   'of': 90,
#   'on': 5,
#   'one': 2,
#   'or': 12,
#   'other': 3,
#   'people': 3,
#   'power': 20,
#   'state': 10,
#   'states': 4,
#   'than': 1,
#   'that': 32,
#   'the': 158,
#   'their': 5,
#   'them': 1,
#   'they': 9,
#   'this': 18,
#   'those': 6,
#   'to': 67,
#   'we': 2,
#   'which': 22,
#   'will': 9,
#   'with': 5,
#   'would': 15},
#  {'a': 45,
#   'all': 6,
#   'an': 13,
#   'and': 48,
#   'any': 8,
#   'are': 19,
#   'as': 20,
#   'at': 6,
#   'be': 42,
#   'been': 12,
#   'but': 9,
#   'by': 4,
#   'can': 7,
#   'for': 26,
#   'from': 12,
#   'government': 8,
#   'has': 6,
#   'have': 16,
#   'if': 12,
#   'in': 55,
#   'is': 16,
#   'it': 23,
#   'its': 11,
#   'may': 6,
#   'more': 4,
#   'no': 8,
#   'not': 15,
#   'of': 137,
#   'on': 11,
#   'one': 8,
#   'or': 12,
#   'other': 12,
#   'people': 3,
#   'power': 10,
#   'state': 12,
#   'states': 12,
#   'than': 3,
#   'that': 43,
#   'the': 186,
#   'their': 10,
#   'them': 4,
#   'they': 7,
#   'this': 14,
#   'those': 10,
#   'to': 107,
#   'we': 21,
#   'which': 27,
#   'will': 16,
#   'with': 12,
#   'would': 20},
#  {'a': 45,
#   'all': 7,
#   'an': 13,
#   'and': 65,
#   'any': 8,
#   'are': 15,
#   'as': 22,
#   'at': 4,
#   'be': 45,
#   'been': 5,
#   'but': 12,
#   'by': 10,
#   'can': 6,
#   'for': 11,
#   'from': 8,
#   'government': 4,
#   'has': 3,
#   'have': 9,
#   'if': 7,
#   'in': 47,
#   'is': 41,
#   'it': 26,
#   'its': 3,
#   'may': 8,
#   'more': 9,
#   'no': 6,
#   'not': 19,
#   'of': 130,
#   'on': 8,
#   'one': 5,
#   'or': 12,
#   'other': 8,
#   'people': 6,
#   'power': 5,
#   'state': 5,
#   'states': 6,
#   'than': 8,
#   'that': 37,
#   'the': 188,
#   'their': 19,
#   'them': 9,
#   'they': 21,
#   'this': 14,
#   'those': 9,
#   'to': 101,
#   'we': 9,
#   'which': 22,
#   'will': 21,
#   'with': 12,
#   'would': 16},
#  {'a': 45,
#   'all': 11,
#   'an': 16,
#   'and': 77,
#   'any': 10,
#   'are': 19,
#   'as': 35,
#   'at': 4,
#   'be': 82,
#   'been': 14,
#   'but': 11,
#   'by': 21,
#   'can': 16,
#   'for': 16,
#   'from': 22,
#   'government': 16,
#   'has': 9,
#   'have': 28,
#   'if': 10,
#   'in': 69,
#   'is': 35,
#   'it': 39,
#   'its': 19,
#   'may': 15,
#   'more': 15,
#   'no': 6,
#   'not': 15,
#   'of': 193,
#   'on': 6,
#   'one': 6,
#   'or': 28,
#   'other': 8,
#   'people': 7,
#   'power': 15,
#   'state': 25,
#   'states': 9,
#   'than': 6,
#   'that': 44,
#   'the': 267,
#   'their': 15,
#   'them': 10,
#   'they': 8,
#   'this': 25,
#   'those': 10,
#   'to': 130,
#   'we': 8,
#   'which': 31,
#   'will': 32,
#   'with': 15,
#   'would': 6},
#  {'a': 56,
#   'all': 10,
#   'an': 10,
#   'and': 101,
#   'any': 3,
#   'are': 18,
#   'as': 29,
#   'at': 2,
#   'be': 47,
#   'been': 24,
#   'but': 12,
#   'by': 30,
#   'can': 2,
#   'for': 12,
#   'from': 20,
#   'government': 11,
#   'has': 10,
#   'have': 26,
#   'if': 2,
#   'in': 62,
#   'is': 30,
#   'it': 37,
#   'its': 7,
#   'may': 18,
#   'more': 7,
#   'no': 5,
#   'not': 19,
#   'of': 159,
#   'on': 19,
#   'one': 6,
#   'or': 13,
#   'other': 12,
#   'people': 6,
#   'power': 3,
#   'state': 5,
#   'states': 3,
#   'than': 5,
#   'that': 47,
#   'the': 230,
#   'their': 23,
#   'them': 10,
#   'they': 14,
#   'this': 17,
#   'those': 4,
#   'to': 85,
#   'we': 8,
#   'which': 44,
#   'will': 10,
#   'with': 17,
#   'would': 7},
#  {'a': 92,
#   'all': 8,
#   'an': 18,
#   'and': 94,
#   'any': 9,
#   'are': 19,
#   'as': 29,
#   'at': 6,
#   'be': 51,
#   'been': 15,
#   'but': 20,
#   'by': 37,
#   'can': 9,
#   'for': 21,
#   'from': 21,
#   'government': 19,
#   'has': 12,
#   'have': 21,
#   'if': 6,
#   'in': 62,
#   'is': 57,
#   'it': 49,
#   'its': 6,
#   'may': 9,
#   'more': 10,
#   'no': 17,
#   'not': 32,
#   'of': 190,
#   'on': 15,
#   'one': 13,
#   'or': 17,
#   'other': 4,
#   'people': 6,
#   'power': 11,
#   'state': 8,
#   'states': 12,
#   'than': 11,
#   'that': 56,
#   'the': 271,
#   'their': 25,
#   'them': 17,
#   'they': 22,
#   'this': 24,
#   'those': 3,
#   'to': 117,
#   'we': 9,
#   'which': 26,
#   'will': 12,
#   'with': 22,
#   'would': 15},
#  {'a': 53,
#   'all': 13,
#   'an': 6,
#   'and': 64,
#   'any': 4,
#   'are': 20,
#   'as': 33,
#   'at': 7,
#   'be': 52,
#   'been': 8,
#   'but': 14,
#   'by': 33,
#   'can': 1,
#   'for': 14,
#   'from': 23,
#   'government': 32,
#   'has': 9,
#   'have': 3,
#   'if': 5,
#   'in': 73,
#   'is': 57,
#   'it': 44,
#   'its': 20,
#   'may': 6,
#   'more': 6,
#   'no': 7,
#   'not': 22,
#   'of': 157,
#   'on': 25,
#   'one': 13,
#   'or': 14,
#   'other': 10,
#   'people': 25,
#   'power': 2,
#   'state': 12,
#   'states': 24,
#   'than': 8,
#   'that': 28,
#   'the': 300,
#   'their': 16,
#   'them': 6,
#   'they': 10,
#   'this': 21,
#   'those': 1,
#   'to': 91,
#   'we': 7,
#   'which': 27,
#   'will': 15,
#   'with': 12,
#   'would': 8},
#  {'a': 53,
#   'all': 11,
#   'an': 12,
#   'and': 100,
#   'any': 2,
#   'are': 13,
#   'as': 33,
#   'at': 7,
#   'be': 54,
#   'been': 20,
#   'but': 7,
#   'by': 55,
#   'can': 3,
#   'for': 23,
#   'from': 16,
#   'government': 25,
#   'has': 10,
#   'have': 26,
#   'if': 8,
#   'in': 68,
#   'is': 29,
#   'it': 35,
#   'its': 4,
#   'may': 7,
#   'more': 4,
#   'no': 9,
#   'not': 19,
#   'of': 174,
#   'on': 13,
#   'one': 9,
#   'or': 10,
#   'other': 3,
#   'people': 13,
#   'power': 6,
#   'state': 6,
#   'states': 31,
#   'than': 5,
#   'that': 63,
#   'the': 294,
#   'their': 35,
#   'them': 9,
#   'they': 28,
#   'this': 18,
#   'those': 7,
#   'to': 120,
#   'we': 3,
#   'which': 31,
#   'will': 7,
#   'with': 15,
#   'would': 6},
#  {'a': 81,
#   'all': 17,
#   'an': 20,
#   'and': 88,
#   'any': 6,
#   'are': 15,
#   'as': 33,
#   'at': 5,
#   'be': 74,
#   'been': 20,
#   'but': 14,
#   'by': 32,
#   'can': 9,
#   'for': 35,
#   'from': 22,
#   'government': 13,
#   'has': 18,
#   'have': 26,
#   'if': 13,
#   'in': 63,
#   'is': 38,
#   'it': 52,
#   'its': 15,
#   'may': 23,
#   'more': 12,
#   'no': 9,
#   'not': 18,
#   'of': 204,
#   'on': 27,
#   'one': 8,
#   'or': 21,
#   'other': 10,
#   'people': 9,
#   'power': 28,
#   'state': 3,
#   'states': 12,
#   'than': 13,
#   'that': 42,
#   'the': 336,
#   'their': 13,
#   'them': 10,
#   'they': 15,
#   'this': 28,
#   'those': 6,
#   'to': 119,
#   'we': 7,
#   'which': 36,
#   'will': 25,
#   'with': 16,
#   'would': 9},
#  {'a': 50,
#   'all': 9,
#   'an': 16,
#   'and': 96,
#   'any': 11,
#   'are': 9,
#   'as': 22,
#   'at': 3,
#   'be': 48,
#   'been': 19,
#   'but': 11,
#   'by': 31,
#   'can': 3,
#   'for': 22,
#   'from': 10,
#   'government': 7,
#   'has': 13,
#   'have': 20,
#   'if': 4,
#   'in': 62,
#   'is': 39,
#   'it': 29,
#   'its': 9,
#   'may': 17,
#   'more': 1,
#   'no': 8,
#   'not': 22,
#   'of': 184,
#   'on': 22,
#   'one': 7,
#   'or': 15,
#   'other': 16,
#   'people': 3,
#   'power': 21,
#   'state': 21,
#   'states': 31,
#   'than': 4,
#   'that': 32,
#   'the': 262,
#   'their': 12,
#   'them': 8,
#   'they': 6,
#   'this': 18,
#   'those': 6,
#   'to': 93,
#   'we': 4,
#   'which': 27,
#   'will': 6,
#   'with': 16,
#   'would': 15},
#  {'a': 93,
#   'all': 13,
#   'an': 12,
#   'and': 79,
#   'any': 8,
#   'are': 15,
#   'as': 39,
#   'at': 7,
#   'be': 78,
#   'been': 14,
#   'but': 12,
#   'by': 47,
#   'can': 9,
#   'for': 28,
#   'from': 6,
#   'government': 22,
#   'has': 11,
#   'have': 21,
#   'if': 6,
#   'in': 55,
#   'is': 34,
#   'it': 57,
#   'its': 15,
#   'may': 25,
#   'more': 8,
#   'no': 14,
#   'not': 26,
#   'of': 223,
#   'on': 33,
#   'one': 13,
#   'or': 21,
#   'other': 20,
#   'people': 3,
#   'power': 6,
#   'state': 26,
#   'states': 45,
#   'than': 10,
#   'that': 50,
#   'the': 356,
#   'their': 10,
#   'them': 10,
#   'they': 12,
#   'this': 22,
#   'those': 5,
#   'to': 112,
#   'we': 1,
#   'which': 34,
#   'will': 19,
#   'with': 17,
#   'would': 12},
#  {'a': 43,
#   'all': 20,
#   'an': 10,
#   'and': 88,
#   'any': 15,
#   'are': 13,
#   'as': 28,
#   'at': 4,
#   'be': 54,
#   'been': 19,
#   'but': 8,
#   'by': 28,
#   'can': 7,
#   'for': 20,
#   'from': 9,
#   'government': 11,
#   'has': 7,
#   'have': 33,
#   'if': 8,
#   'in': 66,
#   'is': 28,
#   'it': 19,
#   'its': 6,
#   'may': 6,
#   'more': 9,
#   'no': 18,
#   'not': 16,
#   'of': 171,
#   'on': 28,
#   'one': 5,
#   'or': 37,
#   'other': 9,
#   'people': 6,
#   'power': 21,
#   'state': 22,
#   'states': 29,
#   'than': 8,
#   'that': 28,
#   'the': 315,
#   'their': 9,
#   'them': 6,
#   'they': 15,
#   'this': 25,
#   'those': 4,
#   'to': 81,
#   'we': 2,
#   'which': 30,
#   'will': 10,
#   'with': 18,
#   'would': 29},
#  {'a': 20,
#   'all': 8,
#   'an': 7,
#   'and': 63,
#   'any': 4,
#   'are': 7,
#   'as': 23,
#   'at': 4,
#   'be': 52,
#   'been': 6,
#   'but': 4,
#   'by': 11,
#   'for': 12,
#   'from': 8,
#   'government': 20,
#   'has': 4,
#   'have': 17,
#   'if': 7,
#   'in': 40,
#   'is': 23,
#   'it': 19,
#   'its': 6,
#   'may': 9,
#   'more': 14,
#   'no': 6,
#   'not': 10,
#   'of': 143,
#   'on': 10,
#   'one': 4,
#   'or': 8,
#   'other': 7,
#   'people': 18,
#   'power': 9,
#   'state': 18,
#   'states': 22,
#   'than': 9,
#   'that': 30,
#   'the': 278,
#   'their': 7,
#   'them': 11,
#   'they': 1,
#   'this': 5,
#   'those': 8,
#   'to': 66,
#   'we': 6,
#   'which': 17,
#   'will': 32,
#   'with': 15,
#   'would': 11},
#  {'a': 42,
#   'all': 5,
#   'an': 9,
#   'and': 73,
#   'any': 6,
#   'are': 13,
#   'as': 21,
#   'at': 6,
#   'be': 72,
#   'been': 5,
#   'but': 13,
#   'by': 21,
#   'can': 7,
#   'for': 11,
#   'from': 10,
#   'government': 22,
#   'has': 4,
#   'have': 15,
#   'if': 5,
#   'in': 46,
#   'is': 7,
#   'it': 32,
#   'its': 6,
#   'may': 13,
#   'more': 11,
#   'no': 4,
#   'not': 20,
#   'of': 162,
#   'on': 32,
#   'one': 9,
#   'or': 14,
#   'other': 9,
#   'people': 28,
#   'power': 3,
#   'state': 31,
#   'states': 16,
#   'than': 11,
#   'that': 39,
#   'the': 303,
#   'their': 29,
#   'them': 5,
#   'they': 14,
#   'this': 9,
#   'those': 6,
#   'to': 86,
#   'we': 2,
#   'which': 23,
#   'will': 40,
#   'with': 18,
#   'would': 29},
#  {'a': 35,
#   'all': 12,
#   'an': 10,
#   'and': 86,
#   'any': 5,
#   'are': 26,
#   'as': 20,
#   'at': 7,
#   'be': 35,
#   'been': 14,
#   'but': 5,
#   'by': 42,
#   'can': 9,
#   'for': 7,
#   'from': 12,
#   'government': 9,
#   'has': 17,
#   'have': 14,
#   'if': 5,
#   'in': 62,
#   'is': 43,
#   'it': 22,
#   'its': 10,
#   'may': 8,
#   'more': 9,
#   'no': 15,
#   'not': 12,
#   'of': 187,
#   'on': 20,
#   'one': 17,
#   'or': 18,
#   'other': 12,
#   'people': 1,
#   'power': 16,
#   'state': 7,
#   'states': 2,
#   'than': 5,
#   'that': 36,
#   'the': 327,
#   'their': 1,
#   'them': 6,
#   'they': 8,
#   'this': 24,
#   'those': 1,
#   'to': 65,
#   'we': 7,
#   'which': 22,
#   'will': 4,
#   'with': 20,
#   'would': 4},
#  {'a': 35,
#   'all': 12,
#   'an': 12,
#   'and': 51,
#   'any': 1,
#   'are': 6,
#   'as': 18,
#   'at': 4,
#   'be': 31,
#   'been': 12,
#   'but': 7,
#   'by': 28,
#   'can': 4,
#   'for': 16,
#   'from': 12,
#   'government': 13,
#   'has': 6,
#   'have': 10,
#   'if': 2,
#   'in': 45,
#   'is': 29,
#   'it': 24,
#   'its': 9,
#   'may': 6,
#   'more': 8,
#   'no': 6,
#   'not': 13,
#   'of': 100,
#   'on': 16,
#   'one': 8,
#   'or': 11,
#   'other': 12,
#   'people': 7,
#   'power': 8,
#   'state': 5,
#   'states': 2,
#   'than': 4,
#   'that': 27,
#   'the': 169,
#   'their': 14,
#   'them': 6,
#   'they': 11,
#   'this': 14,
#   'those': 4,
#   'to': 54,
#   'we': 2,
#   'which': 28,
#   'will': 11,
#   'with': 8,
#   'would': 3},
#  {'a': 33,
#   'all': 6,
#   'an': 11,
#   'and': 42,
#   'any': 3,
#   'are': 15,
#   'as': 15,
#   'at': 2,
#   'be': 47,
#   'been': 3,
#   'but': 8,
#   'by': 15,
#   'can': 4,
#   'for': 11,
#   'from': 5,
#   'government': 12,
#   'has': 2,
#   'have': 5,
#   'if': 3,
#   'in': 34,
#   'is': 18,
#   'it': 26,
#   'its': 8,
#   'may': 4,
#   'more': 3,
#   'no': 4,
#   'not': 13,
#   'of': 101,
#   'on': 16,
#   'one': 4,
#   'or': 10,
#   'other': 6,
#   'people': 17,
#   'power': 5,
#   'state': 2,
#   'than': 1,
#   'that': 21,
#   'the': 178,
#   'their': 14,
#   'them': 7,
#   'they': 5,
#   'this': 5,
#   'those': 1,
#   'to': 58,
#   'we': 4,
#   'which': 20,
#   'will': 1,
#   'with': 11,
#   'would': 22},
#  {'a': 14,
#   'all': 5,
#   'an': 3,
#   'and': 33,
#   'any': 5,
#   'are': 4,
#   'as': 11,
#   'at': 9,
#   'be': 31,
#   'been': 13,
#   'but': 1,
#   'by': 11,
#   'for': 6,
#   'from': 8,
#   'government': 2,
#   'has': 1,
#   'have': 12,
#   'if': 4,
#   'in': 28,
#   'is': 6,
#   'it': 16,
#   'its': 3,
#   'may': 4,
#   'not': 10,
#   'of': 60,
#   'on': 11,
#   'one': 4,
#   'or': 8,
#   'other': 8,
#   'people': 4,
#   'power': 2,
#   'state': 6,
#   'states': 1,
#   'that': 12,
#   'the': 101,
#   'their': 13,
#   'them': 8,
#   'they': 7,
#   'this': 7,
#   'those': 1,
#   'to': 28,
#   'we': 1,
#   'which': 9,
#   'will': 7,
#   'with': 5,
#   'would': 11},
#  {'a': 46,
#   'all': 12,
#   'an': 5,
#   'and': 40,
#   'any': 1,
#   'are': 9,
#   'as': 28,
#   'at': 3,
#   'be': 63,
#   'been': 2,
#   'but': 9,
#   'by': 23,
#   'can': 3,
#   'for': 13,
#   'from': 7,
#   'government': 22,
#   'has': 2,
#   'have': 3,
#   'if': 7,
#   'in': 50,
#   'is': 20,
#   'it': 32,
#   'its': 4,
#   'may': 17,
#   'more': 5,
#   'no': 4,
#   'not': 9,
#   'of': 113,
#   'on': 21,
#   'one': 4,
#   'or': 7,
#   'other': 12,
#   'people': 8,
#   'power': 7,
#   'state': 7,
#   'states': 3,
#   'than': 3,
#   'that': 23,
#   'the': 202,
#   'their': 7,
#   'them': 3,
#   'they': 2,
#   'this': 13,
#   'those': 3,
#   'to': 50,
#   'we': 2,
#   'which': 14,
#   'will': 23,
#   'with': 6,
#   'would': 9},
#  {'a': 35,
#   'all': 3,
#   'an': 3,
#   'and': 37,
#   'any': 7,
#   'are': 8,
#   'as': 16,
#   'at': 7,
#   'be': 46,
#   'been': 16,
#   'but': 6,
#   'by': 22,
#   'can': 7,
#   'for': 13,
#   'from': 12,
#   'government': 10,
#   'has': 3,
#   'have': 19,
#   'if': 5,
#   'in': 33,
#   'is': 19,
#   'it': 32,
#   'its': 6,
#   'may': 7,
#   'more': 7,
#   'no': 4,
#   'not': 11,
#   'of': 101,
#   'on': 19,
#   'one': 4,
#   'or': 7,
#   'other': 8,
#   'people': 13,
#   'power': 3,
#   'state': 9,
#   'states': 9,
#   'that': 30,
#   'the': 186,
#   'their': 9,
#   'them': 4,
#   'they': 5,
#   'this': 15,
#   'those': 4,
#   'to': 72,
#   'we': 5,
#   'which': 21,
#   'will': 10,
#   'with': 11,
#   'would': 8},
#  {'a': 48,
#   'all': 9,
#   'an': 6,
#   'and': 62,
#   'any': 6,
#   'are': 19,
#   'as': 21,
#   'at': 2,
#   'be': 51,
#   'been': 7,
#   'but': 11,
#   'by': 31,
#   'can': 13,
#   'for': 21,
#   'from': 11,
#   'government': 15,
#   'has': 8,
#   'have': 7,
#   'if': 7,
#   'in': 45,
#   'is': 28,
#   'it': 18,
#   'its': 2,
#   'may': 7,
#   'more': 10,
#   'no': 10,
#   'not': 19,
#   'of': 128,
#   'on': 8,
#   'one': 7,
#   'or': 12,
#   'other': 14,
#   'people': 7,
#   'power': 4,
#   'state': 8,
#   'states': 16,
#   'than': 7,
#   'that': 24,
#   'the': 194,
#   'their': 4,
#   'them': 7,
#   'they': 12,
#   'this': 15,
#   'those': 5,
#   'to': 73,
#   'we': 4,
#   'which': 23,
#   'will': 25,
#   'with': 11,
#   'would': 6},
#  {'a': 35,
#   'all': 10,
#   'an': 9,
#   'and': 38,
#   'any': 7,
#   'are': 15,
#   'as': 36,
#   'at': 2,
#   'be': 40,
#   'been': 4,
#   'but': 8,
#   'by': 26,
#   'for': 10,
#   'from': 13,
#   'government': 5,
#   'has': 2,
#   'have': 16,
#   'if': 5,
#   'in': 65,
#   'is': 35,
#   'it': 27,
#   'its': 2,
#   'may': 10,
#   'more': 6,
#   'no': 8,
#   'not': 18,
#   'of': 117,
#   'on': 19,
#   'one': 7,
#   'or': 9,
#   'other': 15,
#   'people': 5,
#   'state': 16,
#   'states': 24,
#   'than': 4,
#   'that': 28,
#   'the': 202,
#   'their': 12,
#   'them': 10,
#   'they': 11,
#   'this': 21,
#   'those': 6,
#   'to': 61,
#   'we': 4,
#   'which': 25,
#   'will': 15,
#   'with': 12,
#   'would': 6},
#  {'a': 48,
#   'all': 5,
#   'an': 4,
#   'and': 48,
#   'any': 8,
#   'are': 13,
#   'as': 12,
#   'at': 17,
#   'be': 52,
#   'been': 6,
#   'but': 5,
#   'by': 14,
#   'can': 8,
#   'for': 17,
#   'from': 12,
#   'government': 4,
#   'has': 5,
#   'have': 6,
#   'if': 5,
#   'in': 30,
#   'is': 25,
#   'it': 17,
#   'may': 11,
#   'more': 11,
#   'no': 4,
#   'not': 14,
#   'of': 122,
#   'on': 9,
#   'one': 9,
#   'or': 20,
#   'other': 11,
#   'people': 9,
#   'power': 4,
#   'state': 7,
#   'states': 8,
#   'than': 15,
#   'that': 32,
#   'the': 182,
#   'their': 16,
#   'them': 4,
#   'they': 16,
#   'this': 12,
#   'to': 78,
#   'we': 6,
#   'which': 29,
#   'will': 20,
#   'with': 11,
#   'would': 10},
#  {'a': 48,
#   'all': 9,
#   'an': 3,
#   'and': 54,
#   'any': 6,
#   'are': 13,
#   'as': 10,
#   'at': 5,
#   'be': 38,
#   'been': 5,
#   'but': 8,
#   'by': 10,
#   'can': 6,
#   'for': 8,
#   'from': 9,
#   'government': 2,
#   'has': 4,
#   'have': 8,
#   'in': 33,
#   'is': 11,
#   'it': 20,
#   'its': 5,
#   'may': 10,
#   'more': 7,
#   'no': 2,
#   'not': 11,
#   'of': 119,
#   'on': 11,
#   'one': 5,
#   'or': 5,
#   'other': 5,
#   'people': 4,
#   'power': 1,
#   'state': 20,
#   'states': 10,
#   'than': 6,
#   'that': 19,
#   'the': 144,
#   'their': 9,
#   'them': 10,
#   'they': 4,
#   'this': 15,
#   'those': 4,
#   'to': 42,
#   'we': 4,
#   'which': 21,
#   'will': 29,
#   'with': 16,
#   'would': 4},
#  {'a': 36,
#   'all': 7,
#   'an': 6,
#   'and': 54,
#   'any': 5,
#   'are': 26,
#   'as': 24,
#   'at': 6,
#   'be': 43,
#   'been': 4,
#   'but': 8,
#   'by': 25,
#   'can': 7,
#   'for': 19,
#   'from': 11,
#   'government': 14,
#   'has': 4,
#   'have': 11,
#   'if': 6,
#   'in': 40,
#   'is': 34,
#   'it': 26,
#   'its': 3,
#   'may': 4,
#   'more': 9,
#   'no': 4,
#   'not': 15,
#   'of': 151,
#   'on': 19,
#   'one': 10,
#   'or': 22,
#   'other': 3,
#   'people': 19,
#   'power': 2,
#   'state': 13,
#   'states': 5,
#   'than': 10,
#   'that': 31,
#   'the': 216,
#   'their': 23,
#   'them': 6,
#   'they': 15,
#   'this': 13,
#   'those': 5,
#   'to': 74,
#   'we': 9,
#   'which': 30,
#   'will': 24,
#   'with': 3,
#   'would': 6},
#  {'a': 51,
#   'all': 14,
#   'an': 9,
#   'and': 47,
#   'any': 5,
#   'are': 7,
#   'as': 21,
#   'at': 5,
#   'be': 52,
#   'been': 14,
#   'but': 7,
#   'by': 22,
#   'can': 5,
#   'for': 13,
#   'from': 10,
#   'government': 9,
#   'has': 11,
#   'have': 18,
#   'if': 6,
#   'in': 58,
#   'is': 17,
#   'it': 24,
#   'its': 7,
#   'may': 10,
#   'more': 13,
#   'no': 5,
#   'not': 14,
#   'of': 117,
#   'on': 18,
#   'one': 5,
#   'or': 11,
#   'other': 9,
#   'people': 10,
#   'power': 3,
#   'state': 6,
#   'states': 17,
#   'than': 5,
#   'that': 32,
#   'the': 213,
#   'their': 13,
#   'them': 5,
#   'they': 10,
#   'this': 14,
#   'those': 4,
#   'to': 61,
#   'we': 4,
#   'which': 27,
#   'will': 37,
#   'with': 13,
#   'would': 12},
#  {'a': 49,
#   'all': 3,
#   'an': 24,
#   'and': 34,
#   'any': 11,
#   'are': 6,
#   'as': 16,
#   'at': 8,
#   'be': 44,
#   'been': 15,
#   'but': 9,
#   'by': 17,
#   'can': 6,
#   'for': 13,
#   'from': 12,
#   'government': 12,
#   'has': 6,
#   'have': 22,
#   'if': 6,
#   'in': 62,
#   'is': 17,
#   'it': 33,
#   'its': 15,
#   'may': 17,
#   'more': 9,
#   'no': 8,
#   'not': 13,
#   'of': 113,
#   'on': 6,
#   'one': 4,
#   'or': 7,
#   'other': 4,
#   'people': 6,
#   'power': 17,
#   'state': 19,
#   'states': 10,
#   'than': 7,
#   'that': 29,
#   'the': 178,
#   'their': 10,
#   'them': 7,
#   'they': 8,
#   'this': 18,
#   'those': 5,
#   'to': 73,
#   'we': 2,
#   'which': 18,
#   'will': 21,
#   'with': 10,
#   'would': 16},
#  {'a': 53,
#   'all': 10,
#   'an': 12,
#   'and': 37,
#   'any': 12,
#   'are': 12,
#   'as': 22,
#   'at': 9,
#   'be': 66,
#   'been': 2,
#   'but': 9,
#   'by': 21,
#   'can': 4,
#   'for': 13,
#   'from': 12,
#   'government': 10,
#   'has': 3,
#   'have': 8,
#   'if': 6,
#   'in': 81,
#   'is': 28,
#   'it': 42,
#   'its': 11,
#   'may': 10,
#   'more': 4,
#   'no': 4,
#   'not': 13,
#   'of': 145,
#   'on': 6,
#   'one': 6,
#   'or': 19,
#   'other': 8,
#   'people': 9,
#   'power': 4,
#   'state': 14,
#   'states': 4,
#   'than': 7,
#   'that': 46,
#   'the': 224,
#   'their': 14,
#   'them': 10,
#   'they': 13,
#   'this': 17,
#   'those': 8,
#   'to': 87,
#   'we': 4,
#   'which': 16,
#   'will': 21,
#   'with': 7,
#   'would': 28},
#  {'a': 35,
#   'all': 2,
#   'an': 5,
#   'and': 25,
#   'any': 5,
#   'are': 9,
#   'as': 18,
#   'at': 12,
#   'be': 37,
#   'been': 9,
#   'but': 3,
#   'by': 5,
#   'can': 6,
#   'for': 17,
#   'from': 8,
#   'government': 2,
#   'have': 12,
#   'if': 7,
#   'in': 47,
#   'is': 10,
#   'it': 25,
#   'its': 3,
#   'may': 11,
#   'more': 4,
#   'no': 5,
#   'not': 8,
#   'of': 100,
#   'on': 6,
#   'one': 3,
#   'or': 8,
#   'other': 8,
#   'people': 5,
#   'power': 6,
#   'state': 13,
#   'states': 6,
#   'than': 12,
#   'that': 32,
#   'the': 151,
#   'their': 5,
#   'them': 2,
#   'they': 11,
#   'this': 14,
#   'those': 4,
#   'to': 61,
#   'we': 2,
#   'which': 12,
#   'will': 7,
#   'with': 7,
#   'would': 17},
#  {'a': 75,
#   'all': 11,
#   'an': 13,
#   'and': 69,
#   'any': 6,
#   'are': 15,
#   'as': 16,
#   'at': 5,
#   'be': 61,
#   'been': 4,
#   'but': 12,
#   'by': 28,
#   'can': 9,
#   'for': 16,
#   'from': 21,
#   'government': 19,
#   'has': 3,
#   'have': 7,
#   'if': 5,
#   'in': 50,
#   'is': 37,
#   'it': 31,
#   'its': 3,
#   'may': 17,
#   'more': 13,
#   'no': 9,
#   'not': 17,
#   'of': 145,
#   'on': 19,
#   'one': 6,
#   'or': 12,
#   'other': 6,
#   'people': 10,
#   'power': 2,
#   'state': 6,
#   'states': 15,
#   'than': 7,
#   'that': 35,
#   'the': 192,
#   'their': 13,
#   'them': 5,
#   'they': 8,
#   'this': 17,
#   'those': 5,
#   'to': 80,
#   'which': 32,
#   'will': 17,
#   'with': 13,
#   'would': 5},
#  {'a': 58,
#   'all': 10,
#   'an': 18,
#   'and': 68,
#   'any': 8,
#   'are': 12,
#   'as': 30,
#   'at': 12,
#   'be': 60,
#   'been': 11,
#   'but': 13,
#   'by': 51,
#   'can': 14,
#   'for': 26,
#   'from': 16,
#   'government': 9,
#   'has': 5,
#   'have': 21,
#   'if': 8,
#   'in': 68,
#   'is': 36,
#   'it': 40,
#   'its': 17,
#   'may': 18,
#   'more': 4,
#   'no': 6,
#   'not': 26,
#   'of': 176,
#   'on': 20,
#   'one': 9,
#   'or': 16,
#   'other': 11,
#   'people': 42,
#   'power': 7,
#   'state': 6,
#   'states': 5,
#   'than': 8,
#   'that': 50,
#   'the': 290,
#   'their': 16,
#   'them': 5,
#   'they': 6,
#   'this': 17,
#   'those': 5,
#   'to': 88,
#   'we': 6,
#   'which': 36,
#   'will': 19,
#   'with': 16,
#   'would': 11},
#  {'a': 32,
#   'all': 8,
#   'an': 6,
#   'and': 103,
#   'any': 8,
#   'are': 25,
#   'as': 39,
#   'at': 5,
#   'be': 57,
#   'been': 4,
#   'but': 12,
#   'by': 30,
#   'can': 8,
#   'for': 14,
#   'from': 12,
#   'government': 2,
#   'has': 5,
#   'have': 19,
#   'if': 8,
#   'in': 53,
#   'is': 17,
#   'it': 30,
#   'may': 12,
#   'more': 4,
#   'no': 4,
#   'not': 20,
#   'of': 99,
#   'on': 14,
#   'one': 4,
#   'or': 14,
#   'other': 4,
#   'people': 6,
#   'power': 12,
#   'state': 3,
#   'states': 4,
#   'than': 2,
#   'that': 46,
#   'the': 174,
#   'their': 21,
#   'them': 12,
#   'they': 32,
#   'this': 11,
#   'those': 15,
#   'to': 88,
#   'we': 5,
#   'which': 14,
#   'will': 25,
#   'with': 14,
#   'would': 7},
#  {'a': 44,
#   'all': 4,
#   'an': 11,
#   'and': 37,
#   'any': 3,
#   'are': 8,
#   'as': 18,
#   'at': 6,
#   'be': 65,
#   'been': 12,
#   'but': 5,
#   'by': 16,
#   'can': 5,
#   'for': 16,
#   'from': 12,
#   'government': 7,
#   'has': 1,
#   'have': 17,
#   'if': 3,
#   'in': 51,
#   'is': 17,
#   'it': 33,
#   'its': 4,
#   'may': 7,
#   'more': 7,
#   'no': 3,
#   'not': 18,
#   'of': 131,
#   'on': 5,
#   'one': 6,
#   'or': 18,
#   'other': 8,
#   'people': 3,
#   'power': 1,
#   'state': 4,
#   'than': 5,
#   'that': 24,
#   'the': 220,
#   'their': 5,
#   'them': 5,
#   'they': 6,
#   'this': 18,
#   'those': 6,
#   'to': 85,
#   'we': 1,
#   'which': 24,
#   'will': 29,
#   'with': 12,
#   'would': 25},
#  {'a': 48,
#   'all': 8,
#   'an': 12,
#   'and': 42,
#   'any': 7,
#   'are': 4,
#   'as': 20,
#   'at': 1,
#   'be': 39,
#   'been': 10,
#   'but': 7,
#   'by': 13,
#   'can': 3,
#   'for': 16,
#   'from': 11,
#   'government': 5,
#   'has': 11,
#   'have': 13,
#   'if': 16,
#   'in': 71,
#   'is': 29,
#   'it': 35,
#   'its': 4,
#   'may': 8,
#   'more': 12,
#   'no': 5,
#   'not': 22,
#   'of': 168,
#   'on': 7,
#   'one': 5,
#   'or': 12,
#   'other': 8,
#   'people': 2,
#   'power': 9,
#   'state': 4,
#   'states': 1,
#   'than': 7,
#   'that': 36,
#   'the': 251,
#   'their': 14,
#   'them': 10,
#   'they': 16,
#   'this': 21,
#   'those': 6,
#   'to': 84,
#   'we': 5,
#   'which': 15,
#   'will': 23,
#   'with': 23,
#   'would': 10},
#  {'a': 24,
#   'all': 5,
#   'an': 8,
#   'and': 46,
#   'any': 3,
#   'are': 7,
#   'as': 15,
#   'at': 5,
#   'be': 18,
#   'been': 17,
#   'but': 5,
#   'by': 14,
#   'can': 3,
#   'for': 11,
#   'from': 5,
#   'government': 2,
#   'has': 12,
#   'have': 21,
#   'if': 4,
#   'in': 36,
#   'is': 18,
#   'it': 20,
#   'its': 3,
#   'may': 3,
#   'more': 3,
#   'no': 4,
#   'not': 13,
#   'of': 110,
#   'on': 3,
#   'one': 3,
#   'or': 5,
#   'other': 4,
#   'people': 4,
#   'power': 11,
#   'state': 6,
#   'states': 9,
#   'than': 5,
#   'that': 16,
#   'the': 183,
#   'their': 5,
#   'they': 4,
#   'this': 12,
#   'those': 4,
#   'to': 84,
#   'we': 2,
#   'which': 26,
#   'will': 3,
#   'with': 12,
#   'would': 5},
#  {'a': 30,
#   'all': 9,
#   'an': 9,
#   'and': 30,
#   'any': 8,
#   'are': 4,
#   'as': 17,
#   'at': 6,
#   'be': 36,
#   'been': 5,
#   'but': 9,
#   'by': 12,
#   'can': 1,
#   'for': 17,
#   'from': 11,
#   'government': 7,
#   'has': 6,
#   'have': 14,
#   'if': 4,
#   'in': 40,
#   'is': 19,
#   'it': 20,
#   'its': 3,
#   'may': 5,
#   'more': 2,
#   'no': 3,
#   'not': 11,
#   'of': 88,
#   'on': 3,
#   'one': 7,
#   'or': 6,
#   'other': 5,
#   'people': 9,
#   'state': 10,
#   'states': 5,
#   'than': 6,
#   'that': 19,
#   'the': 142,
#   'their': 12,
#   'them': 4,
#   'they': 8,
#   'this': 13,
#   'those': 4,
#   'to': 76,
#   'we': 3,
#   'which': 15,
#   'will': 13,
#   'with': 8,
#   'would': 7},
#  {'a': 66,
#   'all': 17,
#   'an': 14,
#   'and': 104,
#   'any': 6,
#   'are': 5,
#   'as': 16,
#   'at': 6,
#   'be': 51,
#   'been': 8,
#   'but': 10,
#   'by': 22,
#   'can': 18,
#   'for': 18,
#   'from': 12,
#   'government': 7,
#   'has': 12,
#   'have': 17,
#   'if': 12,
#   'in': 69,
#   'is': 53,
#   'it': 30,
#   'its': 7,
#   'may': 10,
#   'more': 7,
#   'no': 10,
#   'not': 11,
#   'of': 233,
#   'on': 6,
#   'one': 11,
#   'or': 14,
#   'other': 20,
#   'people': 4,
#   'power': 21,
#   'state': 10,
#   'states': 16,
#   'than': 12,
#   'that': 46,
#   'the': 320,
#   'their': 6,
#   'them': 7,
#   'they': 1,
#   'this': 32,
#   'those': 5,
#   'to': 102,
#   'we': 9,
#   'which': 20,
#   'will': 6,
#   'with': 19,
#   'would': 27},
#  {'a': 72,
#   'all': 7,
#   'an': 20,
#   'and': 84,
#   'any': 16,
#   'are': 23,
#   'as': 26,
#   'at': 12,
#   'be': 39,
#   'been': 17,
#   'but': 17,
#   'by': 15,
#   'can': 5,
#   'for': 24,
#   'from': 19,
#   'government': 13,
#   'has': 11,
#   'have': 32,
#   'if': 10,
#   'in': 95,
#   'is': 55,
#   'it': 42,
#   'its': 8,
#   'may': 21,
#   'more': 18,
#   'no': 10,
#   'not': 15,
#   'of': 195,
#   'on': 15,
#   'one': 10,
#   'or': 25,
#   'other': 3,
#   'people': 6,
#   'power': 8,
#   'state': 7,
#   'states': 3,
#   'than': 15,
#   'that': 37,
#   'the': 305,
#   'their': 22,
#   'them': 6,
#   'they': 30,
#   'this': 16,
#   'those': 9,
#   'to': 132,
#   'we': 7,
#   'which': 30,
#   'will': 12,
#   'with': 20,
#   'would': 11},
#  {'a': 45,
#   'all': 2,
#   'an': 9,
#   'and': 39,
#   'any': 7,
#   'are': 5,
#   'as': 17,
#   'at': 8,
#   'be': 38,
#   'been': 5,
#   'but': 6,
#   'by': 15,
#   'can': 2,
#   'for': 10,
#   'from': 15,
#   'government': 5,
#   'has': 5,
#   'have': 9,
#   'if': 9,
#   'in': 39,
#   'is': 14,
#   'it': 30,
#   'its': 3,
#   'may': 10,
#   'more': 6,
#   'no': 1,
#   'not': 7,
#   'of': 100,
#   'on': 7,
#   'one': 8,
#   'or': 17,
#   'other': 11,
#   'people': 12,
#   'power': 4,
#   'state': 2,
#   'states': 1,
#   'than': 5,
#   'that': 22,
#   'the': 180,
#   'their': 14,
#   'them': 3,
#   'they': 17,
#   'this': 8,
#   'those': 3,
#   'to': 78,
#   'we': 2,
#   'which': 19,
#   'will': 7,
#   'with': 14,
#   'would': 16},
#  {'a': 55,
#   'all': 4,
#   'an': 12,
#   'and': 52,
#   'any': 2,
#   'are': 7,
#   'as': 16,
#   'at': 12,
#   'be': 41,
#   'been': 4,
#   'but': 5,
#   'by': 17,
#   'can': 2,
#   'for': 14,
#   'from': 14,
#   'government': 5,
#   'has': 5,
#   'have': 7,
#   'if': 5,
#   'in': 35,
#   'is': 24,
#   'it': 22,
#   'its': 7,
#   'may': 9,
#   'more': 10,
#   'no': 6,
#   'not': 13,
#   'of': 120,
#   'on': 6,
#   'one': 4,
#   'or': 16,
#   'other': 2,
#   'people': 8,
#   'power': 2,
#   'state': 2,
#   'than': 7,
#   'that': 19,
#   'the': 178,
#   'their': 12,
#   'them': 5,
#   'they': 10,
#   'this': 10,
#   'those': 1,
#   'to': 99,
#   'we': 3,
#   'which': 20,
#   'will': 7,
#   'with': 10,
#   'would': 25},
#  {'a': 64,
#   'all': 8,
#   'an': 9,
#   'and': 42,
#   'any': 12,
#   'are': 8,
#   'as': 11,
#   'at': 10,
#   'be': 49,
#   'been': 15,
#   'but': 10,
#   'by': 27,
#   'can': 3,
#   'for': 14,
#   'from': 13,
#   'government': 4,
#   'has': 14,
#   'have': 15,
#   'if': 5,
#   'in': 62,
#   'is': 29,
#   'it': 43,
#   'its': 9,
#   'may': 12,
#   'more': 10,
#   'no': 5,
#   'not': 13,
#   'of': 143,
#   'on': 5,
#   'one': 8,
#   'or': 24,
#   'other': 12,
#   'people': 1,
#   'power': 17,
#   'state': 4,
#   'states': 4,
#   'than': 14,
#   'that': 40,
#   'the': 207,
#   'their': 8,
#   'them': 5,
#   'they': 14,
#   'this': 27,
#   'those': 6,
#   'to': 83,
#   'which': 20,
#   'will': 19,
#   'with': 15,
#   'would': 29},
#  {'a': 27,
#   'all': 1,
#   'an': 7,
#   'and': 23,
#   'any': 3,
#   'are': 3,
#   'as': 10,
#   'at': 2,
#   'be': 24,
#   'been': 2,
#   'but': 2,
#   'by': 2,
#   'for': 9,
#   'from': 3,
#   'government': 2,
#   'has': 2,
#   'have': 5,
#   'if': 3,
#   'in': 24,
#   'is': 11,
#   'it': 14,
#   'its': 3,
#   'may': 7,
#   'more': 1,
#   'not': 4,
#   'of': 83,
#   'on': 4,
#   'one': 3,
#   'or': 12,
#   'other': 4,
#   'people': 2,
#   'power': 6,
#   'state': 2,
#   'states': 5,
#   'than': 2,
#   'that': 13,
#   'the': 104,
#   'their': 2,
#   'them': 1,
#   'they': 2,
#   'this': 8,
#   'those': 3,
#   'to': 36,
#   'we': 1,
#   'which': 11,
#   'will': 1,
#   'with': 4,
#   'would': 9},
#  {'a': 52,
#   'all': 7,
#   'an': 12,
#   'and': 36,
#   'any': 2,
#   'are': 7,
#   'as': 17,
#   'at': 2,
#   'be': 28,
#   'been': 10,
#   'but': 5,
#   'by': 16,
#   'for': 7,
#   'from': 10,
#   'government': 3,
#   'has': 7,
#   'have': 16,
#   'if': 3,
#   'in': 44,
#   'is': 17,
#   'it': 27,
#   'its': 7,
#   'may': 5,
#   'more': 4,
#   'no': 2,
#   'not': 12,
#   'of': 149,
#   'on': 5,
#   'one': 5,
#   'or': 9,
#   'other': 4,
#   'people': 4,
#   'power': 13,
#   'state': 4,
#   'states': 3,
#   'than': 8,
#   'that': 35,
#   'the': 208,
#   'their': 2,
#   'them': 5,
#   'they': 3,
#   'this': 14,
#   'those': 4,
#   'to': 91,
#   'we': 7,
#   'which': 17,
#   'will': 6,
#   'with': 15,
#   'would': 27},
#  {'a': 48,
#   'all': 4,
#   'an': 13,
#   'and': 48,
#   'any': 5,
#   'are': 3,
#   'as': 15,
#   'at': 4,
#   'be': 58,
#   'been': 8,
#   'but': 6,
#   'by': 20,
#   'can': 1,
#   'for': 9,
#   'from': 10,
#   'government': 2,
#   'has': 5,
#   'have': 16,
#   'if': 2,
#   'in': 50,
#   'is': 20,
#   'it': 26,
#   'its': 6,
#   'may': 7,
#   'more': 5,
#   'no': 5,
#   'not': 14,
#   'of': 116,
#   'on': 4,
#   'one': 8,
#   'or': 23,
#   'other': 9,
#   'people': 3,
#   'power': 8,
#   'state': 3,
#   'states': 4,
#   'than': 7,
#   'that': 34,
#   'the': 169,
#   'their': 7,
#   'them': 4,
#   'they': 8,
#   'this': 14,
#   'those': 4,
#   'to': 83,
#   'we': 2,
#   'which': 16,
#   'will': 20,
#   'with': 7,
#   'would': 23},
#  {'a': 62,
#   'all': 10,
#   'an': 19,
#   'and': 41,
#   'any': 6,
#   'are': 6,
#   'as': 18,
#   'at': 6,
#   'be': 38,
#   'been': 9,
#   'but': 4,
#   'by': 16,
#   'can': 8,
#   'for': 19,
#   'from': 13,
#   'government': 5,
#   'has': 9,
#   'have': 13,
#   'if': 6,
#   'in': 61,
#   'is': 21,
#   'it': 29,
#   'its': 6,
#   'may': 2,
#   'more': 7,
#   'no': 2,
#   'not': 6,
#   'of': 145,
#   'on': 3,
#   'one': 4,
#   'or': 9,
#   'other': 5,
#   'people': 4,
#   'power': 13,
#   'state': 6,
#   'states': 3,
#   'than': 6,
#   'that': 32,
#   'the': 183,
#   'their': 12,
#   'them': 5,
#   'they': 5,
#   'this': 18,
#   'those': 1,
#   'to': 72,
#   'we': 2,
#   'which': 15,
#   'will': 10,
#   'with': 6,
#   'would': 32},
#  {'a': 58,
#   'all': 7,
#   'an': 16,
#   'and': 74,
#   'any': 9,
#   'are': 13,
#   'as': 30,
#   'at': 3,
#   'be': 66,
#   'been': 9,
#   'but': 16,
#   'by': 25,
#   'can': 18,
#   'for': 15,
#   'from': 27,
#   'government': 9,
#   'has': 6,
#   'have': 19,
#   'if': 10,
#   'in': 68,
#   'is': 49,
#   'it': 54,
#   'its': 13,
#   'may': 16,
#   'more': 4,
#   'no': 18,
#   'not': 18,
#   'of': 188,
#   'on': 10,
#   'one': 7,
#   'or': 19,
#   'other': 13,
#   'people': 14,
#   'power': 7,
#   'state': 3,
#   'states': 2,
#   'than': 10,
#   'that': 68,
#   'the': 313,
#   'their': 32,
#   'them': 11,
#   'they': 20,
#   'this': 26,
#   'those': 10,
#   'to': 128,
#   'we': 2,
#   'which': 33,
#   'will': 14,
#   'with': 12,
#   'would': 19},
#  {'a': 23,
#   'all': 2,
#   'an': 2,
#   'and': 24,
#   'any': 8,
#   'are': 6,
#   'as': 5,
#   'at': 5,
#   'be': 30,
#   'been': 5,
#   'but': 3,
#   'by': 4,
#   'can': 7,
#   'for': 15,
#   'from': 7,
#   'government': 2,
#   'has': 8,
#   'have': 6,
#   'if': 2,
#   'in': 35,
#   'is': 11,
#   'it': 13,
#   'its': 2,
#   'may': 6,
#   'more': 5,
#   'no': 4,
#   'not': 8,
#   'of': 55,
#   'on': 5,
#   'one': 1,
#   'or': 4,
#   'other': 2,
#   'people': 1,
#   'power': 4,
#   'state': 4,
#   'states': 2,
#   'than': 7,
#   'that': 19,
#   'the': 89,
#   'their': 12,
#   'them': 1,
#   'they': 4,
#   'this': 8,
#   'to': 42,
#   'we': 4,
#   'which': 12,
#   'will': 7,
#   'with': 4,
#   'would': 5},
#  {'a': 38,
#   'all': 19,
#   'an': 8,
#   'and': 68,
#   'any': 7,
#   'are': 21,
#   'as': 20,
#   'at': 3,
#   'be': 48,
#   'been': 14,
#   'but': 4,
#   'by': 13,
#   'can': 5,
#   'for': 12,
#   'from': 7,
#   'government': 6,
#   'has': 6,
#   'have': 19,
#   'if': 5,
#   'in': 47,
#   'is': 23,
#   'it': 31,
#   'its': 10,
#   'may': 14,
#   'more': 2,
#   'no': 7,
#   'not': 15,
#   'of': 169,
#   'on': 9,
#   'one': 5,
#   'or': 22,
#   'other': 7,
#   'people': 1,
#   'power': 4,
#   'state': 23,
#   'states': 38,
#   'than': 4,
#   'that': 25,
#   'the': 255,
#   'their': 6,
#   'them': 6,
#   'they': 8,
#   'this': 14,
#   'those': 15,
#   'to': 114,
#   'we': 2,
#   'which': 44,
#   'will': 16,
#   'with': 11,
#   'would': 10},
#  {'a': 87,
#   'all': 13,
#   'an': 22,
#   'and': 88,
#   'any': 15,
#   'are': 15,
#   'as': 46,
#   'at': 7,
#   'be': 85,
#   'been': 22,
#   'but': 20,
#   'by': 32,
#   'can': 6,
#   'for': 21,
#   'from': 20,
#   'government': 7,
#   'has': 12,
#   'have': 23,
#   'if': 6,
#   'in': 135,
#   'is': 61,
#   'it': 64,
#   'its': 10,
#   'may': 25,
#   'more': 4,
#   'no': 8,
#   'not': 26,
#   'of': 248,
#   'on': 16,
#   'one': 10,
#   'or': 21,
#   'other': 6,
#   'people': 1,
#   'power': 20,
#   'state': 26,
#   'states': 18,
#   'than': 6,
#   'that': 49,
#   'the': 389,
#   'their': 11,
#   'them': 16,
#   'they': 11,
#   'this': 44,
#   'those': 12,
#   'to': 163,
#   'we': 2,
#   'which': 41,
#   'will': 30,
#   'with': 14,
#   'would': 21},
#  {'a': 22,
#   'all': 7,
#   'an': 10,
#   'and': 41,
#   'any': 1,
#   'are': 11,
#   'as': 15,
#   'at': 2,
#   'be': 36,
#   'been': 1,
#   'but': 4,
#   'by': 4,
#   'can': 5,
#   'for': 4,
#   'from': 14,
#   'government': 3,
#   'have': 7,
#   'if': 2,
#   'in': 38,
#   'is': 15,
#   'it': 13,
#   'its': 4,
#   'may': 14,
#   'more': 1,
#   'no': 4,
#   'not': 13,
#   'of': 94,
#   'one': 9,
#   'or': 13,
#   'other': 2,
#   'people': 1,
#   'power': 10,
#   'state': 18,
#   'states': 8,
#   'than': 3,
#   'that': 19,
#   'the': 168,
#   'their': 6,
#   'them': 4,
#   'they': 10,
#   'this': 14,
#   'those': 6,
#   'to': 83,
#   'we': 2,
#   'which': 18,
#   'will': 7,
#   'with': 6,
#   'would': 11},
#  {'a': 139,
#   'all': 28,
#   'an': 20,
#   'and': 120,
#   'any': 16,
#   'are': 43,
#   'as': 54,
#   'at': 19,
#   'be': 105,
#   'been': 36,
#   'but': 25,
#   'by': 82,
#   'can': 6,
#   'for': 39,
#   'from': 22,
#   'government': 16,
#   'has': 22,
#   'have': 54,
#   'if': 24,
#   'in': 213,
#   'is': 116,
#   'it': 102,
#   'its': 21,
#   'may': 16,
#   'more': 23,
#   'no': 22,
#   'not': 36,
#   'of': 331,
#   'on': 18,
#   'one': 18,
#   'or': 26,
#   'other': 21,
#   'people': 3,
#   'power': 10,
#   'state': 33,
#   'states': 23,
#   'than': 16,
#   'that': 120,
#   'the': 485,
#   'their': 16,
#   'them': 21,
#   'they': 29,
#   'this': 60,
#   'those': 13,
#   'to': 219,
#   'we': 5,
#   'which': 79,
#   'will': 24,
#   'with': 30,
#   'would': 48},
#  {'a': 71,
#   'all': 14,
#   'an': 15,
#   'and': 89,
#   'any': 32,
#   'are': 33,
#   'as': 35,
#   'at': 10,
#   'be': 94,
#   'been': 18,
#   'but': 18,
#   'by': 31,
#   'can': 11,
#   'for': 27,
#   'from': 20,
#   'government': 22,
#   'has': 19,
#   'have': 27,
#   'if': 8,
#   'in': 91,
#   'is': 68,
#   'it': 64,
#   'its': 7,
#   'may': 26,
#   'more': 7,
#   'no': 25,
#   'not': 30,
#   'of': 293,
#   'on': 21,
#   'one': 5,
#   'or': 21,
#   'other': 10,
#   'people': 11,
#   'power': 13,
#   'state': 27,
#   'states': 19,
#   'than': 16,
#   'that': 84,
#   'the': 387,
#   'their': 29,
#   'them': 5,
#   'they': 22,
#   'this': 36,
#   'those': 9,
#   'to': 140,
#   'we': 11,
#   'which': 53,
#   'will': 38,
#   'with': 14,
#   'would': 18},
#  {'a': 68,
#   'all': 13,
#   'an': 20,
#   'and': 73,
#   'any': 12,
#   'are': 13,
#   'as': 20,
#   'at': 6,
#   'be': 34,
#   'been': 17,
#   'but': 7,
#   'by': 11,
#   'can': 10,
#   'for': 12,
#   'from': 9,
#   'government': 10,
#   'has': 15,
#   'have': 23,
#   'if': 4,
#   'in': 73,
#   'is': 38,
#   'it': 41,
#   'its': 6,
#   'may': 16,
#   'more': 5,
#   'no': 13,
#   'not': 20,
#   'of': 172,
#   'on': 18,
#   'one': 8,
#   'or': 12,
#   'other': 3,
#   'people': 7,
#   'state': 11,
#   'states': 16,
#   'than': 5,
#   'that': 34,
#   'the': 246,
#   'their': 7,
#   'them': 1,
#   'they': 9,
#   'this': 13,
#   'those': 9,
#   'to': 115,
#   'we': 4,
#   'which': 42,
#   'will': 16,
#   'with': 8,
#   'would': 6}]

# %%
len(allPgs)
# Out:
# 85

# %%
top50 = pd.DataFrame(allPgs)
top50.index = np.arange(1, len(top50) + 1)
top50
# Out:
#       a  all  an  and   any  are  as  at   be  been  ...    them  they  this  \
# 1    25    9  11   40   6.0   12  10   8   34   3.0  ...     2.0     6    14
# 2    29    4   1   83   1.0    6  16  10   15   8.0  ...     4.0    22    14
# 3    13    4   3   60   5.0    8  24   1   31   2.0  ...     8.0     5     6
# 4    16    4   3   90   5.0   11  20   2   26   2.0  ...    12.0    17     1
# 5     9    4   4   72   3.0    3   3   4   31   NaN  ...    11.0    11     6
# 6    52    6  12   81   NaN   18  19   6   18  13.0  ...     3.0    13    11
# 7    48   12  15   51   7.0    7  19  11   47   8.0  ...    12.0     7    22
# 8    45    9  13   54   2.0   14  16  11   35  16.0  ...    11.0    13    19
# 9    47    8  13   45   4.0   14  19  10   26  15.0  ...     5.0    20    15
# 10   78    4  14  121   4.0   27  20   8   61   9.0  ...     8.0    11    11
# 11   69   13  15   70   4.0    9  21  11   44   3.0  ...     6.0    10    24
# 12   47    5  11   62   7.0   15  19  13   40   8.0  ...     6.0     8    17
# 13   26    3   3   17   3.0    4   8   1   25   2.0  ...     1.0     3     5
# 14   37    6   9   60   3.0    7  24   7   45   9.0  ...     4.0    17    13
# 15   69   21  18   74   3.0   22  15  24   44  14.0  ...     4.0    15    24
# 16   37    9  13   42  11.0    3  19  11   55   7.0  ...     6.0    15    18
# 17   30   12   9   52   2.0    5   3   7   24   3.0  ...     8.0     7    11
# 18   37    8   5   79   2.0    2  14   4    6   4.0  ...     2.0    12    17
# 19   27    5   9   82   6.0   17  10   5   14   4.0  ...     7.0     9    12
# 20   28    7   5   54   NaN   13  12   8    7   1.0  ...     5.0     7     8
# 21   64    3  10   49   6.0    8  18   4   40  11.0  ...     3.0     7    17
# 22   98   12  19   83   7.0   18  26  12   54  16.0  ...     3.0    15    31
# 23   24   10  11   56   9.0   18  22   3   45   6.0  ...     6.0     4    14
# 24   51    8   9   59   6.0   10  13   7   52   4.0  ...     5.0     5    23
# 25   44    7   7   46   4.0   14  24  11   52   6.0  ...     8.0     9    20
# 26   53    8  22   49  10.0    6  18  12   54   8.0  ...     2.0    12    15
# 27   30    4   5   33   8.0   10  11   4   34   6.0  ...     2.0     5     9
# 28   33   15  13   35   2.0    6  10   7   41   4.0  ...     5.0     8     7
# 29   50    4  14   59   6.0   10  26  11   50   6.0  ...    12.0     7    14
# 30   38    5   7   45   8.0    7  22   6   49  10.0  ...     2.0    10    17
# ..  ...  ...  ..  ...   ...  ...  ..  ..  ...   ...  ...     ...   ...   ...
# 56   48    9   3   54   6.0   13  10   5   38   5.0  ...    10.0     4    15
# 57   36    7   6   54   5.0   26  24   6   43   4.0  ...     6.0    15    13
# 58   51   14   9   47   5.0    7  21   5   52  14.0  ...     5.0    10    14
# 59   49    3  24   34  11.0    6  16   8   44  15.0  ...     7.0     8    18
# 60   53   10  12   37  12.0   12  22   9   66   2.0  ...    10.0    13    17
# 61   35    2   5   25   5.0    9  18  12   37   9.0  ...     2.0    11    14
# 62   75   11  13   69   6.0   15  16   5   61   4.0  ...     5.0     8    17
# 63   58   10  18   68   8.0   12  30  12   60  11.0  ...     5.0     6    17
# 64   32    8   6  103   8.0   25  39   5   57   4.0  ...    12.0    32    11
# 65   44    4  11   37   3.0    8  18   6   65  12.0  ...     5.0     6    18
# 66   48    8  12   42   7.0    4  20   1   39  10.0  ...    10.0    16    21
# 67   24    5   8   46   3.0    7  15   5   18  17.0  ...     NaN     4    12
# 68   30    9   9   30   8.0    4  17   6   36   5.0  ...     4.0     8    13
# 69   66   17  14  104   6.0    5  16   6   51   8.0  ...     7.0     1    32
# 70   72    7  20   84  16.0   23  26  12   39  17.0  ...     6.0    30    16
# 71   45    2   9   39   7.0    5  17   8   38   5.0  ...     3.0    17     8
# 72   55    4  12   52   2.0    7  16  12   41   4.0  ...     5.0    10    10
# 73   64    8   9   42  12.0    8  11  10   49  15.0  ...     5.0    14    27
# 74   27    1   7   23   3.0    3  10   2   24   2.0  ...     1.0     2     8
# 75   52    7  12   36   2.0    7  17   2   28  10.0  ...     5.0     3    14
# 76   48    4  13   48   5.0    3  15   4   58   8.0  ...     4.0     8    14
# 77   62   10  19   41   6.0    6  18   6   38   9.0  ...     5.0     5    18
# 78   58    7  16   74   9.0   13  30   3   66   9.0  ...    11.0    20    26
# 79   23    2   2   24   8.0    6   5   5   30   5.0  ...     1.0     4     8
# 80   38   19   8   68   7.0   21  20   3   48  14.0  ...     6.0     8    14
# 81   87   13  22   88  15.0   15  46   7   85  22.0  ...    16.0    11    44
# 82   22    7  10   41   1.0   11  15   2   36   1.0  ...     4.0    10    14
# 83  139   28  20  120  16.0   43  54  19  105  36.0  ...    21.0    29    60
# 84   71   14  15   89  32.0   33  35  10   94  18.0  ...     5.0    22    36
# 85   68   13  20   73  12.0   13  20   6   34  17.0  ...     1.0     9    13
#
#     those   to    we  which  will  with  would
# 1     9.0   72   8.0     18    25     6      2
# 2     2.0   53   5.0     11     2    13      5
# 3     6.0   56   NaN     11    24    10      2
# 4     4.0   51  10.0     10    15    12     17
# 5     9.0   45   5.0     10     6    11     37
# 6     7.0   61   5.0     24     6    15      6
# 7     8.0   82  16.0     24     1    12     51
# 8     6.0   80   5.0     26    11    13     27
# 9     6.0   71   6.0     25     7    14      8
# 10    4.0  100   9.0     39    30    11      6
# 11    7.0   83  12.0     25    17    22     50
# 12    3.0   82   5.0     23    11    18     22
# 13    NaN   43  11.0     11     9    10     14
# 14   13.0   72   8.0     40    26     7      5
# 15   10.0  117  24.0     55    19    19     13
# 16   10.0   89   4.0     22     5    13     36
# 17    9.0   58   1.0     24    12    10     12
# 18    5.0   54   3.0     12     1    12      6
# 19    NaN   59   1.0     31     1    21      4
# 20    1.0   42   2.0     13     4     8      1
# 21    9.0   55   9.0     20     6    15     12
# 22   13.0  145  14.0     36    11    20     20
# 23    4.0   97  11.0     31    15    16      4
# 24    2.0   91   4.0     15     8     5     25
# 25    6.0   90   8.0     15    10     8     21
# 26    5.0   95  11.0     21    11     9     16
# 27    4.0   63   6.0     19    34     6      3
# 28    4.0   66   4.0     14    13     9     12
# 29    4.0  112   5.0     16    11    12     19
# 30    5.0   76   5.0     20    11    12     22
# ..    ...  ...   ...    ...   ...   ...    ...
# 56    4.0   42   4.0     21    29    16      4
# 57    5.0   74   9.0     30    24     3      6
# 58    4.0   61   4.0     27    37    13     12
# 59    5.0   73   2.0     18    21    10     16
# 60    8.0   87   4.0     16    21     7     28
# 61    4.0   61   2.0     12     7     7     17
# 62    5.0   80   NaN     32    17    13      5
# 63    5.0   88   6.0     36    19    16     11
# 64   15.0   88   5.0     14    25    14      7
# 65    6.0   85   1.0     24    29    12     25
# 66    6.0   84   5.0     15    23    23     10
# 67    4.0   84   2.0     26     3    12      5
# 68    4.0   76   3.0     15    13     8      7
# 69    5.0  102   9.0     20     6    19     27
# 70    9.0  132   7.0     30    12    20     11
# 71    3.0   78   2.0     19     7    14     16
# 72    1.0   99   3.0     20     7    10     25
# 73    6.0   83   NaN     20    19    15     29
# 74    3.0   36   1.0     11     1     4      9
# 75    4.0   91   7.0     17     6    15     27
# 76    4.0   83   2.0     16    20     7     23
# 77    1.0   72   2.0     15    10     6     32
# 78   10.0  128   2.0     33    14    12     19
# 79    NaN   42   4.0     12     7     4      5
# 80   15.0  114   2.0     44    16    11     10
# 81   12.0  163   2.0     41    30    14     21
# 82    6.0   83   2.0     18     7     6     11
# 83   13.0  219   5.0     79    24    30     48
# 84    9.0  140  11.0     53    38    14     18
# 85    9.0  115   4.0     42    16     8      6
#
# [85 rows x 50 columns]

# %% [markdown]
# ### Grader's Comments
#
# -
# -
#
# [This question is worth 10 points.]

# %%
# This cell should only be modified only by a grader.
# paper given is compared against all other papers
scores.append(0)

# %% [markdown]
# ## Question 2
#
# Implement a function `calc_cosine_similarity` that calculates the cosine similarity between a vector (representing the counts of the 50 most common words in a document) and each document in the _Federalist Papers_ corpus. Some code to check your implementation has been provided for you below.

# %%
top50.iloc[1].head(5)
# Out:
# a      29.0
# all     4.0
# an      1.0
# and    83.0
# any     1.0
# Name: 2, dtype: float64

# %%
# use df from questin 1 and put on this function
# subset results to get ones without author - for other question
# compare vector to every row

# top50.iloc[1]
def calc_cosine_similarity(vector):
    idf = np.log(len(top50)/((top50)>0).sum())
    tf_idf = top50*idf
    query_vector = vector*idf
    dot_products = (tf_idf*query_vector).sum(axis=1)
    length1 = np.sqrt((tf_idf**2).sum(axis=1))
    length2 = np.sqrt((query_vector**2).sum())
    cos_sim = dot_products/(length1*length2)
    return cos_sim

# %%
# This should return a vector with the cosine similarity of each
# Federalist Paper with Paper No. 49 (one of the disputed papers).
calc_cosine_similarity(top50.loc[1]).nlargest(3)
# Out:
# 1     1.000000
# 2     0.835979
# 3     0.782240
# 4     0.785857
# 5     0.866028
# 6     0.814072
# 7     0.600997
# 8     0.790892
# 9     0.713261
# 10    0.915364
# 11    0.859037
# 12    0.745709
# 13    0.739847
# 14    0.837228
# 15    0.819067
# 16    0.811168
# 17    0.831711
# 18    0.806310
# 19    0.666848
# 20    0.690224
# 21    0.791626
# 22    0.826072
# 23    0.672404
# 24    0.754902
# 25    0.852453
# 26    0.807772
# 27    0.738337
# 28    0.665122
# 29    0.641748
# 30    0.729425
#         ...
# 56    0.786391
# 57    0.863653
# 58    0.741779
# 59    0.744361
# 60    0.915302
# 61    0.767328
# 62    0.677962
# 63    0.736188
# 64    0.771537
# 65    0.808865
# 66    0.828350
# 67    0.700048
# 68    0.871360
# 69    0.689032
# 70    0.907207
# 71    0.849740
# 72    0.804264
# 73    0.786818
# 74    0.647510
# 75    0.760247
# 76    0.825332
# 77    0.665681
# 78    0.689477
# 79    0.725164
# 80    0.596428
# 81    0.747166
# 82    0.662256
# 83    0.790878
# 84    0.761035
# 85    0.747552
# dtype: float64

# %%
# This test should pass without an error. (Think about why!)
assert(calc_cosine_similarity(top50.loc[49]).loc[49] == 1.0)
# because it's comparing its cosine similarity to itself!

# %% [markdown]
# ### Grader's Comments
#
# -
# -
#
# [This question is worth 15 points.]

# %%
# This cell should only be modified only by a grader.
scores.append(0)

# %% [markdown]
# ## Question 3
#
# We will consider two ways of using the cosine similarities to assign an authorship to the disputed papers.
#
# 1. We can take the author of the Federalist Paper (among those with known authors) with the highest cosine similarity to the disputed paper.
# 2. We can look at the authors of the 3 papers (among those with known authors) with the 3 highest cosine similarities to the disputed papers and use "majority vote" to determine the winner. (For example, if the 3 most similar papers were written by Hamilton, Madison, and Hamilton, then we would conclude that the paper was written by Hamilton.) In the case of a tie, we pick one arbitrarily.
#
# Remember that the known authorships can be found in `/data/federalist/authorship.csv`.
#
# To determine which of the two methods is better, we first apply the methods to the papers with known authorship. For each of the 70 papers with known authors, apply the two methods above and create a [confusion matrix](https://en.wikipedia.org/wiki/Confusion_matrix) -- showing how often you predicted Hamilton, Jay, or Madison, and how often it actually was Hamilton, Jay, or Madison. You can create the confusion matrix using either Pandas or Matplotlib, as long as it is labeled.
#
# **WARNING:** When applying the above methods to the papers with known authorships, you should exclude the document with the highest cosine similarity. (Do you see why?)

# %% [markdown]
# <h3>First Method</h3>

# %%
auth = pd.read_csv("/data/federalist/authorship.csv")
known = auth[auth["Author"].notnull()]
disp = auth[auth["Author"].isnull()]
disp_lst = auth[auth["Author"].isnull()].Paper.tolist()
known_lst = auth[auth["Author"].notnull()].Paper.tolist()


def related_author_1(lst):
    pred_auths = []
    for num in lst:
        g_row = calc_cosine_similarity(top50.loc[num]).sort_values(ascending=False)[1:2].index.values[0]
        pred_auth = auth[auth["Paper"]== g_row].Author.values[0]
        pred_auths.append(pred_auth)
    y_actu = pd.Series(known.Author.values, name='Actual')
    y_pred = pd.Series(pred_auths, name='Predicted')
    df_confusion = pd.crosstab(y_actu, y_pred)
    return df_confusion

related_author_1(known_lst)
# Out:
# Predicted  Hamilton  Jay  Madison
# Actual
# Hamilton         38    0        7
# Jay               1    0        2
# Madison           4    1        6

# %% [markdown]
# <h3>Second Method</h3>

# %%
def related_author_2(lst):
    pred_auths = []
    for num in lst:
        g_row = calc_cosine_similarity(top50.loc[num]).sort_values(ascending=False)[1:4].index.values
        box = []
        box.append(auth[auth["Paper"]== g_row[0]].Author.values[0])
        box.append(auth[auth["Paper"]== g_row[1]].Author.values[0])
        box.append(auth[auth["Paper"]== g_row[2]].Author.values[0])
        if box[0] == (box[1] or box[2]):
            pred_auths.append(box[0])
        elif box[1] == (box[0] or box[2]):
            pred_auths.append(box[1])
        elif box[2] == (box[0] or box[1]):
            pred_auths.append(box[2])
        else:
            pred_auths.append(box[randint(0,2)])
    y_actu = pd.Series(known.Author.values, name='Actual')
    y_pred = pd.Series(pred_auths, name='Predicted')
    df_confusion = pd.crosstab(y_actu, y_pred)
    return df_confusion

related_author_2(known_lst)
# Out:
# Predicted  Hamilton  Jay  Madison
# Actual
# Hamilton         40    0        7
# Jay               3    0        1
# Madison           5    1        5

# %% [markdown]
# _DISCUSS WHICH OF THE TWO METHODS WAS BETTER AND WHY._
#
# Although our models contain small flaws, it seems like the second model is more accurate for it takes into account more cos similarities than the first before it makes a choice.

# %% [markdown]
# ### Grader's Comments
#
# -
# -
#
# [This question is worth 20 points.]

# %%
# This cell should only be modified only by a grader.
scores.append(0)

# %% [markdown]
# ## Question 4
#
# Using the method that you deemed better in Question 3, assign an authorship to the 15 disputed _Federalist Papers_.

# %%
related_author_2(disp_lst)
# Out:
# Predicted  Hamilton  Jay  Madison
# Actual
# Hamilton          3    1        2
# Jay               3    0        1
# Madison           1    0        0

# %% [markdown]
# ### Grader's Comments
#
# -
# -
#
# [This question is worth 5 points.]

# %%
# This cell should only be modified only by a grader.
scores.append(0)
