# %% [markdown]
# # Bigram Markov Chain Model
#
# Now you'll build a more complex Markov chain that uses the last _two_ words (or bigram) to predict the next word. Now your dict `chain` should map a _tuple_ of words to a list of words that appear after it. So for example, one entry of this dict might be
#
# ```
# chain = {
#     ("it", "is"): ["the", "the", "not", "a", "a", "not", "the"],
#     ...
# }
# ```
#
# As before, you should also include tags that indicate the beginning and end of a song, as well as line breaks. That is, a tuple might contain tags like `"<START>"`, `"<END>"`, and `"<N>"`, in addition to regular words. So if the song starts with the line "Is this the real life?" and ends with the line "Nothing really matters to me.", you would have a dictionary that looks like
# ```
# chain = {
#     (None, "<START>"): ["Is", ...],
#     ("<START>", "Is"): ["this", ...],
#     ("Is", "this"): ["the", ...],
#     ("this", "the"): ["real", ...],
#     ("the", "real"): ["life?", ...],
#     ("real", "life?"): ["<N>", ...],
#     ("<N>", "Nothing"): ["really", ...],
#     ("Nothing", "really"): ["matters", ...],
#     ("really", "matters"): ["to", ...],
#     ("matters", "to"): ["me.", ...],
#     ("to", "me."): ["<END>", ...],
#     ...
# }
# ```

# %%
def train_markov_chain(lyrics):
    """
    Args:
      - lyrics: a list of strings, where each string represents
                the lyrics of one song by an artist.
    
    Returns:
      A dict that maps a tuple of 2 words ("bigram") to a list of
      words that follow that bigram, representing the Markov
      chain trained on the lyrics.
    """
    chain = {(None, "<START>"): []}
    for song in lyrics: ## song is a list of lines = one song's lyrics
        l_count = 0
        end_count = len(song)-1
        for line in song:
            words = line.split()
            for idx,word in enumerate(words):
                if idx == 0 and l_count == 0:
                    chain[(None, "<START>")].append(word)
                if idx == 1:
                    if l_count == 0:
                        if ("<START>", words[idx-1]) in chain:
                            chain[("<START>", words[idx-1])].append(word)
                        else:
                            chain[("<START>", words[idx-1])] = [word]
                    else:
                        if ("<N>", words[idx-1]) in chain:
                            chain[("<N>", words[idx-1])].append(words[idx])
                        else:
                            chain[("<N>", words[idx-1])] = [words[idx]]
                elif idx > 1:
                    if (words[idx-2], words[idx-1]) in chain:
                        if idx == len(words)-1:
                            if l_count == end_count:
                                chain[(words[idx-2], words[idx-1])].append("<END>")
                            else:
                                chain[(words[idx-2], words[idx-1])].append("<N>")
                        else:
                            chain[(words[idx-2], words[idx-1])].append(word)
                    elif (words[idx-2], words[idx-1]) not in chain:
                        if idx == len(words)-1:
                            if l_count == end_count:
                                chain[(words[idx-2], words[idx-1])] = ["<END>"]
                            else:
                                chain[(words[idx-2], words[idx-1])] = ["<N>"]
                        else:
                            chain[(words[idx-2], words[idx-1])] = [word]
            l_count+=1

    return chain

# %%
# Load the pickled lyrics object that you created in Part 1.
import pickle
lyrics = pickle.load(open("lyrics.pkl", "rb"))

# Call the function you wrote above.
chain = train_markov_chain(lyrics)

# What words tend to start a song (i.e., what words follow the <START> tag?)
print(chain[(None, "<START>")][:20])
# Out:
# ['Hold', '[Intro:', 'Buddah', '[Intro:', 'Zaytoven!', 'Respect', '[Hook', 'Cocaina,', 'Bentley', 'If', 'I', 'You', 'They', 'Purps', 'Hold', 'Mama', 'Pop', 'Tell', 'Buddah', 'Zaytoven!']

# %%
for key in chain:
    print(key)
#print(chain["<START", "Zaytoven!"])
# Out:
# ('no', 'more')
# ('my', 'heart')
# ('pay', 'your')
# ('I', 'scare')
# ('coupe,', 'typhoon')
# ('Beat', 'the')
# ('lights', 'as')
# ('up', 'before')
# ('Twenty', 'hoes')
# ('(drink', 'it')
# ('changed', 'the')
# ('tryna', 'leave')
# ('you', 'so')
# ('<N>', 'Used')
# ('Lamborghini', 'two')
# ('liquid', 'in')
# ('Young', 'rich')
# ('a', 'girlfriend')
# ('rock', 'chains')
# ('warm', 'up')
# ('licensed', 'to')
# ('on', 'stage')
# ('Back', 'it')
# ('the', 'ride')
# ('can', 'do')
# ('<N>', 'Straight')
# ('her,', 'take')
# ('Niggas', 'plotting')
# ('That', 'come')
# ('wanna', 'shop')
# ('chop', 'you')
# ('(ahh-urr,', 'ahh-urr,')
# ('called', '(called),')
# ('drank', 'and')
# ('Treat', 'the')
# ('Lamborghini', 'like')
# ('Met', 'her')
# ('<N>', 'Close')
# ('slip', 'for')
# ("didn't", 'let')
# ('Fuckboy', 'bow')
# ('like', "it's")
# ("'bout", 'that')
# ('You', 'might')
# ('they', 'from')
# ('100,000', 'in')
# ('the', 'crowd')
# ('<N>', 'Going')
# ("can't", 'pull')
# ('not', 'a')
# ('Bando', "Shane's")
# ('problem', 'my')
# ('buried', 'in')
# ("Droppin'", 'them')
# ('my', 'shooters,')
# ('drugs,', 'wrap')
# ('all', 'the')
# ('front', 'end')
# ('Bugatti', 'on')
# ('back', 'of')
# ('on', 'that')
# ("talkin'", 'stupid')
# ('Italy,', 'Hawaii,')
# ('it', 'my')
# ('nigga', 'pole,')
# ('out', 'the')
# ('recognized', 'in')
# ('Atlanta', 'now')
# ('(clean', 'it')
# ('Lifestyle,', 'yeah')
# ('biggest', 'shit')
# ('to', 'get')
# ('was', 'Newton,')
# ('and', 'asked')
# ('right', 'in')
# ("'em", 'please')
# ('playa', 'playa')
# ('<N>', 'Disrupted')
# ('But', "don't")
# ('they', "'bout")
# ('the', 'Margielas,')
# ('lemonade', "it's")
# ('trap', 'by')
# ('wrist', 'like')
# ('that', 'the')
# ('We', 'thank')
# ('a', 'pro')
# ('niggas', 'neck,')
# ("I'm", 'talking')
# ('on', 'them,')
# ('it', 'you')
# ('better,', 'never')
# ('lions,', 'elephants')
# ('When', 'a')
# ('You', 'want')
# ('<N>', 'Actavis')
# ('charge', 'you')
# ('to', 'do')
# ('cookie', 'yeah')
# ('jet', 'to')
# ('so', 'a')
# ('done', 'fucked')
# ('and', 'gold,')
# ('Let', 'me')
# ('<N>', 'Twenty')
# ('up', 'a')
# ('get', 'that')
# ('one', 'time,')
# ('that', 'Draco,')
# ('round', 'ten')
# ('to', "droppin'")
# ('get', 'the')
# ('Niggas', 'pocket')
# ('heart,', 'you')
# ('mom', 'started')
# ('meet', 'the')
# ('it', 'can')
# ("lyin'", "'bout")
# ('you', 'listen')
# ('Niggas', 'come')
# ('for', 'tonight')
# ('Started', 'with')
# ('No', 'forreal,')
# ('the', 'white,')
# ('coupe', 'and')
# ('them', 'birds,')
# ('(turn', 'the')
# ("I'm", 'making')
# ('of', 'time,')
# ('tapestry,', 'I')
# ('smash', 'her')
# ('Never', 'see')
# ('whipping', 'chickens,')
# ('<N>', 'Tinted')
# ('of', 'who')
# ('bullets', 'starting')
# ("don't", 'need')
# ('great', 'feeling')
# ("Trappin'", 'out')
# ('know', 'all')
# ('and', 'we')
# ('top', 'ropes')
# ('valet,', 'the')
# ('you', 'clear')
# ('mama,', "lil'")
# ('when', 'times')
# ('she', 'an')
# ('was', 'trapping')
# ('want', 'it')
# ('my', 'R8')
# ('Bentley', 'I')
# ('ease', 'my')
# ('<N>', 'Once')
# ('bitch', 'when')
# ('the', 'teacher')
# ('me', '(mama)')
# ("don't", 'play')
# ('my', 'top')
# ("I'm", 'just')
# ('no', 'clothes,')
# ("who's", 'that')
# ('Mama', 'told')
# ('me', 'for')
# ('phone', 'number,')
# ('with', 'pints')
# ('trench', 'coat')
# ('not', 'stupid')
# ('get', 'your')
# ('momma', 'told')
# ('beat', 'it')
# ('rich,', 'good')
# ('niggas', "couldn't")
# ('calm', 'down,')
# ('mamma', 'get')
# ('We', 'made')
# ('but', "ain't")
# ('Finesse', 'him')
# ('took', 'the')
# ('the', 'foundation')
# ('Nation', '(Yung')
# ("trippin'", "'bout")
# ('Kicked', 'them')
# ('the', 'plan')
# ('the', 'pressure')
# ('your', 'song,')
# ('grandmama', 'was')
# ('yeah,', 'Dat')
# ('like', 'it')
# ('get', "'em")
# ('Recognized', '(recognized,')
# ('right', 'and')
# ('the', 'trap')
# ('and', 'relax')
# ('she', 'took')
# ('boy', 'you')
# ('from', 'an')
# ("that's", 'tragic')
# ('Went', 'to')
# ('Gotta', 'pay')
# ('Got', '100')
# ('that', "ain't")
# ('gator', 'shots')
# ('night,', 'yeah,')
# ('some', 'bitches')
# ("'cause", 'the')
# ('<N>', 'Nigga')
# ('the', 'Benz')
# ("don'", 'broke')
# ('<N>', 'He')
# ('me', "what's")
# ('plug', 'at')
# ('so', 'innocent,')
# ('dollar', 'signs,')
# ('band', 'grip')
# ('crack', 'in')
# ('pass', 'the')
# ('close,', 'bout')
# ('sun', 'come')
# ('<N>', 'Working')
# ('last', '(I')
# ('<N>', 'Lambo')
# ('Price,', 'going')
# ("talkin',", 'yeah')
# ('mind', '(skr')
# ('my', 'poker')
# ('it', 'change')
# ('Nigga', 'Timeline')
# ('favourite', 'rapper')
# ('<N>', 'Dope')
# ('a', 'foreign')
# ('magazine,', 'the')
# ('<N>', 'Vacay')
# ('me', "(jumpin'")
# ('I', 'bought')
# ('ass', 'on')
# ('the', 'song')
# ('Two', 'bitches,')
# ('Put', 'his')
# ('brother,', 'my')
# ('Heard', 'that')
# ('<N>', 'Clear')
# ('<N>', 'Forgive')
# ('see', 'me')
# ('played', 'yourself!')
# ('around,', 'dope')
# ('the', 'block')
# ('Your', 'lil')
# ('A', 'lot')
# ('on', '(Young')
# ('dine', 'and')
# ('speed', 'chase')
# ('same', 'ones')
# ('a', 'nigga')
# ("ain't", 'move')
# ('it,', 'call')
# ('told', 'the')
# ('have', 'bricks')
# ('Greta', 'serve')
# ('see', 'red')
# ('pro', 'skater')
# ("ain't", 'even')
# ('was', 'a')
# ('reason', 'that')
# ('back,', 'is')
# ('want', "y'all,")
# ('Rich', 'Nation')
# ("gon'", 'never')
# ('want', 'it,')
# ('with', 'thirties')
# ('(I', 'got')
# ("30's", 'and')
# ('I', 'came')
# ('boys', 'in')
# ('time', '(drink,')
# ('night,', 'good')
# ("thinkin'", 'to')
# ('Friday', 'and')
# ('me', 'running')
# ('keep', 'that')
# ('<N>', 'Police')
# ('out', 'my')
# ('(choice', 'of')
# ('off', 'some')
# ('Now', 'who')
# ('the', 'baby')
# ("'em,", "I'mma")
# ('the', 'anna,')
# ('fucking', 'up')
# ("That's", 'cause')
# ('spreading', 'like')
# ('<N>', 'Send')
# ('the', 'migo')
# ('stop', 'me')
# ('from', 'bando')
# ('a', 'father')
# ('trying', 'to')
# ('<N>', 'Oh,')
# ('You', 'were')
# ("trappin'", 'hard')
# ('the', 'record,')
# ('a', 'Lambo,')
# ('a', 'rodeo')
# ('we', 'brought')
# ('walk', 'up')
# ('on', 'top')
# ('eyes', 'on')
# ('the', 'sack')
# ('man,', 'whip')
# ('spinning', 'out')
# ('Cry', 'me')
# ('<N>', 'Shine,')
# ("befo'", 'it')
# ('to', 'cock')
# ('some', 'money,')
# ('half', 'to')
# ('<N>', 'Technical')
# ('the', 'extras,')
# ('pop', 'out')
# ('Beretta,', 'case')
# ('white', 'in')
# ('her', 'her')
# ('with', 'fashion,')
# ('the', 'back')
# ('Feeling', 'like')
# ('she', 'broke')
# ('Got', 'your')
# ('everyday', "'cause")
# ('it', 'for')
# ('<START>', '[Intro:')
# ('your', 'favorite')
# ("'em", 'when')
# ('baby', 'look')
# ('Niggas', 'with')
# ('to', 'switch')
# ('give', 'you')
# ('What', 'the')
# ('then', 'I')
# ("drippin'", 'but')
# ('Migos', 'on')
# ('for', 'Instagram,')
# ('day,', 'somebody')
# ('Rib', 'Shack')
# ("Juggin'", 'iPhones,')
# ('Margielas,', 'right')
# ("gon'", 'go')
# ('punk', 'ass')
# ('said', 'she')
# ('it', 'in')
# ('momma', 'had')
# ('no', 'dream,')
# ('nickel,', "that's")
# ('<N>', "Gettin'")
# ('Beamer', 'to')
# ('leave', 'and')
# ('camo', 'when')
# ('just', 'get')
# ("havin'", 'brunch')
# ('fly', 'to')
# ('broke', "'cause")
# ('nigga', 'no')
# ('<N>', 'Twenty-five-hundred')
# ('Baby', 'bottle,')
# ('addicted', 'to')
# ('over', 'night')
# ('Maybach', 'with')
# ('Lambo,', 'Piccolo')
# ('made', 'a')
# ('she', 'might')
# ('it', 'sure')
# ('I', 'dab')
# ('J-Lo,', 'you')
# ('give', 'away')
# ('Hell', 'naw,')
# ('many', 'people')
# ('many', 'gold')
# ("can't", 'defeat')
# ('officer', 'you')
# ('nigga,', 'no')
# ('home', 'with')
# ('her', 'off')
# ('angels', 'with')
# ('in', 'saran')
# ('<N>', "I'd")
# ('they', 'respect')
# ('auto,', 'start')
# ('like', 'loose')
# ('mom', 'might')
# ('the', 'shits')
# ('shot', 'ya')
# ("sayin'", 'Migos')
# ('serve', 'my')
# ('<N>', 'When')
# ('bitch', 'you')
# ('news,', 'they')
# ('see', 'dollar')
# ('blue', 'lights')
# ('For', 'a')
# ('family', 'count')
# ('behind', 'the')
# ('Dat', 'Way,')
# ('with', 'bags,')
# ("'Rari,", 'that')
# ('on', 'gas')
# ('Motherfuckers', 'said')
# ('100,', 'you')
# ("Lamb',", 'have')
# ('around', 'with')
# ('R,', 'I')
# ('<N>', 'Pay')
# ('with', 'all')
# ('bite', '(gonna')
# ('like', 'why')
# ('gas', 'bag')
# ('pieces,', 'I')
# ('I', 'put')
# ('heart', 'so')
# ('night,', 'you')
# ('either', 'good')
# ('keep', 'up')
# ('do', 'that,')
# ('my', 'whips')
# ('I', 'had')
# ('him', 'for')
# ('Act', 'pints')
# ('up', '(uh')
# ('(just', 'for')
# ('Uh,', 'yeah,')
# ('yo', 'diamonds')
# ('Only', 'one')
# ('<N>', 'Lamborghini,')
# ('use', 'me')
# ('shows', 'outta')
# ('Next', 'thing')
# ('Bumping', 'yo')
# ('my', 'window')
# ('remember,', 'get')
# ('And', 'a')
# ('Abracadabra,', 'work')
# ('Nate', 'Dogg,')
# ('money', 'twice')
# ('squad', 'like')
# ('niggas', 'laughed')
# ("'em", '(pay')
# ('<N>', "J's")
# ('off', 'like')
# ('through', 'a')
# ('<N>', 'Arm')
# ('that', 'you')
# ('was', "knockin'")
# ('the', 'corner')
# ('Call', 'up')
# ('up', 'new')
# ('call', 'on')
# ('old', 'they')
# ('no', 'English')
# ('of', 'me')
# ('my', "motherfuckin'")
# ('he', 'happy')
# ('only', 'for')
# ("Sippin'", 'codeine')
# ('oven', 'it')
# ('stage', 'in')
# ('nothing', 'but')
# ('the', 'ones')
# ('fall', 'I')
# ('did', 'everything')
# ('me', 'what')
# ('<N>', 'Independent,')
# ('Bought', 'that')
# ('leave', 'it')
# ('shit', 'talk,')
# ('beat', 'the')
# ('it,', 'now')
# ('until', 'we')
# ('biggest', 'gangstas')
# ('snipers,', 'no')
# ('pinocchio,', 'nigga,')
# ('sound', 'like')
# ('our', 'jet,')
# ('stage', 'show')
# ('the', 'territory')
# ('me,', 'she')
# ('so', 'sick')
# ("swappin',", 'no')
# ('I', 'grant')
# ('club', 'while')
# ('so', 'I')
# ('Have', 'my')
# ('Head', 'full')
# ("I'mma", 'call')
# ('<START>', 'Pop')
# ('persistent,', 'if')
# ('was', 'my')
# ('black,', 'getting')
# ('fuck', 'that,')
# ('crib', 'is')
# ('And', "I'm")
# ('a', 'kiss')
# ('no', 'selfie')
# ('get', 'in')
# ('percocet,', 'pour')
# ('phone', 'ring,')
# ("motherfuckin'", 'cook')
# ('to', 'fuck')
# ('over', 'the')
# ('I', 'wanted')
# ('mine,', 'I')
# ('my', 'drugs,')
# ('50', 'bands')
# ('on', 'Fox')
# ('new', 'Bentley')
# ('gave', 'them')
# ('came', 'in')
# ('Quavo', "livin'")
# ("I'm", "gettin'")
# ('who', 'I')
# ('really', 'here')
# ('done', 'been')
# ('got', 'single')
# ('we', "gon'")
# ('abnormal', 'so')
# ('right', 'there,')
# ('so', 'close,')
# ('quick', 'at')
# ('me', 'put')
# ('money', 'and')
# ('money', 'turn')
# ('the', 'bag,')
# ('a', '100')
# ('plug', 'mail')
# ('bad', 'bitch')
# ('dab', 'at')
# ("can't", 'give')
# ('Sorry', 'you')
# ("she'll", 'be')
# ('stashed', 'in')
# ('tryna', 'get')
# ('out', 'to')
# ('you', 'like')
# ('run', 'at')
# ('our', 'swag')
# ('clothes', '(like')
# ('<N>', 'Drop')
# ('they', 'put')
# ('fucking', 'niggas')
# ("Takin'", 'nine')
# ('cut,', 'posted')
# ('geeking,', 'going')
# ('Lamborghini,', 'white')
# ("'Cause", 'a')
# ('them', 'with')
# ('Scotty', 'like')
# ("bangin'", 'twist')
# ('slimy,', 'grimy,')
# ('<N>', 'Brown')
# ('<N>', 'Popeyes,')
# ('neck', 'and')
# ('catch', 'a')
# ('the', 'Nawf,')
# ('from', 'the')
# ('for', 'giving')
# ('[Hook', '-')
# ('me', 'lonely,')
# ('rich', 'niggas')
# ('the', "M&M;'s,")
# ('pots', 'and')
# ('got', "30's")
# ('ass', 'after')
# ('i8', 'and')
# ('cookie', "smellin'")
# ('get', 'jammed')
# ('they', 'in')
# ('you', 'see')
# ('it', 'trap')
# ('on', 'the')
# ('Draco', 'get')
# ('gas', 'stashed')
# ('a', 'hole')
# ('<N>', 'Aye')
# ('bitches', 'from')
# ('2', '-')
# ('cut,', '12')
# ('what', "ain't")
# ('pot', 'on')
# ('he', 'need')
# ('Whipping', 'the')
# ('taking', 'all')
# ('a', 'feature,')
# ('to', 'let')
# ("wouldn't", 'bond')
# ('<N>', 'Walk')
# ('they', 'globing')
# ('on', 'new')
# ("wouldn't", 'make')
# ('Have', 'everybody')
# ("don't", 'gotta')
# ('stove,', 'take')
# ('(in', 'your')
# ('get', 'to')
# ('passion', '(beat')
# ('some', 'tar')
# ('the', 'couch')
# ('fell', 'off')
# ("OG's", 'they')
# ('that', 'Draco')
# ('we', 'beat')
# ('label', 'we')
# ('large,', 'you')
# ('having', 'recognition')
# ('that', 'on')
# ('the', 'KFC')
# ("backin'", 'up')
# ('they', 'extinct')
# ('calling', 'Scotty')
# ('in', 'them')
# ('[Verse', '2')
# ('Mommas', 'and')
# ("'cause", "I'm")
# ('Wipe', 'my')
# ('(freezy),', 'young')
# ('a', 'drum')
# ("I'm", 'thinking')
# ('Buddah', 'blessed')
# ('know', 'she')
# ('playa', '(nah,')
# ('<N>', "Ridin'")
# ('<N>', 'Perky')
# ('Ten', 'different')
# ('hundred', 'racks')
# ('is', 'what')
# ('him', 'on')
# ('club', 'I')
# ('pocket', 'rocket')
# ('is', 'glass')
# ('the', 'condos')
# ('robotic,', 'bad')
# ('thot,', 'thot,')
# ('big', 'bag')
# ("Pullin'", 'out')
# ('might', 'get')
# ("I'm", "sellin'")
# ('diamonds', 'gonna')
# ('1', '-')
# ('You', 'never')
# ('up,', 'never')
# ('screaming', 'out')
# ('they', 'be')
# ('were', 'probably')
# ('did,', 'and')
# ('talking', 'but')
# ('brick', 'turned')
# ('hey,', 'slippery,')
# ('that', 'talking')
# ('the', 'bando')
# ('serve', 'ya')
# ('and', 'that')
# ('want', 'all')
# ("M&M;'s,", "I'm")
# ('nigga', 'pull')
# ('my', 'flows')
# ('official,', 'My')
# ('me', 'dad')
# ('she', 'with')
# ('dope', 'like')
# ('<N>', 'Cocaina,')
# ('boat,', 'call')
# ('take', 'one')
# ('sprinter', 'you')
# ('click', 'shit')
# ('two', 'bad')
# ('bitch', 'and')
# ("I'm", "askin'")
# ('and', 'rewind')
# ('it', 'with')
# ('a', 'four,')
# ('just', 'want')
# ('That', 'Migos')
# ("dabbin'", 'in')
# ('migo', 'said')
# ('hey,', 'huh,')
# ('fuck', 'did')
# ('Close', 'the')
# ("I'ma", 'make')
# ('Pink', 'slip')
# ('foundation', 'to')
# ("shouldn't", 'of')
# ('daddy', "(I'm")
# ('talking', 'to')
# ('looking', 'for')
# ('see', 'the')
# ('Phantom,', 'not')
# ('trap', 'with')
# ('for', 'one')
# ('help', 'my')
# ('saved', 'me')
# ('knew', 'me,')
# ('<N>', 'Let')
# ('dab,', 'I')
# ('from', "nothin'")
# ('speak', 'your')
# ('(when', 'you')
# ('ice', 'tell')
# ('flow', 'through')
# ('a', "'Yonce")
# ('five', "o'")
# ('<N>', 'Last')
# ('Hocus', 'pocus')
# ('going', 'up,')
# ('it', 'one')
# ('twelve"', 'turn')
# ('a', 'party')
# ('an', 'American')
# ('some', 'crosses')
# ('my', 'pants')
# ('tripping', 'Takeoff')
# ('worth', 'a')
# ('got', 'kicked')
# ('Aye', 'Takeoff,')
# ('so', 'fuck')
# ("(I'm", 'with')
# ('the', 'check')
# ('niggas', "doin'")
# ('chopper', "aimin'")
# ('thanking', 'god')
# ('bitches', 'come')
# ('windows', 'on')
# ('splurge,', "it's")
# ('no', 'old')
# ('on', "'em,")
# ('ask', 'for')
# ('blew', 'up,')
# ('My', 'lifestyle')
# ('I', 'dialled')
# ('a', 'fox')
# ("pushin'", 'a')
# ('You', 'remember')
# ('five', 'rooms,')
# ('khakis,', 'Versace')
# ('the', 'two')
# ('around', 'in')
# ('Bad', 'bitches,')
# ('a', 'good')
# ('turn', 'the')
# ('Once', 'upon')
# ('rice', '(eat')
# ('<N>', '(Young')
# ('Momma', 'said')
# ('and', 'white')
# ('recognized', 'then')
# ('if', 'I')
# ('fundraiser', 'fetti')
# ('bubblegum', 'wrapping')
# ('the', 'wings')
# ('number,', 'you')
# ('touch', 'what')
# ('be', 'thanking')
# ('it', 'to')
# ('you', 'cloned')
# ('off', 'the')
# ('We', 'in')
# ('the', 'name')
# ('<N>', 'Tape')
# ('finesse', 'a')
# ('the', 'pen')
# ('I', 'keep')
# ('you', 'bout')
# ("I'm", "choppin'")
# ('nigga', 'called')
# ('lose', '(lose')
# ('smell', 'the')
# ('Put', 'a')
# ('fur,', 'look')
# ('working', 'for')
# ('yo', 'diamonds,')
# ('Last', 'time')
# ('stretch', 'it')
# ('nigga', 'so')
# ("Fuckin'", 'with')
# ('jet', 'we')
# ('rep', 'this')
# ('better', 'shut')
# ('(Fuck', 'mathmatics,')
# ('plug', 'out')
# ('Got', 'home')
# ('your', 'recorder')
# ('the', 'interview,')
# ('<N>', 'Want')
# ('them', 'snipers,')
# ('me', 'later,')
# ('need', 'me')
# ('mansion,', 'no')
# ('California', 'foreign')
# ('<N>', 'Mansion,')
# ('time', '(one')
# ('playa,', 'playa')
# ('Niggas', 'going')
# ("debatin',", 'they')
# ("I'm", 'flyer')
# ('sick', 'it')
# ('12', 'in')
# ('Donkey', 'of')
# ('jungle,', 'lions,')
# ('it', 'Grandma')
# ("What's", 'up')
# ('flex', 'on')
# ('wonder', 'If')
# ('I', 'could')
# ('the', 'gas')
# ("I'm", 'not')
# ('Wilt', 'Chamberlain')
# ('came', 'from')
# ("I'm", 'a')
# ("ain't", 'no')
# ('in', 'traffic')
# ('shawty', 'thought')
# ('tell', "'em")
# ('<N>', 'Ride')
# ('money', 'you')
# ('that', 'be')
# ('a', 'thot,')
# ('a', 'coupe')
# ('her,', 'nigga')
# ('bunnies', 'and')
# ("Swappin',", 'no')
# ('you', 'is')
# ('over', 'your')
# ("nothin',", 'you')
# ('out', 'Toyotas')
# ('last', 'don,')
# ('you', "trappin',")
# ('<N>', 'Count')
# ('Try', 'to')
# ('bricks,', 'plain')
# ('he', "ridin'")
# ('Break', 'the')
# ('artist', 'be')
# ('we', 'was')
# ('We', 'gave')
# ('niggas,', 'they')
# ('empty', 'the')
# ('trapping', 'at')
# ('<N>', 'Fresh')
# ('"you', 'sure')
# ('Stripper', 'girl')
# ('froze,', 'wrist')
# ('Is', 'Mr.')
# ('lean', 'on')
# ('niggas', 'at')
# ("fumblin'", 'with')
# ('coulda', 'pulled')
# ('My', 'bitches')
# ('then', 'move')
# ('grab', 'the')
# ('you', 'working')
# ('round,', 'uh,')
# ('nigga,', 'boy,')
# ('say', 'I')
# ('full', 'Texas')
# ('me', 'just')
# ('talk', '(whole')
# ('lethal', 'parts,')
# ('corner', "it's")
# ('College,', 'nigga')
# ('take', 'some')
# ("sellin'", 'crack')
# ('it,', "I'm")
# ("I'm", 'walking,')
# ('and', 'said')
# ('I', 'wanna')
# ('Lemme', 'talk')
# ('ride', 'around,')
# ('door', 'and')
# ('<N>', 'Christian')
# ('Iron', 'man')
# ('they', 'seized')
# ('and', 'back')
# ('<N>', 'Cry')
# ('good', 'on')
# ('On', 'the')
# ('keys', 'I')
# ('it,', 'beat')
# ('emptied', 'the')
# ('Tell', 'my')
# ('on', 'big,')
# ('sleep', 'in')
# ('the', 'gun')
# ('and', 'dashed')
# ('we', 'fuck')
# ('<N>', "Cuffin'")
# ('Pussy', 'nigga')
# ('the', 'condo,')
# ('I', 'done')
# ('my', 'Jesus')
# ('<N>', 'Name')
# ('bag,', 'the')
# ('the', 'camo')
# ('daddy,', "I'm")
# ('niggas', 'they')
# ('corner', '(skrr')
# ('<N>', "Hoppin'")
# ('gas,', 'you')
# ('a', 'crumb')
# ('every', 'day')
# ('do', 'this')
# ("'em", 'knocked')
# ('spoil', 'them')
# ("feelin'", 'million')
# ('like', "Noah's")
# ('acting', 'like')
# ('I', "didn't")
# ('that', 'Bentley')
# ('extension', 'for')
# ('go', 'slow')
# ('count', 'on')
# ('He', 'was')
# ('Heroin,', 'half')
# ('<N>', "Packin'")
# ("You're", 'going')
# ('she', 'get')
# ('all', 'me')
# ('recognition', '(all')
# ('<N>', 'Free')
# ("ain't", "gon'")
# ('I', 'turned')
# ('them', 'like')
# ('your', 'partners')
# ('Throw', 'body')
# ('(Yung', 'Rich')
# ('girlfriend', 'in')
# ('close,', 'my')
# ('with', 'a')
# ('busta', 'and')
# ('it', 'on,')
# ('head', 'on')
# ('no', 'type,')
# ('a', 'trip')
# ('Lemme', 'smash')
# ("livin'", 'legend,')
# ('And', 'listen')
# ('I', 'stand')
# ('Niggas', 'bite')
# ('need', "y'all,")
# ("I'm", 'surrounded')
# ('No', 'stomach,')
# ('bands', 'so')
# ('a', 'Beretta,')
# ('No', 'credit,')
# ('Perky', 'got')
# ("can't", 'push')
# ('respect', 'us')
# ('that', 'bitch')
# ("goin'", 'out')
# ('it', 'all')
# ('trapping', 'the')
# ('fucking', 'her')
# ('up', '(pop')
# ('up,', 'niggas')
# ('Before', 'we')
# ('nigga', 'old')
# ('family', 'nigga,')
# ('talking', 'shit,')
# ('and', 'them')
# ("it's", 'attached')
# ('on', 'list')
# ('status,', 'you')
# ('the', 'semi')
# ('trap,', 'watch')
# ('come', 'up')
# ('a', 'act')
# ("comin'", 'back')
# ('the', 'Migos')
# ('I', 'jump')
# ('listening', 'to')
# ('<N>', 'Tear')
# ('the', 'hood')
# ('get', 'along')
# ('Fuck', 'around')
# ('last', 'I')
# ('seriously', 'afford')
# ('Tunnel', 'vision,')
# ('me', 'off')
# ('stores', 'now')
# ('Grandma', 'told')
# ('life', 'was')
# ('<N>', 'Pick')
# ('backends', 'in')
# ('Givenchy', 'my')
# ('twenties', 'or')
# ('<N>', 'Championship,')
# ('stage', 'and')
# ("don't", 'even')
# ('had', 'pain')
# ('we', 'heard')
# ('act', 'brand')
# ('I', 'did')
# ('two', 'hundred')
# ('Madden', '(I')
# ("'em,", 'but')
# ('in', 'project')
# ('are', 'large,')
# ('You', 'tripping')
# ('sacrifice,', "can't")
# ("ain't", 'bright')
# ('I', "ain't")
# ('to', 'meet')
# ('me', '(skirrt')
# ("I've", 'been')
# ('lick', 'was')
# ('cops', '(fuck')
# ('pies', '(woah),')
# ("I'm", 'playing')
# ('(mob),', 'real')
# ('gas', '(gas),')
# ('that', 'lean')
# ('piped', 'her')
# ('<N>', 'Hopping')
# ('Cut', "'em")
# ('do', 'not')
# ("Pourin'", 'lean')
# ('(four),', 'five')
# ('the', 'Forbes')
# ('a', 'fact')
# ('Toyota,', 'have')
# ('but', 'a')
# ('bag', '(know')
# ('your', 'ho')
# ('the', 'bricks,')
# ('there', "snitchin',")
# ('I', 'hit')
# ('<N>', '[Bridge:')
# ('<N>', 'Pass')
# ('flyer', 'than')
# ('we', 'smoking')
# ('put', 'your')
# ('hell', 'just')
# ('all', 'over')
# ('<N>', 'Word')
# ('been', 'sleep')
# ('thing', 'we')
# ('never', 'ask')
# ('run', 'with')
# ('body', 'would')
# ('that', 'life')
# ('frog,', 'woah')
# ('coming', 'on')
# ('find', 'the')
# ('They', 'talking')
# ('on', 'Quavo')
# ("ain't", "playin'")
# ('thinking', 'she')
# ('boy,', 'we')
# ("it's", 'only')
# ('to', 'pass')
# ('niggas', 'and')
# ('the', 'far')
# ("gon'", 'fuck')
# ("geekin'", 'out,')
# ('Mama', 'asked')
# ('sweet,', 'I')
# ('time', '(turn')
# ('<N>', 'Boy')
# ('her', 'from')
# ('of', 'your')
# ('hoes', 'like')
# ('to', 'Nate')
# ('I', 'got')
# ('<N>', '(Fuck')
# ('<N>', 'Sipping')
# ('my', 'CEO')
# ('nigga', 'needed')
# ('coat', 'for')
# ('criminals', 'trying')
# ('shawty,', 'do')
# ('<N>', 'Stopped')
# ('night', '(rich')
# ('you', 'to')
# ('Mama', 'on')
# ('run', 'it')
# ('break', 'it')
# ('tryna', 'keep')
# ('Pure', 'cocaina')
# ('I', 'cut')
# ('tomorrow', 'you')
# ('they', 'said')
# ('just', 'a')
# ('in', 'and')
# ('dead', 'and')
# ('Henny,', 'or')
# ('whip', 'up')
# ('Cut', 'his')
# ('rocks', '(rocks),')
# ('and', "poppin',")
# ('pick', 'up')
# ("switchin'", 'my')
# ('Same', 'people')
# ('lord', 'for')
# ('flow,', 'you')
# ('work', 'for')
# ('that', 'gas,')
# ("flippin'", 'it,')
# ('call', 'Scooby')
# ('yeah,', 'my')
# ('the', 'fashion!')
# ("poppin',", 'I')
# ('my', 'momma')
# ('me,', "it's")
# ('get', 'right,')
# ('accuracy,', 'abracadabra')
# ('stars', 'for')
# ("havin'", 'this')
# ('elephants', 'and')
# ('<N>', 'Run')
# ('birds', 'take')
# ('glide,', "ain't")
# ('[Verse', '1')
# ('a', 'problem')
# ("I'm", "drippin'")
# ('boy', 'I')
# ('I', 'like,')
# ('want', 'is')
# ("ain't", 'pass')
# ('to', 'locker,')
# ('I', 'make')
# ('why', "can't")
# ("gon'", 'do')
# ('Got', 'unfinished')
# ('then', 'the')
# ('You', 'gonna')
# ('on', 'Toyota,')
# ('<N>', 'Heroin,')
# ('on', 'your')
# ('you', 'must')
# ('a', 'whole')
# ('in', 'with')
# ('the', 'most')
# ('Niggas', 'copy,')
# ('why', 'the')
# ("'Rari?", '458')
# ('the', 'mall,')
# ('Trap', 'out')
# ('took', 'a')
# ('you', 'cuffing')
# ('that', 'brought')
# ('(Grab', 'my')
# ('ya', '(')
# ('em', 'fuck')
# ('in', 'stock')
# ('need', 'it')
# ('We', 'hopped')
# ('nigga', 'sacrifice')
# ('and', 'go')
# ('go', 'splurge,')
# ('Kick', 'door,')
# ('amigos', 'by')
# ('<N>', 'Bumping')
# ('that', 'eggbeater')
# ('mansion,', 'you')
# ('me', 'feeling')
# ('solve', 'a')
# ('it', 'or')
# ('got', 'different,')
# ('Mulsanne', 'but')
# ('to', 'repay,')
# ('your', 'car')
# ('cause', "I'm")
# ('we', "havin'")
# ('Cohen', "havin'")
# ('<N>', 'Diamond')
# ('no', 'drought')
# ('that', "you're")
# ('want', 'the')
# ('20K', 'right')
# ('say', 'he')
# ('Hoes', 'calling')
# ('Get', "'em")
# ('got', 'the')
# ("don't", 'fuck')
# ('pint,', 'stocking')
# ('KFC', 'and')
# ('and', 'blues')
# ('you', 'thinking')
# ('copy,', 'Mike')
# ('robbed', 'in')
# ('bitch', 'got')
# ('All', 'ass')
# ('not', 'taking')
# ('flexing', 'on')
# ('Go', 'to')
# ('(all', 'ass')
# ('up,', 'you')
# ('gold', "that's")
# ('<N>', 'Pyrex')
# ('to', 'have')
# ('feature,', 'nigga?,')
# ('She', 'try')
# ('the', 'cash')
# ('Piccolo', '(skrr')
# ('cut', 'the')
# ('slippery,', 'she')
# ('this', 'shit')
# ('Boobie', '(run')
# ('yeah,', 'yeah,')
# ('rockstar,', 'with')
# ('gold', 'chains')
# ('Harambe,', 'abused')
# ('thot', 'on')
# ('you', 'hold')
# ('My', 'money')
# ('<N>', 'Sorry')
# ('We', 'go')
# ('kiss', 'me,')
# ('<N>', 'Fiend')
# ('me', '(come')
# ('dynamite', '(cookie,')
# ('Young', 'Metro')
# ('Recognize', 'a')
# ('favorite', 'Corvette,')
# ('how', 'I')
# ('shadow', 'when')
# ('thank', 'god')
# ('Yeah,', 'dat')
# ('Call', 'me')
# ('I', 'left')
# ('Niggas', 'in')
# ('good', 'care')
# ('the', 'porch,')
# ('lotta', 'money,')
# ('just', 'look')
# ('<N>', 'Sad')
# ('like', 'he')
# ('<N>', 'If')
# ('Where', 'were')
# ('(only', 'take')
# ('ten', 'years')
# ('a', 'carpet')
# ('(shit', "goin'")
# ('want', 'my')
# ('me', 'boobies')
# ('I', 'walked')
# ('shoot', 'it,')
# ('the', 'mind')
# ('but', 'the')
# ('keep', 'texting')
# ('crib', "tryin'")
# ('you', 'stupid')
# ('a', 'cutie,')
# ('Plays', 'off')
# ('<N>', "Juggin'")
# ('<N>', 'I')
# ('ho', 'for')
# ('Welcome', 'to')
# ('Diamond', 'shine')
# ('Smashing', 'your')
# ('Your', 'main')
# ('places', "I'm")
# ('bitch', 'I')
# ('Still', "goin'")
# ('go', 'find')
# ('die', "don't")
# ('wrist', 'cost')
# ('hood', 'on')
# ('diamonds', 'yeah')
# ("makin'", 'my')
# ('had', 'a')
# ('<START>', "What's")
# ('car,', 'he')
# ("Won't", 'get')
# ('From', 'the')
# ('you', 'will')
# ('A', 'nigga')
# ('If', 'she')
# ('ice', 'tray,')
# ('baby,', 'something')
# ("I'm", 'gon')
# ('shit', 'for')
# ('screw', 'that')
# ('Album', 'first')
# ('take', 'me')
# ('than', 'one')
# ('doors', 'for')
# ('bitter', 'and')
# ('money', 'counter')
# ('high', 'on')
# ('they', "hatin',")
# ('I', 'step')
# ('bottle,', 'but')
# ('But', 'they')
# ('the', 'clip,')
# ('sack', 'like')
# ('killing', 'each')
# ("I'm", 'your')
# ('bullshit', 'and')
# ('<N>', 'Try')
# ('White', 'boys')
# ('Now', 'you')
# ('Jackpot,', 'hit')
# ('<N>', 'Plus')
# ('<N>', 'Eight-ball,')
# ('want', 'me')
# ('with', 'these')
# ('and', 'get')
# ('out', '"pipe')
# ('get', 'one')
# ('have', 'to')
# ('Forgiatos', 'on')
# ('by', 'yourself')
# ('involved', 'in')
# ('pumps', 'and')
# ('chickens,', 'all')
# ('to', 'play')
# ('diamonds,', 'yo')
# ('cost', 'a')
# ('off,', 'my')
# ("smokin'", 'on')
# ('Two', 'piece')
# ('way,', 'float')
# ('Fully', 'automatic,')
# ('a', 'mosh')
# ('Her', 'daddy')
# ('Andy', 'Milonakis')
# ('front', 'of')
# ('bitch,', 'and')
# ('wit', 'my')
# ('I', 'do')
# ('solve', 'the')
# ('(look', 'at')
# ('web', 'up')
# ("Act'", 'rate')
# ('I', 'go')
# ('see', 'me,')
# ('hell', 'nah,')
# ('me', 'can')
# ('profit', 'like,')
# ('tryna', 'embarass')
# ('houses', 'kicking')
# ('<START>', 'One')
# ('we', 'both')
# ('he', 'smell')
# ('Float', 'like')
# ('it,', 'pop')
# ('you', "I'm")
# ('of', 'jail')
# ('[?]', 'pistol,')
# ('hoe', 'on')
# ('right', 'to')
# ('be', "trappin'")
# ("recordin',", "reportin'")
# ('and', 'she')
# ('kemosabe,', 'chopper')
# ('up', 'some')
# ('defeat', 'me,')
# ('tell', 'them')
# ('couch', '(30')
# ('you', 'take')
# ('a', 'problem,')
# ('still', "don't")
# ('wanna', 'play')
# ('change', 'your')
# ('<N>', "Pullin'")
# ('Yeah,', 'trap')
# ('from', 'Columbia,')
# ('know', "it's")
# ('like', 'they')
# ('come', 'straighten')
# ('Dropped', 'out')
# ('Percocet', 'party,')
# ('cap,', 'I')
# ('<N>', 'Finessing')
# ('Lemme', 'fuck')
# ('way', 'way')
# ('<N>', 'Lit')
# ('and', 'come')
# ('Yeah,', 'beat')
# ('hide,', 'shoot')
# ('you', 'gonna')
# ('nigga', 'with')
# ('the', 'tension')
# ('some', 'dirt')
# ('the', 'left,')
# ('the', 'six')
# ('speed', 'chase,')
# ('they', 'picked')
# ('(these', 'bitches')
# ('evidence', 'of')
# ('jungle,', 'my')
# ('Lil', 'bitty')
# ('more', 'than')
# ('Take', 'it')
# ('globing', 'into')
# ('gonna', 'ball')
# ('(skirrt', 'skirrt')
# ('neck,', "walkin'")
# ('me', 'pull')
# ('Remember', 'that')
# ('everywhere,', "ain't")
# ('One', 'gun')
# ('Disrupted', 'the')
# ('only', 'get')
# ('that', 'while')
# ("Cappin'", 'and')
# ('<N>', 'Double')
# ('Truck', "backin'")
# ('heaven,', 'grab')
# ('on', 'froze,')
# ("Pourin'", 'act')
# ('time', 'you')
# ('be', "poppin'")
# ('tell', 'the')
# ('kick', 'your')
# ('my', 'windows')
# ('shit', 'just')
# ('lemme', 'tell')
# ('hair', 'just')
# ('playa', "(thinkin'")
# ('neck,', 'cold')
# ('we', 'known')
# ('I', 'walk')
# ('Neck', 'water')
# ('ready', 'to')
# ('Mama', "cryin',")
# ('time', 'caught')
# ('My', 'momma')
# ('Quavo', 'came')
# ('He', 'pulling')
# ('we', 'did')
# ('drought?', '(Hell')
# ('Hit', 'the')
# ('lot', '(skrt')
# ('(beat', 'it')
# ('some', 'crazy')
# ('Bankrolls', 'are')
# ('Got', 'me')
# ('a', 'double')
# ('Bloody', 'money')
# ('seen', 'her')
# ('we', "don't")
# ('Draco,', 'come')
# ("walkin'", 'lick')
# ('we', 'looking')
# ('engine', 'in')
# ('Seventeen', 'years')
# ('fuck', 'a')
# ('was', "trappin'")
# ('habits', '(Actavis,')
# ('a', 'nine')
# ('strong,', 'grandma')
# ('like', 'her')
# ('love', 'my')
# ('momma', "ain't")
# ('it', 'dancing')
# ('went', 'missing')
# ("I'm", 'young')
# ('back', 'a')
# ('it,', "flippin'")
# ('Ruler,', 'diamonds')
# ("it's", 'simply,')
# ('really', 'did')
# ('<N>', 'Nobody')
# ('Throw', 'a')
# ('on', 'it,')
# ('Nigga', "talkin'")
# ('the', 'stove,')
# ('in', 'smelt')
# ('So', 'hit')
# ('that', 'he')
# ('did', 'way')
# ('in', 'Moscow')
# ('wrist', 'so')
# ('be', 'mad')
# ('they', 'white')
# ('an', 'ass,')
# ("let's", 'have')
# ('beat', 'it,')
# ("ain't", 'solid')
# ('every', 'day,')
# ('<N>', 'Park')
# ('I', 'dip')
# ('it', "don't")
# ('Get', 'a')
# ('watch', 'that')
# ('Gotta', 'thank')
# ('the', 'bitch,')
# ('go', 'round')
# ('for', 'sure,')
# ('the', 'seal')
# ('it', '(skrt')
# ('got', 'sickle')
# ('Frost,', 'Jack')
# ("Rockin'", 'down')
# ('Vietnamese', '(brrt')
# ('30,000', 'to')
# ('put', 'a')
# ('huh,', "switchin'")
# ('cruel', 'with')
# ('Lambo,', 'crossover')
# ('bando', 'I')
# ('a', 'bad')
# ('Oh,', 'oh,')
# ('Louboutins,', 'a')
# ('no', 'Iron')
# ('you', 'really')
# ('call', 'the')
# ('park', 'and')
# ('cashed', 'out')
# ('dot,', 'retro')
# ('You', 'got')
# ('left,', 'hit')
# ('Pete,', "that's")
# ('<N>', 'Benjamins')
# ('the', 'trash')
# ('should', 'I')
# ('tonight', '(only')
# ('coupe', 'with')
# ('he', 'shook')
# ('The', 'way')
# ('her', 'hair')
# ('sounding', 'like')
# ('was', 'hard')
# ('<N>', 'Kept')
# ('me', 'think')
# ('a', 'long')
# ('<START>', "Feelin'")
# ('hood', 'they')
# ('got,', 'unlock')
# ('you', 'know')
# ('Iceberg', '(ice),')
# ('wrong,', 'I')
# ('the', 'tag')
# ("I'mma", 'feed')
# ('the', 'ticket,')
# ('they', 'want')
# ('Seventeen', 'five,')
# ('down', 'Boggs')
# ('My', 'brothers')
# ('We', "goin'")
# ('Migos', 'pull')
# ('they', 'bite')
# ('you', "bangin'")
# ('me,', 'call')
# ('do', 'you')
# ("Can't", 'play')
# ('they', 'use')
# ('never', 'work')
# ('the', 'ceiling')
# ('both', 'know')
# ('was', 'still')
# ('360', 'the')
# ('I', 'thought')
# ('Act,', 'I')
# ('and', 'boujee')
# ('<N>', 'Trick')
# ('how', 'it')
# ('said', 'show')
# ('how', 'we')
# ('the', 'snow')
# ('Popeyes', "ain't")
# ('them', 'chinks')
# ('<N>', 'Statistics')
# ('treated', 'me')
# ('drive', 'feeling')
# ('hold', 'up,')
# ('face', '(in')
# ('the', 'bone,')
# ('(think', 'about')
# ('snow', 'white')
# ('a', 'show')
# ("I'm", 'no')
# ('your', 'hoe')
# ('another', 'one,')
# ('keep', 'calling')
# ('David', 'Bland')
# ('established', 'on')
# ('the', 'brick')
# ('my', 'diamond')
# ('<N>', 'Climb')
# ('cube', 'knock')
# ('me,', 'a')
# ('you', 'ask')
# ('man,', "can't")
# ('they', "didn't")
# ("snakin',", 'I')
# ('get', 'right')
# ('plug', 'up')
# ("braggin',", "havin'")
# ("talkin'", 'about,')
# ('seized', 'the')
# ('show,', 'can')
# ('and', 'counted')
# ('call,', 'no')
# ('take', 'a')
# ('but', "don't")
# ('(paper)', 'bags')
# ('plug', 'pull')
# ('dog,', 'woof')
# ('like', 'vultures')
# ('<N>', "Ain't")
# ('truck', 'bent')
# ('riding', 'on')
# ('twice', '(clean')
# ('back', 'end')
# ('yeah,', 'call')
# ('drop', 'her')
# ('said', 'nigga')
# ("don't", "don't")
# ('Fancy', 'bitches')
# ('click,', 'click,')
# ('his', 'ass')
# ('Drop', 'the')
# ('Way,', 'dab')
# ('a', 'riddle')
# ('rounds', 'too')
# ('heart', 'and')
# ('Just', 'hop')
# ("don't", 'wanna')
# ('on', 'rackings,')
# ('so', 'she')
# ('That', "wasn't")
# ('Make', 'my')
# ('We', 'can')
# ('time', 'high')
# ("Don't", 'mislead')
# ('Offset', 'at')
# ("gon'", 'kill')
# ('R.I.P', 'to')
# ('Beverly,', 'it')
# ('open', 'the')
# ('ho', 'fly,')
# ('Philippe', 'on')
# ('want', 'you')
# ('to', "em'")
# ('<N>', 'Get')
# ('rich', 'and')
# ('prices,', 'going')
# ("I'm", "livin'")
# ("countin'", 'them')
# ('trip', 'to')
# ('clip', 'like')
# ('the', 'dummy,')
# ('Outer', 'space,')
# ('trapping', '(trap,')
# ('no', 'binoculars,')
# ('unkindly,', 'cruel')
# ('Migos', "'til")
# ('<N>', '50')
# ('a', 'pot')
# ('It', 'is')
# ('my', 'hoe')
# ('<N>', 'Choppa')
# ('Middle', 'finger')
# ('Way', 'back')
# ('<N>', 'Never')
# ('sewed', 'up,')
# ('that', 'ever')
# ('Rich', 'nigga,')
# ('the', 'northside')
# ('the', 'shadow,')
# ('<N>', 'Her')
# ('can', 'catch')
# ('me', '(no')
# ('night,', 'I')
# ('Rich', 'Nation!')
# ('this', 'dab')
# ('said,', 'we')
# ('this', 'a')
# ('broke', 'down')
# ('been', "ridin'")
# ('dry', 'until')
# ('thinking', 'that')
# ('you', 'tell')
# ('<START>', 'Buddah')
# ('can', 'turn')
# ('we', 'broke')
# ('At', 'my')
# ('low', 'and')
# ('a', 'great')
# ('Heard', 'it')
# ('Turn', 'the')
# ('out', 'nigga')
# ('said', '"Damn')
# ('the', 'mac')
# ('put', 'in')
# ('trips', 'in')
# ('mama', 'told')
# ('get', 'at')
# ('Headed', 'to')
# ('Never', 'switch,')
# ('that', 'gangsta')
# ('drive', 'for')
# ('kill', '(pew')
# ('she', "can't")
# ("Ridin'", 'in')
# ("don't", 'stand')
# ('money,', "don't")
# ('<N>', 'Smoking')
# ('Touchdown,', 'going')
# ('back', 'and')
# ('stuffed', 'full')
# ('we', 'extra')
# ('the', 'crib')
# ('They', 'finally')
# ('gon', 'big')
# ('your', 'Cuban')
# ('Lamborghini,', "that's")
# ('me', 'back')
# ('Pistol', 'in')
# ("didn't", 'recognized')
# ('<N>', 'Hoes')
# ('gas', 'on')
# ('play', 'me')
# ('<START>', 'Respect')
# ('out,', 'clear')
# ('a', 'Audi')
# ("drippin'", 'like')
# ('Double', 'cup')
# ('Piped', 'up')
# ('ceiling', 'light')
# ('sacrifice', '(all')
# ('myself', 'and')
# ('him', 'with')
# ('hundred', 'nigga')
# ('hate', 'the')
# ('and', 'baby')
# ('got', 'to')
# ('them', 'pints')
# ('(Splash,', 'drip,')
# ('when', "I'm")
# ('better', 'sewed')
# ('<N>', 'Make')
# ('a', 'dad')
# ('mansion', 'on')
# ('a', 'knot')
# ('be', 'exact')
# ('sells', 'a')
# ('fuck', '12')
# ('taking', 'trips')
# ('opened', 'up')
# ('hundred', 'thousand,')
# ('the', 'box')
# ('the', 'Lamborghini')
# ('a', 'bitch')
# ('Choppa', 'sound')
# ('sip', 'Actavis')
# ('choppers', 'but')
# ('only', 'one')
# ('do', 'nothing')
# ('heard,', 'you')
# ('thought', 'it')
# ('Get', 'beat,')
# ('meals,', 'Popeyes')
# ('<N>', 'Kicking')
# ('van,', 'they')
# ('modern', 'day')
# ('Me,', 'myself')
# ('will', 'make')
# ("hatin'", 'I')
# ('<START>', 'Aye')
# ('he', 'putting')
# ('girl', '"it\'s')
# ('Never', 'cuff')
# ('roof', 'and')
# ("Geekin'", 'out,')
# ('the', 'pussy')
# ('of', 'trap')
# ('Brrrt', '(skrt')
# ('(Spray', 'the')
# ('Purple', 'Haze')
# ('must', 'be')
# ('<N>', 'R.I.P')
# ('time,', "it's")
# ('nose', 'in')
# ('Rob', 'the')
# ('ton,', 'Purple')
# ('gotta', 'stay')
# ('we', 'won')
# ('Rich', 'nigga')
# ('<N>', "Walkin'")
# ('playing', 'on')
# ('<N>', 'Cut')
# ('<N>', 'Middle')
# ('at', 'how')
# ('when', 'you')
# ('pull', 'me')
# ('in', 'yo')
# ('the', 'bread')
# ('my', 'cars,')
# ('they', "tryna'")
# ('we', 'on')
# ('you', 'coming')
# ('me', 'on')
# ('believe', 'nina')
# ('bitch', "walkin'")
# ('weather,', "I'm")
# ('we', 'handle')
# ('for', 'money')
# ('she', 'still')
# ('culture,', 'stay')
# ('the', 'funeral')
# ('First', 'night,')
# ('pace,', 'I')
# ("can't", 'fuck')
# ('waist', 'pretty')
# ("lil'", 'mama')
# ("Ain't", 'thinking')
# ('stupid', 'boy,')
# ('<N>', "'cause")
# ('the', 'squad,')
# ('He', 'told')
# ('jet,', 'me')
# ('doughnut', 'in')
# ('rule', 'in')
# ('come', 'through')
# ('get', 'it')
# ("gon'", 'eat')
# ('start', 'talking')
# ("ain't", 'yours,')
# ('worldwide', 'we')
# ('a', 'milli,')
# ('<N>', 'Every')
# ('said', '"baby')
# ('been', 'to')
# ('they', "bustin'")
# ('Mr.', 'Offset')
# ('with', 'me,')
# ('Hopping', 'out')
# ('pans,', 'call')
# ('my', 'line')
# ('As', 'I')
# ('Murci̩lago,', 'pull')
# ('the', 'first')
# ('screaming', 'fuck')
# ('<N>', 'Pussy')
# ('wifey', 'and')
# ("ain't", 'going')
# ('Red', 'bottom')
# ("Fuckin'", 'a')
# ('her', 'work')
# ('No', 'more')
# ('for', 'you')
# ('groupie', 'he')
# ('dog', 'from')
# ('and', 'unkindly,')
# ('hollow', 'tips')
# ('light', 'but')
# ('and', 'daughters')
# ('way', 'and')
# ('Damn', 'your')
# ('white', 'blue')
# ('molly', 'like')
# ('bitch', 'that')
# ('a', 'Jag,')
# ('biting', 'the')
# ('copy,', 'name')
# ('around,', 'get')
# ('she', 'work')
# ("can't", 'do')
# ('trash,', 'nigga')
# ("I'm", 'having')
# ('knock', 'the')
# ('I', 'send')
# ('see', 'it')
# ('in', 'first')
# ('player,', 'no')
# ('Real', 'street')
# ('bread', 'up')
# ("Dabbin'", 'on')
# ('later,', 'tell')
# ('want', 'her')
# ("poppin'", 'with')
# ('(two', 'cups,')
# ('<N>', 'And')
# ('up', "missin'")
# ('a', 'low')
# ('six', "o'")
# ('room', 'with')
# ('Nation,', 'Migo')
# ('Chamberlain', 'Julius')
# ('Lambo', 'avatar')
# ('I', 'fucked')
# ('car', "don'")
# ('She', 'see')
# ('business,', 'got')
# ('her', 'trap')
# ('Trapped', 'out')
# ('<N>', '(Cocaina,')
# ('bout', 'running')
# ('all', 'pinocchio,')
# ('water', 'faucet')
# ('til', 'I')
# ('let', 'the')
# ('party', 'for')
# ('the', 'bag')
# ('High', 'speed')
# ('and', 'in')
# ('just', 'wanted')
# ('your', 'way')
# ('said', '"Fuck')
# ('no', 'way')
# ('Gang,', 'we')
# ('cup', 'with')
# ('on', 'him')
# ('go', 'smoke')
# ('keys', 'that')
# ('what', 'the')
# ('make', 'a')
# ('car', 'and')
# ('move', 'down')
# ('we', 'never')
# ('semi', 'talk')
# ('all', 'night')
# ('it,', 'thirty')
# ('like,', 'I')
# ('<N>', 'On')
# ('Now', "who's")
# ('the', 'stop')
# ('put', 'the')
# ('rich', 'with')
# ('one', 'round,')
# ('I', 'fuck')
# ('bitch', 'forreal,')
# ('<N>', "Fuckin'")
# ('Niggas', 'we')
# ('witcha', "(I'ma")
# ('Make', 'a')
# ('daddy,', 'pull')
# ('black', 'spades')
# ('(You', "makin'")
# ('kicking', 'in')
# ('we', 'spreading')
# ('charm', 'and')
# ('Macy', 'Gray')
# ('and', "I've")
# ('them', 'roll')
# ('really', "don't")
# ('no', 'jail')
# ('burn', 'a')
# ('still', 'going')
# ('Bentley', 'like')
# ('police', "givin'")
# ('you', "ain't")
# ('fuck', 'em')
# ('see', 'your')
# ('She', 'eat')
# ('snaggered', 'tooth')
# ('a', 'walk')
# ('just', 'me')
# ('my', 'bitch')
# ('go', 'a')
# ('me', '(it')
# ('was', 'fucking')
# ('(Not', 'my')
# ('bigger', 'than')
# ('to', 'fly,')
# ('<N>', 'Three')
# ('the', 'whole')
# ('I', 'hope')
# ('Ma?"', 'she')
# ('could', 'make')
# ('Let', 'them')
# ('your', 'life')
# ('Smoke', 'one,')
# ('wrist', 'in')
# ("what's", 'in')
# ("ain't", 'the')
# ('school,', 'they')
# ('Cross', 'my')
# ('niggas,', 'official,')
# ('start', 'spinning')
# ("that's", 'where')
# ('life', 'lil')
# ("'cause", 'we')
# ('screaming', 'pipe')
# ('to', 'come')
# ('He', 'opened')
# ("I'm", "doin'")
# ('a', 'hockey')
# ('of', 'the')
# ('Flying', 'from')
# ('we', 'hit')
# ('grant', 'your')
# ('the', 'coupe,')
# ('I', 'only')
# ('bachelor', 'pad')
# ('handle', 'business')
# ('my', 'old')
# ('this', 'bitch')
# ("it's", 'time')
# ('a', 'dream')
# ('<N>', "Trappin'")
# ('the', 'pool')
# ('buy', "Ferrari's")
# ('hookah,', 'my')
# ('in', 'trouble,')
# ('<N>', "Servin'")
# ('of', 'white')
# ('nobody', 'said')
# ('told', "'em")
# ('my', 'back')
# ('nigga', 'to')
# ('to', 'your')
# ('thot', 'in')
# ('you', 'suck')
# ('<N>', 'Tipping')
# ('this', 'molly')
# ('cups', 'of')
# ('She', "ain't")
# ('he', 'got')
# ('mystery,', 'Scooby')
# ('we', 'done')
# ('Mirror,', 'when')
# ('the', 'gang')
# ('really', 'real')
# ('bitch', 'one')
# ('did', 'a')
# ('Fuck', 'a')
# ('crossed', 'the')
# ('throttle,', 'she')
# ('of', 'Venezuela')
# ('still', 'saying')
# ('back', 'like')
# ('One', 'rum')
# ("'cause", 'these')
# ('They', "hatin'")
# ('Busta', 'Rhymes')
# ('Never', 'been')
# ('eeny', 'meeny')
# ('bitch', 'unless')
# ('the', 'magazine,')
# ('Nigga', "lyin'")
# ('been', 'hated')
# ('out', 'after')
# ('Mirror', 'mirror,')
# ('and', "wasn't")
# ('talking', 'my')
# ('Just', 'take')
# ('that', 'wise')
# ('Road', 'seen')
# ('aight,', "feelin'")
# ('<N>', "Countin'")
# ('Hop', 'in')
# ('Wonder', 'why')
# ('nigga', 'got')
# ('(Woo', 'woo')
# ("(I'm", 'the')
# ('Staples', 'watching')
# ('get', 'from')
# ('choose', 'me,')
# ('on', 'this')
# ('count', 'it')
# ('then', 'you')
# ('one', 'to')
# ('her', "I'm")
# ('let', 'up')
# ('money', 'nigga')
# ('They', 'come')
# ('the', 'shower')
# ('<N>', 'Throw')
# ('out,', 'she')
# ('twenty', 'five')
# ('I', 'never')
# ('and', 'run')
# ('right', 'now')
# ('move', 'to')
# ('drip,', 'drip,')
# ('to', 'see')
# ('butterly,', 'sting')
# ('Rich', 'niggas')
# ('Givenchy', 'khakis,')
# ('it', 'ten')
# ('night', '(Street')
# ('drop,', "that's")
# ('side,', 'yeah')
# ('in', 'a')
# ('Ride', 'through')
# ('young', 'rich')
# ('See', 'that')
# ('the', 'craps')
# ('the', 'plans?')
# ('pretty', 'face,')
# ('ass', 'aye,')
# ('<N>', 'Bought')
# ('mirror', 'said')
# ('of', 'a')
# ('to', 'act')
# ('Shoutout', 'to')
# ('never', 'had')
# ('Swear', 'to')
# ("I'm", "whippin',")
# ('with', 'choppers')
# ('stay', 'strong,')
# ('<N>', 'Ever')
# ('fight', 'what')
# ('sleep', 'a')
# ('border,', 'nigga,')
# ('dimes,', 'no')
# ('<N>', 'Broke')
# ('cook', 'up')
# ('on', 'television')
# ('a', 'regular')
# ('they', 'come')
# ('cocaina', 'with')
# ('Island', 'fucking')
# ('Fucked', 'the')
# ('<N>', 'Hop')
# ('Turn', 'a')
# ('my', 'grass,')
# ('if', "it's")
# ('<N>', 'No')
# ('Stopped', 'at')
# ('dollar', 'one')
# ('Take', 'her')
# ('truck,', 'yeah')
# ('far', 'shit')
# ('she', 'on')
# ('for', 'pennies')
# ('Dope', 'in')
# ("sippin'", 'oil,')
# ('Bitches', 'cross')
# ('the', 'huncho')
# ('Cocaina,', 'call')
# ('it', '100,')
# ('ride', '(skr')
# ('Got', 'some')
# ('everybody', 'screaming')
# ('her', 'now')
# ('takin', 'all')
# ('the', 'pack')
# ('<N>', '(Grab')
# ('chances,', 'had')
# ('the', 'baddest')
# ('charter', 'jet,')
# ('you', 'niggas')
# ('nigga', 'but')
# ('now', 'that')
# ('Blue', 'and')
# ('sell', 'work')
# ('to', 'go')
# ('stand', 'too')
# ('when', 'momma')
# ('tops', '(drop')
# ('ride', '(skrrt')
# ('back', 'gangsta')
# ('lice,', 'yeah')
# ('<N>', 'Mirror,')
# ('key', 'push')
# ('and', "it's")
# ('Pop', 'a')
# ('Huncho', 'on')
# ('fact', '(they')
# ('do', 'is')
# ('so', 'fake')
# ('100', 'bought')
# ("takin'", 'chances,')
# ('trust', 'you')
# ('<N>', 'Baby')
# ("don't", 'stutter')
# ('bando', 'to')
# ('first', 'album')
# ('the', 'house,')
# ('<N>', 'Tryna')
# ('off', 'one')
# ('one', 'night)')
# ('They', 'copy')
# ('my', 'bitch,')
# ('jeweler', 'out')
# ('forreal,', 'she')
# ('these', 'trophies')
# ('talking', 'about')
# ('go', 'big')
# ('them', 'houses')
# ('just', 'Benjamin')
# ('real,', 'well')
# ('dab', 'daddy,')
# ('let', 'you')
# ('Migo', 'Gang,')
# ('the', 'job')
# ('for', 'that')
# ('can', 'bet')
# ('top', 'me')
# ('the', 'roof')
# ('<N>', 'Lord')
# ('on', 'froze')
# ('on', 'an')
# ('<N>', 'Dead')
# ('bout', 'a')
# ('be', "fuckin'")
# ('ride', 'today?')
# ('niggas', 'with')
# ('check', 'the')
# ('the', 'game')
# ('time', 'I')
# ('cooking', 'make')
# ('main', 'bitch,')
# ('day', 'and')
# ('thot,', 'thot')
# ('Had', 'people')
# ('bird', 'like')
# ('any', 'weather,')
# ("what's", 'the')
# ('do', 'magic,')
# ('8', 'one')
# ('for', 'me')
# ('Fiend', 'money')
# ('Taliban,', 'my')
# ('and', '100')
# ('cap,', 'my')
# ('stomach,', 'no')
# ("I'd", 'like')
# ('yo', 'lip')
# ('(Skrrt', 'skrrt,')
# ('and', 'my')
# ('same', 'color')
# ('<N>', 'Spending')
# ('bitch', 'anal')
# ('And', 'that')
# ('at', 'your')
# ('that', 'dope,')
# ('I', 'dream')
# ('nigga', 'disrespect,')
# ('condo,', 'no')
# ('of', 'hair,')
# ('your', 'face')
# ('by', 'my')
# ('up,', 'graat,')
# ('last', 'wave,')
# ("Kickin'", 'dough')
# ('Cancel', 'all')
# ('and', 'do')
# ('Know', 'you')
# ('nigga', 'crossed')
# ('the', 'pipe,')
# ('me', 'remind')
# ('talk,', 'shit')
# ('on', 'like')
# ('Public', 'Service')
# ('splurge,', "It's")
# ('forty-five', 'on')
# ('the', 'devil')
# ('up,', 'get')
# ('wrapping', "'cause")
# ('biting', 'but')
# ('you', "talkin'")
# ('Call', 'the')
# ('<N>', 'Do')
# ('lil', 'hoe')
# ('shining', 'now')
# ('out,', 'outta')
# ('and', 'fucking')
# ('kitchen', 'whipping,')
# ("couldn't", 'do')
# ('the', 'front')
# ('this', 'what')
# ('Bitch', 'you')
# ('Plan', 'a')
# ('say', 'they')
# ('it', 'through')
# ('avatar', '(Lambo),')
# ('her', 'back,')
# ('dope', 'with')
# ('Act,', 'daily')
# ('<N>', 'my')
# ('flow', 'nigga')
# ("I'm", 'selfish')
# ('like', 'Marshawn')
# ('day,', 'my')
# ('skrr,', 'skrr,')
# ('me', 'stay')
# ("it's", 'just')
# ('back', 'at')
# ("Flippin'", 'it,')
# ('Kill', 'ten,')
# ('bad', 'day')
# ('down', 'club')
# ('Plug', 'called')
# ("you're", 'here')
# ('nigga', 'gotta')
# ('whipping', 'and')
# ('them', 'doors')
# ('her', 'sing,')
# ('<N>', 'what')
# ('<N>', 'Bag,')
# ('turned', "Zaxby's")
# ('like', 'where')
# ('to', 'warm')
# ('you', 'picture')
# ("gon'", 'suck')
# ('he', "swimmin'")
# ('be', 'drinking')
# ('lines', '(pull')
# ('crowd', 'and')
# ('Tape', 'a')
# ('Draco', 'and')
# ('own', 'it')
# ('my', 'own')
# ('Damn', 'I')
# ('out', 'looking')
# ('she', "geekin'")
# ('Yeah,', 'Dat')
# ('gun,', 'come')
# ('and', 'finesse,')
# ('a', 'lot')
# ('a', 'brick')
# ('all', 'in')
# ('my', 'tour')
# ('know', "I'd")
# ('Versace', 'and')
# ('nigga', 'fucking')
# ('keep', "wavin'")
# ('switch', 'it')
# ('knock', 'down')
# ('betting', 'my')
# ('the', 'game,')
# ('sure', 'to')
# ('Do', 'it')
# ('plug', 'was')
# ('make', 'it')
# ('dat', 'way,')
# ("shootin'", 'that')
# ('niggas', 'on')
# ('of', "runnin'")
# ('we', 'land')
# ("Ridin'", 'down')
# ('much', 'information')
# ('<N>', 'My')
# ('they', 'got')
# ('My', 'choice')
# ('picture', 'with')
# ('there', 'with')
# ('<N>', "'Til")
# ('say', '(I')
# ('know', 'where')
# ('the', '38')
# ("I'mma", 'hit')
# ('My', 'diamonds')
# ("Thumbin'", 'through')
# ('want', 'no')
# ('neck', 'a')
# ('club', 'on')
# ('his', 'mansion')
# ('to', 'the')
# ('car', 'garage,')
# ("Dippin',", "dabbin'")
# ('That', 'was')
# ('keep', 'the')
# ('be', 'calling')
# ('Wait,', 'what')
# ('it', 'make')
# ('<N>', 'Salute')
# ('build', 'our')
# ('then', 'gunplay')
# ("somethin'", 'nigga')
# ('a', 'J-Lo,')
# ('stand', 'on')
# ('got', 'Actavis,')
# ('me', 'Bill')
# ('"son,', 'when')
# ('need', 'to')
# ('long', 'way')
# ('about', 'the')
# ("Servin'", 'all')
# ('I', 'watch')
# ("It's", "fallin'")
# ('And', 'you')
# ('that', 'boy')
# ('through', 'it,')
# ('ass', 'niggas')
# ('<N>', 'Rubbing')
# ('Just', 'a')
# ('tell', 'her')
# ('<N>', 'Aw')
# ('the', 'origin')
# ('Drank', 'too')
# ('ran', 'out')
# ('the', 'strip')
# ('a', 'ferris')
# ('the', 'pocket')
# ("ridin'", 'American,')
# ('<N>', 'Recognized')
# ('them', 'bangers,')
# ('You', "goin'")
# ('Heavy', 'choppers')
# ('twist', 'your')
# ('hundred', 'million')
# ('a', "walkin'")
# ('got', 'money')
# ('<N>', 'Shoot')
# ('missed', 'call,')
# ('print', 'my')
# ('<N>', 'Yrn')
# ('a', 'broke')
# ('geek', 'a')
# ('drugs,', 'they')
# ('woo', 'woo,')
# ('champagne', '(Spray')
# ('I', 'change')
# ('stay', 'with')
# ('bitch', 'kinda')
# ('Like', 'top')
# ('store', 'for')
# ('trapping', 'in')
# ('locker,', "Gilbert's")
# ('<N>', 'Jump')
# ('I', 'dine')
# ('go', 'try')
# ('going', 'out')
# ('fast', 'to')
# ('jungle', 'then')
# ('<N>', 'Gas')
# ('a', 'lil')
# ('some', 'boulders')
# ("lil'", 'mama,')
# ('me,', 'but')
# ("I'm", "ridin'")
# ('she', 'see')
# ('crust,', 'my')
# ('niggas', 'gonna')
# ('rich', 'niggas,')
# ('<N>', 'Met')
# ('Short', 'days,')
# ('up', 'Diablo,')
# ('a', 'quarter,')
# ('crazy', 'over')
# ('diamonds', 'hit')
# ('Migos', 'Citgo')
# ('roll', 'a')
# ('white', 'lights')
# ('bag', 'and')
# ('took', 'his')
# ("it's", 'over')
# ("hittin'", 'the')
# ('only', 'a')
# ('<N>', 'Seen')
# ('Sad', 'to')
# ('the', 'Bentley')
# ('time,', "y'all")
# ('Police', 'pull')
# ('<N>', 'Wrapped')
# ('even', 'solve')
# ('killing', 'it,')
# ('doing', 'show')
# ('at', 'my')
# ('(it', "ain't")
# ('snow', 'like')
# ('I', 'geek')
# ('<N>', 'Woke')
# ('nigga', 'flexing')
# ('that', 'paper')
# ('bring', 'you')
# ('pitch', 'it')
# ('condom', "'cause")
# ("Feelin'", 'great,')
# ('to', 'just')
# ('Yeah,', 'boy')
# ('really', "it's")
# ('me,', 'Nickelodeon')
# ('<N>', 'So')
# ('the', 'chains,')
# ('wanna', 'look')
# ("I'm", "talkin',")
# ('nigga', 'be')
# ('I', 'seize')
# ('different,', 'different')
# ('You', "drivin'")
# ('yeah', 'yeah')
# ("I'm", 'getting')
# ('The', 'plug')
# ('problem,', 'know')
# ('need', 'for')
# ('your', 'racks')
# ('racks', '(racks')
# ('time', 'Quavo')
# ('Run', 'in')
# ('<N>', 'Cancel')
# ('big,', 'stop')
# ('Just', 'make')
# ('artist', "can't")
# ('Doo', 'and')
# ('Atlanta', '(north')
# ('even', 'on')
# ('and', 'found')
# ('done', 'walk')
# ('It', 'can')
# ('can', 'never')
# ('buddy,', 'now')
# ('a', 'better')
# ('smokey', 'in')
# ('gotta', 'count')
# ('back', 'the')
# ('picked', 'up')
# ('the', 'dab')
# ('another', 'high')
# ('Moscow', 'with')
# ('at', 'yo')
# ('had,', 'she')
# ('house,', 'where')
# ('shit', 'that')
# ('north', 'Atlanta')
# ('My', 'heart')
# ('them', 'niggas')
# ('<N>', 'Woo')
# ('bite', '(ahh-urr,')
# ("trappin'", 'no')
# ('tape', 'from')
# ('its', 'a')
# ("tryna'", 'get')
# ('up', 'where')
# ('I', 'just')
# ('chances,', 'nigga,')
# ('way', 'to')
# ('fuck', 'with')
# ('on', 'Beverly')
# ('No,', 'no,')
# ('turn', 'to')
# ('my', 'nut')
# ('sealed', 'and')
# ('time', 'to')
# ('In', 'stores')
# ('sell', 'no')
# ('step', 'on')
# ('way', 'for')
# ('how', 'to')
# ('in', 'casinos')
# ('flow', 'everybody')
# ('way,', 'young')
# ('five', 'in')
# ('knew', 'it')
# ('that', 'tongue')
# ('night', '(just')
# ('Seen', 'it')
# ('a', 'cape')
# ('ever', 'doubted')
# ('our', 'temperature')
# ('bill', 'to')
# ("'em", 'now')
# ('She', 'want')
# ('<N>', 'Know')
# ('bad', 'bitches,')
# ('Spending', "M&M;'s")
# ('smoking', 'on')
# ('like', 'you')
# ('<N>', 'How')
# ('big', 'arms')
# ('you', 'in')
# ('nigga', 'in')
# ('play', 'us,')
# ('that', 'back')
# ('Have', 'you')
# ('can', 'pitch')
# ('<N>', 'Instagram')
# ('plans?', "(it's")
# ('fuck', 'and')
# ('She', 'bought')
# ('everything', 'but')
# ('can', 'call')
# ("cappin'", 'all')
# ('that', 'lil')
# ('still', 'be')
# ('fuck', 'under')
# ('double', 'cupping')
# ('jewelry', 'store')
# ('young', 'nigga')
# ('tour', 'bus')
# ('Hold', 'on')
# ('on', 'our')
# ('no', 'waist')
# ('paper', 'like')
# ('the', 'greatest')
# ('been', 'my')
# ('mansion,', "fuckin'")
# ('yours,', 'it')
# ('and', 'driving')
# ("M's", 'in')
# ('Lamborghini,', 'turn')
# ('(water),', 'mocking')
# ("Don't", 'get')
# ('(gonna', 'bite')
# ('way,', 'big')
# ('E', "(let's")
# ('The', 'bitches,')
# ('to', 'sleep')
# ('nats,', 'nigga')
# ('watch', '(ice),')
# ('up', 'Lincoln')
# ('the', 'banana')
# ('<N>', 'Italy,')
# ('Lost', 'Mike')
# ('bottles,', "I'm")
# ('Stayed', 'on')
# ('the', 'side,')
# ('out', 'there')
# ('Migo', 'flow')
# ('is', 'so')
# ('always', 'going')
# ('top', 'of')
# ('day', 'rap')
# ('basic', 'bitch')
# ('Just', 'clear')
# ('Big', 'mansion,')
# ('game,', 'we')
# ('like', 'percussion,')
# ('the', 'ash')
# ('a', 'Perky')
# ('<N>', 'Shopping')
# ('be', 'asking')
# ('a', 'deal,')
# ('When', 'the')
# ('really', 'involved')
# ('talk,', 'bullets')
# ('Niggas', 'cloning')
# ('[Verse', '3')
# ('Had', 'a')
# ('<N>', 'Have')
# ("fuckin'", 'til')
# ('hear', 'me')
# ('to', 'die')
# ('Thirty', 'round')
# ('Bentley', 'truck')
# ('gave', 'me')
# ('they', 'criminals')
# ('For', 'all')
# ('off', 'a')
# ('Nation', "that's")
# ('and', "can't")
# ('Columbia,', 'name')
# ('cocaina', 'make')
# ('chop', 'it')
# ("it's", 'three')
# ('like', "what's")
# ('<N>', 'Chopper')
# ('Call', '911')
# ('<N>', 'Hit')
# ('hit', 'one')
# ('she', 'fucking')
# ('<N>', 'Billboard')
# ('told', 'her')
# ('before', 'they')
# ('kitchen', 'like')
# ('a', 'front')
# ('one', 'cosign')
# ('do', 'it,')
# ('now', 'we')
# ('You', 'wanna')
# ('seal', 'and')
# ('Uncle', 'Bo,')
# ("lookin'", 'like')
# ('not', "gon'")
# ('people', 'see')
# ('the', 'booth,')
# ('wrapped', 'up')
# ('With', 'a')
# ('the', 'show')
# ('you', 'got')
# ('<N>', 'Talking')
# ('Bahamas,', 'shout')
# ("ain't", 'real')
# ('but', 'I')
# ('Got', 'racks')
# ('couch', 'talking')
# ('like', 'Steve')
# ('You', 'niggas')
# ('Her', 'phone')
# ('my', 'Mulsanne')
# ("celebratin'", "smokin'")
# ('to', 'my')
# ('on', 'Perkys')
# ('ass', 'way')
# ('done', 'did')
# ('up,', 'damn,')
# ('They', 'asking')
# ('"Fuck', 'twelve"')
# ('come', 'all')
# ('without', 'the')
# ('water,', 'diamonds,')
# ('way,', 'way')
# ('lotta', 'choppas')
# ('tryna', 'knock')
# ('If', '12')
# ('windows', "can't")
# ('(Money', 'counter')
# ('<N>', 'Samurai')
# ('me', 'wrong,')
# ('Had', 'to')
# ('your', 'house')
# ('<N>', 'Cuffing')
# ('a', 'murderer')
# ('Northside,', 'police')
# ('<N>', 'Rumble')
# ('done', 'took')
# ('<N>', "What's")
# ('swervin', 'in')
# ('think', 'about')
# ('simply,', 'just')
# ('I', 'shoot')
# ('go', 'they')
# ("Takin'", 'back')
# ('on', 'hockey')
# ('macs', 'and')
# ('it', 'back')
# ('Looking', 'at')
# ('with', 'bout')
# ('call', 'it')
# ('(skrr', 'skrr,')
# ('really', 'worth')
# ('is', 'back')
# ('we', 'established')
# ('gotta', 'pipe')
# ('Wraith', 'and')
# ("ain't", 'like')
# ('to', 'wet')
# ('<N>', 'Play')
# ('Now', 'he')
# ('goal', 'you')
# ('Fat', 'cookie')
# ('Niggas', 'be')
# ('starting', 'to')
# ('<N>', 'Pink')
# ('said', 'that')
# ('system', '(fuck')
# ('pay', 'em')
# ('mall', 'and')
# ('neck', 'it')
# ('suck', 'me')
# ('houses', 'in')
# ('to', 'bring')
# ('take', 'that')
# ('my', "lil'")
# ('hundreds,', 'call')
# ('so', 'we')
# ('Hotline', 'Motorola')
# ('bad', 'but')
# ('Forgive', 'me')
# ('chickens,', 'tryna')
# ('record,', 'just')
# ('coupe', 'is')
# ('think', 'he')
# ('conscious', 'telling')
# ('<N>', 'Quavo')
# ('ten,', "that's")
# ('on', "shootin'")
# ('since', 'a')
# ('bags', 'but')
# ('touchdown', 'on')
# ("it's", 'not')
# ...
# ('big', 'bales,')
# ('song', "you're")
# ('her', 'grandmama')
# ('a', 'player')
# ('it', 'Nia')
# ('Hoe', 'game')
# ('your', 'way,')
# ('then,', 'and')
# ('niggas', 'call')
# ('dismiss', 'em')
# ('way,', 'so')
# ('my', 'pocket')
# ('say', 'you')
# ('Twenty-five', 'bitches')
# ('pelicans', 'fly')
# ('she', 'going')
# ('god', 'my')
# ('Niggas', 'is')
# ('bringing', 'the')
# ('the', 'low')
# ('about', 'running')
# ('<N>', 'Listerine,')
# ('shoes', 'lil')
# ('and', 'one')
# ('know', 'Young')
# ('player', 'for')
# ('<N>', 'Juug')
# ('binoculars,', 'we')
# ('down', 'with')
# ('<N>', 'Head')
# ("playin'", 'Madden')
# ('<N>', 'Poured')
# ("Droppin'", 'my')
# ('mean,', 'woo')
# ('<N>', 'Now')
# ('he', 'a')
# ('feeling', 'giving')
# ('Came', 'from')
# ('no', 'superman,')
# ("I'm", "cookin',")
# ('young', 'and')
# ('aye,', 'all')
# ('Out', 'of')
# ('with', 'no')
# ("gon'", 'get')
# ('overseas', 'for')
# ('that', 'bag,')
# ('These', 'bitches')
# ('plug', 'right')
# ('my', 'grand')
# ('you,', 'so')
# ('so', 'many')
# ('Blast', 'off,')
# ('just', 'pulled')
# ('but', 'you')
# ('so', 'they')
# ('riddle', 'for')
# ('me,', 'please')
# ('that', 'bag')
# ('lights', 'on')
# ('She', "didn't")
# ('nine', 'hour')
# ('Ghosts,', 'yeah')
# ('<N>', 'Ice')
# ('Lincoln', 'Continental,')
# ('bags', '(bags)')
# ('pull', 'up,')
# ('Four', 'car')
# ('know', 'that')
# ('on', 'four')
# ('Cancun,', 'spaceship')
# ('bitches', 'suck')
# ('go', 'like')
# ('bath', 'bae')
# ('you', 'rich')
# ('gotta', 'deal')
# ('if', 'a')
# ('hurt', 'my')
# ('<START>', 'Uh')
# ('hard', 'for')
# ('then', 'put')
# ('lurking', 'in')
# ('<N>', 'Snowball,')
# ('remember', 'that)')
# ('ask', 'the')
# ('Young', 'Rich')
# ('can', 'finesse')
# ('really', 'tough')
# ('you', 'heard')
# ('plus', "I'm")
# ('I', 'had,')
# ('Migos,', 'so')
# ('the', 'fish')
# ('niggas', 'copy,')
# ('When', 'these')
# ('Straight', 'out')
# ('Tried', 'to')
# ('We', 'got')
# ('<N>', 'Culture')
# ('After', 'the')
# ('<N>', '(If')
# ('RIP', 'to')
# ('I', 'swore')
# ('<N>', 'Sticks')
# ('Park', 'the')
# ('know', 'it')
# ('pain', 'in')
# ('lil', 'Uzi')
# ("tryin'", 'dry')
# ('choppas', "coolin'")
# ('my', 'uncles')
# ('putting', 'on')
# ('know', 'what')
# ('to', 'lose')
# ('nigga,', 'you')
# ('Rollie', 'not')
# ('God', 'they')
# ('of', 'school,')
# ('Red', 'Bentley,')
# ('care', 'nothing')
# ('at', 'niggas')
# ('of', 'this')
# ('No', 'lemonade')
# ('gotta', 'print')
# ('the', "plug's")
# ("don't", 'be')
# ('eat', 'you')
# ('the', 'rocket')
# ('told', 'me')
# ("OG's", 'who')
# ('I', 'know')
# ('the', 'jewelry')
# ('this', 'pain,')
# ("I'mma", 'spaz')
# ('How', 'you')
# ('a', 'man,')
# ('his', 'bitch,')
# ('happy', 'that')
# ('let', 'him')
# ('nigga', 'you')
# ('mama', 'said')
# ('<N>', 'Rude')
# ('fuck', 'on')
# ('red', 'and')
# ('a', 'Rollie')
# ('<START>', 'Hold')
# ('a', 'foundation')
# ('it', 'up')
# ('Niggas', 'get')
# ('Twenty-five', 'pointers,')
# ('fucked,', 'she')
# ('<N>', 'Narcotics')
# ('no', 'mind')
# ('<N>', 'Took')
# ('not', 'let')
# ('let', 'them')
# ('fur,', "that's")
# ('(bite),', 'abnormal')
# ('baby,', 'how')
# ('he', 'mad')
# ("Feelin'", 'aight,')
# ('they', 'tryna')
# ('collar', 'now')
# ('What', 'a')
# ('try', 'to')
# ('baby', 'you')
# ('<N>', 'Auntie')
# ('you', 'unannounced')
# ('Doo,', 'it')
# ('pull', 'up')
# ('lift', 'up')
# ('call', 'for')
# ('it', 'feel')
# ('percussion,', 'run')
# ('diamonds', 'on')
# ('a', 'rock')
# ('schedule,', 'itinerary')
# ('me', 'have')
# ('Flash,', 'dash')
# ('sad', 'today')
# ('<N>', 'Snakes')
# ('this', 'stage')
# ('My', 'diamond')
# ('back', 'when')
# ('a', 'truckload')
# ('world', 'turn')
# ('me', 'they')
# ('the', 'trigger')
# ('chase', 'going')
# ('preacher', 'preach')
# ('gang', 'we')
# ('them', 'information')
# ('baby', 'girl')
# ('jail', 'and')
# ('whatever', 'goal')
# ('Now', 'I')
# ('You', "trappin'")
# ('ten,', 'rubber')
# ('spend', 'it')
# ('way', 'around')
# ('I', 'pull')
# ('strip', 'club,')
# ('the', 'David')
# ('my', 'dinner')
# ('hundred', 'thousand')
# ('<N>', "Rammin'")
# ('that', 'she')
# ('house', 'and')
# ('<N>', 'Tommy')
# ('<N>', "Divin'")
# ('of', "niggas'")
# ('been', 'patiently')
# ('move', 'too')
# ('she', "don't")
# ('you', "havin'")
# ('like', 'what')
# ('to', 'front,')
# ('not', 'welcome')
# ('what', 'sells')
# ('then', 'dismiss')
# ('<N>', 'They')
# ('bitches', "walkin'")
# ('a', 'fat')
# ('<N>', 'Been')
# ('a', 'drag')
# ('the', 'phone')
# ('the', 'bitch')
# ('you', 'the')
# ('911', 'like')
# ('off', 'for')
# ('Imma', 'let')
# ('the', 'Lear')
# ('through', 'all')
# ('the', 'trunk,')
# ('the', 'cops')
# ('know', 'they')
# ('<START>', 'Purps')
# ('grand', 'momma')
# ('Then', 'why')
# ('to', 'drain')
# ('and', 'trade')
# ('Sip', 'slow')
# ('bout', 'to')
# ('rep', 'the')
# ('I', 'look')
# ('that', "I'm")
# ('ass', 'go')
# ('high', 'with')
# ('he', 'like')
# ('anthrax,', 'hit')
# ("Talkin'", 'country')
# ('bus', 'bitch,')
# ('my', 'life')
# ('nigga', 'put')
# ('you', 'tomorrow')
# ('this', 'year')
# ('<N>', 'Spent')
# ('a', 'ton,')
# ('Tired', 'of')
# ('the', 'cam')
# ('jet', 'taking')
# ('keep', 'it')
# ('a', 'player,')
# ("Lil'", 'mama')
# ('me', 'brain')
# ('my', 'nigga,')
# ('hey,', 'tater')
# ('pussy', 'out')
# ('and', "y'all")
# ('see', 'whatchu')
# ('dope', 'right')
# ('up,', 'blew')
# ('fly,', 'one')
# ('you', 'going')
# ('head', 'off')
# ('get', 'caught')
# ('<N>', 'Wipe')
# ('I', 'need')
# ('We', 'put')
# ('Tha', 'Album')
# ('Your', 'ho')
# ('feeling', 'that')
# ('the', 'pole')
# ('her', 'pipe')
# ('god', 'for')
# ('accuracy,', 'now')
# ('the', 'squad')
# ('yeah', 'I')
# ('me', 'tell')
# ('would', 'fall')
# ('(hockey),', 'wrist')
# ('my', 'Bentley')
# ('Jump', 'off')
# ("watchin',", 'so')
# ("I'm", 'recognized')
# ('hit', 'her')
# ('want', 'young')
# ('<N>', 'Hocus')
# ('<N>', 'Smashing')
# ('about,', 'we')
# ("Runnin'", 'from')
# ('<N>', 'Gotta')
# ('better', 'than')
# ('drive,', 'I')
# ('English', 'baby,')
# ('fuckboys', "ain't")
# ('to', 'flip')
# ('Work', 'come')
# ("trappin'", 'out')
# ('the', 'dice')
# ('up,', 'I')
# ('on', "'em")
# ('or', 'fifties,')
# ('Jack', 'Frost,')
# ('(ice),', "ridin'")
# ('my', 'nigga')
# ('a', 'plate')
# ('than', 'the')
# ('too', 'close,')
# ('there', 'right')
# ('with', 'Louboutin')
# ('nigga', "poppin'")
# ('all', 'ways')
# ('Who', 'really')
# ('Brown', 'paper')
# ('to', 'ask')
# ('in', 'empty')
# ('Nobody', 'thought')
# ('them', 'bitches')
# ('that', "flexin',")
# ('thot', 'coochie')
# ('bad', 'and')
# ('really', 'know')
# ('forreal,', 'no')
# ("Don't", 'worry')
# ("trappin',", "I'd")
# ('the', 'VIP')
# ('Now', 'remember,')
# ('12', "can't")
# ("walkin'", 'around')
# ('dropping', 'off')
# ('(brrt),', 'AK')
# ('the', 'store')
# ('<N>', 'Brrrt')
# ('out', 'when')
# ('stupid', 'up')
# ('the', 'right')
# ('<N>', 'M&M;')
# ('show', "I'm")
# ('<N>', 'Ferragamo,')
# ('know', 'how')
# ('ash', 'tray')
# ('them', 'bottles,')
# ('<N>', 'Tunnel')
# ('my', 'money')
# ('pipe', 'it')
# ('Erving', 'money')
# ('Four', "o'")
# ('a', 'dub')
# ('dub', 'and')
# ('Bow', 'one')
# ('(bitch!),', "'sace")
# ('having', 'gas')
# ('50', 'in')
# ("don't", 'like')
# ('seen', 'money')
# ('<N>', 'Neck')
# ('Hold', 'me')
# ('at', 'him')
# ('Now', 'these')
# ('you', 'on')
# ('double', 'XL')
# ('He', 'probably')
# ('Jesus', 'piece,')
# ('leaves', 'bitches')
# ('could', 'never')
# ('saying', "I'm")
# ('<N>', 'What')
# ('<N>', 'Shut')
# ('<N>', 'Quarter')
# ('Versace,', 'we')
# ('up', 'in')
# ('in', 'Ghosts,')
# ('No', 'key')
# ('and', 'nawl,')
# ('know', 'why')
# ('With', 'cocaina')
# ('(aye)', 'not')
# ('rocket', 'and')
# ('this', 'money')
# ('<N>', 'Think')
# ('Fishscale', 'jumping')
# ('started', "trippin'")
# ('let', 'her')
# ('like', 'Kelly')
# ("Lookin'", 'at')
# ('Samsung,', 'get')
# ('you', "don't")
# ('out', 'V12,')
# ('Hey,', 'hey,')
# ('the', 'bachelor')
# ('Wait', 'hold')
# ('this', 'fame')
# ('titties', 'pop')
# ('whip', 'and')
# ('the', 'usual')
# ('through', 'swervin')
# ('from', 'menace')
# ('giving', 'money')
# ('Pull', 'up')
# ('had', 'my')
# ('Trapping', 'out')
# ('she', "blowin'")
# ('type', 'of')
# ('She', 'wanna')
# ('space,', 'KiD')
# ('fifties,', 'just')
# ('out', 'on')
# ('faucet', '(water),')
# ('know', 'daddy')
# ('club', 'up')
# ('bow', 'crumpet')
# ('brick', 'then')
# ("sayin'", "I'm")
# ('no', 'cosigns')
# ('bitch', 'bad,')
# ('feel', 'good')
# ('Niggas,', 'they')
# ('chamber,', "ain't")
# ('bitches,', 'eeny')
# ('she', "callin'")
# ('thank', 'you,')
# ('said', 'we')
# ('she', 'cook')
# ('Poured', 'a')
# ('hundred', 'lines')
# ('Fucking', 'on')
# ('then', 'my')
# ('want', 'a')
# ('pool', 'I')
# ("gon'", 'clone')
# ('hundred,', 'Philippe')
# ('up,', 'wrap')
# ('go', 'out')
# ('coming', 'soon')
# ('(well', 'damn)')
# ('juuged', 'him')
# ('the', 'ocean,')
# ("I'm", 'smoking')
# ('song', 'Hit')
# ("can't", 'find')
# ('off', 'tried')
# ('That', 'bullshit')
# ('street,', 'I')
# ('English,', 'she')
# ('Magic', 'with')
# ('nutty', 'buddy,')
# ('Watt', 'is')
# ('trouble', '(think')
# ('she', 'wanna')
# ('to', 'chop')
# ('my', 'front')
# ('Scooby', 'Doo')
# ('white,', 'that')
# ('Tell', 'me')
# ('country,', 'trying')
# ('be', 'like')
# ('furniture', 'same')
# ('going', 'our')
# ('in', 'that')
# ('nowhere', 'without')
# ('these', 'houses')
# ('diamond', 'it')
# ('my', 'property')
# ('spaz', 'bae')
# ('<START>', "We're")
# ('the', 'North,')
# ('I', 'took')
# ("won't", 'hesitate')
# ('act', 'like')
# ('Just', 'like')
# ('Really', 'she')
# ('fucked', 'a')
# ('they', 'envy')
# ('Kept', 'me')
# ('pop', 'it')
# ('oat', 'meals,')
# ('go', 'nowhere')
# ('<N>', 'Check')
# ("'bout", 'to')
# ('you', "wouldn't")
# ('Phil,', 'fresh')
# ('up', 'on')
# ('a', 'Gucci')
# ('niggas', "didn't")
# ('rum', 'and')
# ("snowin'", 'with')
# ('went', 'missing,')
# ('myself', 'Takeoff')
# ('the', 'reason')
# ('<START>', 'If')
# ('cupping', 'muddy')
# ('radar', 'watch')
# ('said', 'it')
# ('his', 'head')
# ('foreign,', 'she')
# ('you', 'soft')
# ('stage', 'nigga')
# ('Slide', 'with')
# ('broke', 'nigga')
# ('an', 'international')
# ('the', 'time,')
# ('just', "can't")
# ('way', 'out')
# ('key', 'to')
# ('long', 'like')
# ('She', 'talk')
# ("wasn't", "goin'")
# ('the', 'preacher')
# ('wrist', 'and')
# ('hate', '(they')
# ('pack', 'and')
# ('<N>', 'Ysl')
# ('get', 'high')
# ('around', 'the')
# ('<N>', 'But')
# ('clear', 'water')
# ('best', 'believe')
# ('Finesse', 'a')
# ('<N>', '(Not')
# ('She', 'fuck')
# ('a', 'feeling,')
# ("M&M;'s", 'in')
# ('way,', 'come')
# ('some', 'fire')
# ("'Cause", 'the')
# ('<N>', 'Courtside')
# ('December', 'issue')
# ('some', 'niggas')
# ("ain't", 'one')
# ("I'm", "throwin'")
# ('turn', 'up')
# ('ask', 'me')
# ('top', 'on')
# ('<N>', 'Treat')
# ('seven', 'in')
# ('it', 'clap,')
# ('trip,', 'just')
# ('pay', 'the')
# ('money,', 'give')
# ('nina', 'on')
# ('Take', 'that')
# ('<N>', 'Migos')
# ('arenas', 'like')
# ('bands', 'in')
# ('dancing', 'they')
# ('Peter', 'Parker')
# ('copied', 'the')
# ('<N>', 'Stacking')
# ('where', 'I')
# ('the', 'Glock')
# ('The', 'rings,')
# ('feed', 'the')
# ('not', 'play')
# ('diamonds', 'and')
# ('lights', 'off')
# ('on', 'going')
# ('<N>', 'Not')
# ('<N>', 'Always')
# ("Trappin'", 'babies')
# ('to', 'start')
# ('We', 'bring')
# ("I'm", 'back')
# ('Talking', 'fast')
# ('thirty', 'round')
# ('the', 'crockpot,')
# ('he', 'meet')
# ('staring', 'at')
# ("I'm", "thinkin'")
# ('the', 'biggest')
# ("don't", 'come')
# ('these', 'bitches,')
# ('look', 'at')
# ('Rackings', 'on')
# ('klondike,', 'ride')
# ("that's", 'on')
# ('recognized', 'you')
# ('Hit', "Em'")
# ('can', 'leave')
# ('left', 'by')
# ('swear', 'these')
# ('fish', 'in')
# ('Big', 'dog,')
# ('nigga', 'never')
# ('Pockets', 'strong,')
# ('Put', 'the')
# ('Go', 'and')
# ('like', 'anacondas')
# ('The', 'chains')
# ('come', 'with')
# ('my', 'clothes')
# ('They', 'rep')
# ("don't", 'have')
# ('Diamonds', 'pull')
# ('got', 'rocks')
# ('grinds,', 'yeah')
# ('some', 'of')
# ('Check', 'my')
# ('eggbeater', 'cook')
# ('empty-handed', 'but')
# ('to', 'roll')
# ('and', 'say')
# ('and', 'molly,')
# ('Walk', 'in')
# ('like', "I'm")
# ('This', 'gold')
# ('<N>', 'Niggas')
# ('they', 'mamma')
# ('of', 'us')
# ('here', 'playing')
# ('we', "ain't")
# ('dyke', 'ho')
# ('a', 'percocet,')
# ('woah,', 'woah,')
# ('<N>', 'VH1')
# ('mollies,', 'Xannies,')
# ('bitch', 'ass')
# ('She', 'knew')
# ("plottin',", 'they')
# ('put', 'me')
# ('album', 'soon')
# ('Plus', 'another')
# ('<N>', 'That')
# ('fuck', 'your')
# ('cars,', 'jewelry,')
# ('No', 'they')
# ('thought', 'that')
# ('<N>', 'Gang')
# ('sure', "ain't")
# ('clip,', 'she')
# ('cocaina', 'you')
# ('Take', 'your')
# ('you', 'did,')
# ('my', 'shoes')
# ('<N>', 'Hey,')
# ('kept', 'her')
# ('Wrist', 'watch')
# ("don't", 'vote')
# ('said', 'pipe')
# ('main', 'bitch')
# ('the', 'dracos')
# ('Venezuela', 'talking')
# ('So', 'the')
# ('all', 'time')
# ('up', 'like')
# ("don't", 'got')
# ('I', 'better')
# ('Three', 'young')
# ("that's", 'when')
# ('my', 'tapestry,')
# ('and', 'gave')
# ("o'", 'clock')
# ('thing', 'you')
# ('do', "nothin',")
# ('this,', "I'm")
# ('why', 'I')
# ('tips', 'in')
# ('nigga', 'all')
# ('anacondas', '(know')
# ('calling', 'say')
# ('<N>', 'Trap')
# ('I', 'stretch')
# ('no', "I'm")
# ('Money', 'flop,')
# ('<N>', 'Lemme')
# ("'round", 'through')
# ('now', '(rid')
# ('like', 'Sapp')
# ('But', 'get')
# ('I', 'saw')
# ('up', 'that')
# ('you', 'a')
# ('dope', 'still')
# ('brown', 'paper')
# ('like', 'Busta')
# ('but', 'this')
# ('like', 'she')
# ('And', 'I')
# ('man', 'but')
# ('cross', 'the')
# ('whips', 'is')
# ("It's", 'gon')
# ('lost', 'and')
# ('a', 'picture')
# ('heard', 'a')
# ('would', 'love')
# ('No', 'cop')
# ('Yeah,', 'coupe')
# ('(niggas', 'in')
# ('the', 'door,')
# ('Get', 'to')
# ('(pew', 'pew')
# ('mirror', 'on')
# ('Bitches', 'call')
# ('Miami', 'I')
# ('without', 'John')
# ('sure', 'Ma?"')
# ('let', 'that')
# ('once', 'now')
# ('still', 'bubblegum')
# ('make', 'your')
# ('count', 'a')
# ('get', 'them')
# ('what', 'kind')
# ('slide', 'and')
# ('part', 'of')
# ('to', 'drank')
# ('my', 'busy')
# ('panties', 'drop,')
# ('color', 'T-shirt')
# ('doubt', 'about')
# ('it', 'up,')
# ('phones', 'and')
# ('jumped', 'off')
# ('V12,', "pickin'")
# ('cash', 'bags,')
# ('I', 'gotta')
# ('<N>', 'Cocaina')
# ('<N>', 'Huncho,')
# ("Gabbana's,", 'Alexander')
# ('He', 'getting')
# ('it', 'rain')
# ('foul', 'fuck')
# ('worried', "'bout")
# ("there's", 'nothing')
# ('Thinking', 'about')
# ('cocaina', 'get')
# ('gun,', "don't")
# ('Narcotics', 'made')
# ('My', 'rich')
# ('fuck', 'the')
# ('<N>', 'Talk')
# ('up', 'back')
# ('niggas', "ain't")
# ('"pipe', 'it')
# ('grey', 'like')
# ('right', 'up')
# ('with', 'my')
# ('You', 'acting')
# ('turn', "'em")
# ('and', 'spend')
# ('having', 'blue')
# ('chain', 'might')
# ('give', 'a')
# ('diamonds', "ain't")
# ('the', 'style')
# ('Homie', "don't")
# ('(skrt', 'skrt')
# ('work', 'I')
# ('white', 'on')
# ('much', 'money')
# ('and', 'night')
# ('bitches', 'they')
# ('VIP', 'while')
# ('you', "botherin'")
# ("M's", 'on')
# ('And', 'we')
# ('10', 'racks,')
# ('<N>', 'Headed')
# ('choppa', 'sounding')
# ('so', 'mad')
# ('300', 'right')
# ('come', 'in')
# ('Cuffing', 'that')
# ('or', 'my')
# ('she', 'a')
# ('I', 'would')
# ('your', 'girl')
# ('back', 'in')
# ('some', 'bad')
# ('never', 'made')
# ('only', 'sip')
# ('can', 'help')
# ('Need', 'some')
# ('that', 'dope')
# ('four', 'door,')
# ('the', 'bando,')
# ('Metro', "don't")
# ('pulled', 'over')
# ('nigga', 'on')
# ('nigga?,', 'Gotta')
# ('<N>', 'Raindrops,')
# ('want', 'red')
# ('it', "wasn't")
# ('said', 'you')
# ('like', 'a')
# ('We', 'gonna')
# ('em', 'they')
# ('a', 'basic')
# ('soft', 'in')
# ('hard', "it's")
# ('gonna', 'do')
# ('your', 'bitch')
# ("It's", 'some')
# ('a', 'lower')
# ('fat', 'one')
# ('turned', 'it')
# ("I'ma", 'shoot')
# ('find', 'me')
# ('at', 'the')
# ('nigga', "bitin'")
# ('all', 'good')
# ('unless', 'she')
# ('day', "'cause")
# ('cross,', 'lie')
# ('of', 'broccoli')
# ('getting', 'too')
# ('<N>', 'Grandma')
# ('go', "shoppin'")
# ('for', 'a')
# ('the', "'Rari,")
# ('dream', 'in')
# ('babies,', 'Harambe,')
# ('we', 'winning')
# ('Hawaii,', 'Beverly,')
# ('into', 'a')
# ('I', 'own')
# ('pole', '(all')
# ('around', 'it')
# ('smoking', 'up')
# ('Porsche', 'last')
# ('Running', 'with')
# ('fam?,', 'I')
# ('(come', 'for')
# ('down', 'like')
# ('shit,', 'gotta')
# ('garage,', 'two')
# ('and', 'break')
# ('Like', 'a')
# ('nigga', "ballin'")
# ('with', 'shooters')
# ('be', 'sure')
# ('My', 'OG')
# ('Fisher', 'Price,')
# ('he', "havin'")
# ('Purps', 'on')
# ('ball', 'like')
# ('Jag,', "I'm")
# ('bet', 'I')
# ("ridin'", "'round")
# ('Offset', 'he')
# ('Mansion,', 'twenty')
# ('people', '(skrrt')
# ('in', 'cash')
# ('and', 'show')
# ('respected,', 'Migos')
# ("I'm", "poppin'")
# ('got', 'grenades')
# ('split', "em'")
# ('all', 'my')
# ('up', 'dope')
# ('grenades', 'and')
# ('some', 'Visine')
# ('Young', 'niggas')
# ('Wanna', 'know')
# ('<N>', 'Fuckboy')
# ('Count', 'up')
# ('gotta', 'use')
# ('Gangsta,', 'gangsta,')
# ('Bought', 'the')
# ('to', 'shoot')
# ('known', 'to')
# ('a', 'trip,')
# ('to', 'Peru,')
# ('keep', 'her')
# ('chicken,', 'no')
# ('dip', 'in')
# ('that', 'for')
# ('they', 'free')
# ('tell', 'em')
# ('You', 'go')
# ('drink,', 'I')
# ("can't", 'get')
# ('tag', 'will')
# ('plans,', 'you')
# ("gon'", 'start')
# ('sock,', 'and')
# ('you', 'was')
# ('a', '8')
# ('because', 'what')
# ('started', 'last')
# ('with', 'the')
# ('<N>', 'This')
# ('by', 'myself')
# ('The', 'nigga')
# ('Diamonds', 'thrill')
# ('keep', 'some')
# ('off', 'and')
# ("Bettin'", 'poker')
# ('we', 'some')
# ('Newton,', 'then')
# ('rapper', "bitin'")
# ("Sprayin'", 'champagne')
# ("gon'", 'bite')
# ('know', 'we')
# ('remember', 'that')
# ('Leg', 'lock')
# ('sacrifice,', 'I')
# ('the', 'choppa')
# ('kitchen', 'with')
# ('pussy', 'nigga')
# ("trappin'", "gon'")

# %% [markdown]
# Now, let's generate new lyrics using the Markov chain you constructed above. To do this, we'll begin at the `(None, "<START>")` state and randomly sample a word from the list of first words. Then, we'll randomly sample each next word from the list of words that appeared after the current word in the training data. We will continue this until we reach the `"<END>"` state. This will give us the complete lyrics of a randomly generated song!

# %%
import random

def generate_new_lyrics(chain):
    """
    Args:
      - chain: a dict representing the Markov chain,
               such as one generated by generate_new_lyrics()
    
    Returns:
      A string representing the randomly generated song.
    """
    
    # a list for storing the generated words
    words = []
    # generate the first word
    words.append(random.choice(chain[(None, "<START>")]))
    
    # YOUR CODE HERE
    words.append(random.choice(chain[("<START>"), words[-1]]))
    while words[-1] != "<END>":
        if words[-1] == "<N>":
            words.append(random.choice(chain[(words[-3]), words[-2]]))
        else:
            words.append(random.choice(chain[(words[-2], words[-1])]))
    
    # join the words together into a string with line breaks
    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

# %%
print(generate_new_lyrics(chain))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-174-bb1f4d36bfad> in <module>()
# ----> 1 print(generate_new_lyrics(chain))
#
# <ipython-input-173-2b7f2609bdb9> in generate_new_lyrics(chain)
#      22             words.append(random.choice(chain[(words[-3]), words[-2]]))
#      23         else:
# ---> 24             words.append(random.choice(chain[(words[-2], words[-1])]))
#      25
#      26     # join the words together into a string with line breaks
#
# KeyError: ('<N>', 'Nation')

# %% [markdown]
# ### Grader's Comments
#
# -
# -
#
# [This question is worth 20 points.]

# %%
# This cell should only be modified only by a grader.
scores = [None]
