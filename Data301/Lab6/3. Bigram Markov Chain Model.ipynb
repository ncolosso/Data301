# %% [markdown]
# # Bigram Markov Chain Model
#
# Now you'll build a more complex Markov chain that uses the last _two_ words (or bigram) to predict the next word. Now your dict `chain` should map a _tuple_ of words to a list of words that appear after it. So for example, one entry of this dict might be
#
# ```
# chain = {
#     ("it", "is"): ["the", "the", "not", "a", "a", "not", "the"],
#     ...
# }
# ```
#
# As before, you should also include tags that indicate the beginning and end of a song, as well as line breaks. That is, a tuple might contain tags like `"<START>"`, `"<END>"`, and `"<N>"`, in addition to regular words. So if the song starts with the line "Is this the real life?" and ends with the line "Nothing really matters to me.", you would have a dictionary that looks like
# ```
# chain = {
#     (None, "<START>"): ["Is", ...],
#     ("<START>", "Is"): ["this", ...],
#     ("Is", "this"): ["the", ...],
#     ("this", "the"): ["real", ...],
#     ("the", "real"): ["life?", ...],
#     ("real", "life?"): ["<N>", ...],
#     ("<N>", "Nothing"): ["really", ...],
#     ("Nothing", "really"): ["matters", ...],
#     ("really", "matters"): ["to", ...],
#     ("matters", "to"): ["me.", ...],
#     ("to", "me."): ["<END>", ...],
#     ...
# }
# ```

# %%
def train_markov_chain(lyrics):
    """
    Args:
      - lyrics: a list of strings, where each string represents
                the lyrics of one song by an artist.
    
    Returns:
      A dict that maps a tuple of 2 words ("bigram") to a list of
      words that follow that bigram, representing the Markov
      chain trained on the lyrics.
    """
    chain = {(None, "<START>"): []}
    for song in lyrics: ## song is a list of lines = one song's lyrics
        l_count = 0
        end_count = len(song)-1
        for line in song:
            words = line.split()
            #print(len(words))
            for idx,word in enumerate(words):
                if len(words) == 1:
                    continue
                if idx == 0: # First word:
                    if l_count == 0: ## -of the song
                        chain[(None, "<START>")].append(word)
                        if ("<START>", word) in chain:
                            chain[("<START>", word)].append(words[1])
                        else:
                            chain[("<START>", word)] = [words[1]]
                    elif l_count > 0: ## -of line
                        if ("<N>", word) in chain:
                            chain[("<N>", word)].append(words[1])
                        elif ("<N>", word) not in chain:
                            chain[("<N>", word)] = [words[1]]
                        if last_word in chain:
                            chain[last_word].append(word)
                        elif last_word not in chain:
                            chain[last_word] = [word]
                if idx == len(words)-1: # Last word
                    if l_count == end_count: # -of the song
                        if (words[-2], words[-1]) in chain:
                            chain[(words[-2], words[-1])].append("<END>")
                        else:
                            chain[(words[-2], words[-1])] = ["<END>"]
                    else: # -of the line
                        if (words[-2], words[-1]) in chain:
                            chain[(words[-2], words[-1])].append("<N>")
                        else:
                            chain[(words[-2], words[-1])] = ["<N>"]
                else: # All other words
                    if (words[idx-1], word) in chain:
                        chain[(words[idx-1], word)].append(words[idx+1])
                    else:
                        chain[(words[idx-1], word)] = [words[idx+1]]
                    
                    
            if len(words) > 1:
                last_word = (words[-1], "<N>")   
            l_count+=1

    return chain

# %%
# Load the pickled lyrics object that you created in Part 1.
import pickle
lyrics = pickle.load(open("lyrics.pkl", "rb"))

# Call the function you wrote above.
chain = train_markov_chain(lyrics)

# What words tend to start a song (i.e., what words follow the <START> tag?)
print(chain[(None, "<START>")][:20])
# Out:
# ['Hold', '[Intro:', 'Buddah', '[Intro:', 'Respect', '[Hook', 'Cocaina,', 'Bentley', 'If', 'I', 'You', 'They', 'Purps', 'Hold', 'Mama', 'Pop', 'Tell', 'Buddah', 'They', 'Mama']

# %% [markdown]
# Now, let's generate new lyrics using the Markov chain you constructed above. To do this, we'll begin at the `(None, "<START>")` state and randomly sample a word from the list of first words. Then, we'll randomly sample each next word from the list of words that appeared after the current word in the training data. We will continue this until we reach the `"<END>"` state. This will give us the complete lyrics of a randomly generated song!

# %%
import random

def generate_new_lyrics(chain):
    """
    Args:
      - chain: a dict representing the Markov chain,
               such as one generated by generate_new_lyrics()
    
    Returns:
      A string representing the randomly generated song.
    """
    
    # a list for storing the generated words
    words = []
    # generate the first word
    words.append(random.choice(chain[(None, "<START>")]))
    
    # YOUR CODE HERE
    words.append(random.choice(chain[("<START>"), words[-1]]))
    while words[-1] != "<END>":
        words.append(random.choice(chain[(words[-2], words[-1])]))
    
    # join the words together into a string with line breaks
    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

# %%
print(generate_new_lyrics(chain))
# Out:
# Hold up, get right witcha)
#  Hold on
#  Now you see me have a drag race (skrt)
#  I'm a dog, woof (grrr)
#  Beat the pot, oh
#  Bad bitches walkin' out with bags at the store (bad)
#  Cookin' up dope with a hundred (thumb)
#  Thumbin' through a hundred thousand start snowin' with it (hundred)
#  Go grab the Margielas, right there with the white like mayonnaise
#  Pull up in a brown paper bag (ah)
#  That bullshit and cap you can leave it out (cap)
#  I just can't understand her
#  She gon' eat this molly like it's rice (eat it up)
#  Bitches call me Quavo Ratatouille
#  Run with that fire, aim at his eye
#  Bentley truck like a Chef
#  Count up the kitchen with a Uzi (dope)
#  My bitch is a five, my bitch (aye)
#  Take me a missile (aye)
#  Take out the bed
#  Uh oh, count up the door was a part of the plan, get millions is working
#  Brown paper bag (ah)
#  With them snipers, no binoculars, we looking for you in trouble (think about it)
#  Two cups of purple just to start up (pop it, pop it pop it)
#  I heard your bitch she think that she gon' play a player, no (no)
#  Throw the money twice (clean it up)
#  Break the bread up with the nonsense (uh-uh)
#  How you gon big on big)
#  (Can't go big on big?
#  If you let me in and I paid the price
#  Tell me the dab daddy
#  I'm on a plate at Kelz
#  (Can't go big on big?
#  If you don't need it (brrt)
#  Get right witcha (I'ma get right witcha
#  In the kitchen with the axe (hey)
#  Flexing on purpose, flexing on purpose
#  These Balmains no Calvin Kleins
#  Flood my neck looks just golden
#  Hocus pocus you niggas laughed at me
#  Short days, long nights, trapping at the IA like why I can't get involved, nah nah
#  She gon' eat this molly like it's rice, yeah
#  Climb on a mile a minute
#  I gave her her first (smash)
#  Hoe game itchin' (itch)
#  Fuckin' with the wrong time
#  I take your bitch on Henny, or Henny and coca (coca)
#  You know I keep the rocket (glaw)
#  Neck water faucet (water), mocking birds mocking (woo)
#  Plug called (called), tried to send the thot
#  That's 'cause the Migos
#  You niggas in trouble (niggas in trouble)
#  You niggas got the Sig
#  How you gon' drive
#  If you don't know nothing
#  She ain't got nothing but love
#  Yeah, trap shit
#  All ass aye
#  All white bricks, plain Jane
#  Pure cocaina cane, cocaina cane
#  Have you ever seen a drought? (Hell nah)
#  Have you ever seen a pot before?
#  Fishscale jumping out
#  Won't open the door, tryna leave me out (open)
#  I'ma let that lean flow through my ice
#  Said she never had a gangsta shootout
#  Dope in my dope
#  Is back
#  Is back, is back
#  Gangsta rap is back
#  Is Mr. Offset at home?
#  Momma told the school it caught me five
#  One to fly, one to slide
#  One off in the Double R, I scare ya bitch, Freddy Krueger
#  Freddy Vermeulen
#  Broke a brick down, nutty buddy, now that nigga put on a bitch (money)
#  Go to the south
#  Niggas cloning me but I did last night, 'cause I know we winnin' (winnin')
#  Yeah, I got to flip the money twice (clean it up)
#  Street nigga sacrifice (sacrifice)
#  Street nigga sacrifice
#  Takin' back the streets
#  Fuckboy bow down
#  Started with a Uzi (dope)
#  My lifestyle like a Jag
#  Got me running to the dead niggs'
#  Drums, thirty extensions (30)
#  We got 30's and 100 rounds too (grrah)
#  My momma told me (aye) not to sell work (mama)
#  Seventeen five, same color T-shirt (white)
#  Mama asked me "son, when the young niggas the crown
#  Spray the champagne (Spray the champagne)
#  Spray the champagne
#  Young niggas got the crown (crown)
#  Young niggas from the back, I'm facing a pillar
#  You remember that shit just to start up (pop it, pop it pop it)
#  It's fucked up, niggas in trouble, rock chains by the subway (trappin')
#  Yeah, trap shit
#  You say you gon' one up the deads
#  Uh oh, count up the white, that Ku Klux
#  My bitch is bad and boujee (bad)
#  Cookin' up dope in the coupe and we don't fuck under cover
#  I never work the warehouse
#  I had to get into something
#  Really she don't wanna serve my people
#  Cocaina, cocaina
#  (Cocaina, cocaina)
#  Cocaina, cocaina
#  You never ask me to repay, no
#  You can read between the lines
#  Like top me off tried to kiss me, fuck that, and call Kanye
#  Uh, yeah, Dat Way
#  Your artist be taking my swag
#  I fuck them then move down the line
#  Mama told you
#  You always dropping off your flav
#  You niggas still bubblegum wrapping 'cause you niggas just look at my past
#  Sip slow and live fast (Actavis)
#  I got some boulders (Rocky Balboa)
#  Ice on my level
#  Gotta turn that kitchen to a two seater
#  Work come from Columbia, name it Catalina
#  Might buy a bando then I make you rich with a passion (beat it up)
#  Hold on
#  Now remember, fore we made the song 'Birds', pelicans fly to the M&Ms;
#  If you think about runnin' with that cocaina get time
#  My bitch is bad and boujee (bad)
#  Cookin' up dope in the back (skrt, skrt)
#  Big mansion, no neighbours
#  Bitch you see the far shit and I got more titles than Busta Rhymes
#  That was a mystery, can't even say where
#  But we are against those Migos
#  You can get 'em whichever way
#  Nigga, trap turned Zaxby's (Zax)
#  I walk in the coupe with the right
#  I'ma knock the pussy out like fight night
#  I'ma call on squad like what's the plans? (it's lit!)
#  We got 30's and 100 rounds too (grrah)
#  My neck is glass (glass)
#  Last jeweler just spent sixty cash (cash)
#  Last bitch I had, she bought a salon to clean money
#  We got 30's and 100 rounds too (glah)
#  Holdin' the fire with no guitar
#  Lambo avatar (Lambo), sippin' on some tar (Act)
#  I'm the dab daddy (yo)
#  Hoes calling me the price
#  Tell me what the tag
#  Gas better sewed up, bitch you wanna make a mountain
#  Gotta turn that kitchen to a massacre
#  (Fuck it up, fuck the club up one time (smash)
#  Turn the club light but really it's the red dot
#  Fucked a bitch
#  Young nigga with the left, hit with the wings (brrt)
#  Hundred niggas with the right spot, so she had to go splurge
#  [Hook: Quavo]
#  This the story of a young rich nigga
#  They asking me questions no information
#  No twenties or fifties, just Benjamin Franklins
#  Block on lock call me Simon
#  When you get it make you rich with a Uzi (dope)
#  My bitch is a ten
#  How you gon' big on big?
#  What a feelin', what a feelin'
#  Talk to em' Quavo
#  Stayed on the runway
#  Got home and counted the check (check)
#  I'mma feed my family nigga, ain't no fairy tale
#  They recognize a nigga on my Murci̩lago, pull up with the fur (hey)
#  I dab in the latest fashion (eat it up)
#  Park the Lamb in the club up one time (ooh)
#  Only take one time (smoke one)
#  Fuckboy bow down
#  Started with a Uzi (dope)
#  My Giuessepe steppers same ones in thriller
#  Diamonds build our temperature up, fucking run it to a nine (nine)
#  I put a seven in a Gucci fleece
#  It's forever pussy nigga gotta deal with it (hundred)
#  Go out your way, yeah yeah for real
#  Nigga lyin' sayin' he havin' Act seal
#  How you gon' big on big?
#  If I got M's on my tutor (who)
#  'Cause I'm having gas bag
#  And that cocaina gon' bring you to Yung Rich Nation
#  I be whipping and driving the Lamborghini like it's rice
#  I'ma let that lean flow through my ice
#  Said she never had a dad (never)
#  Remember the time
#  High speed chase, going down 85
#  Young nigga poppin' with a passion (beat it up)
#  A hundred acres on the mansion (mansion)
#  I grant your ho for the right
#  I'ma knock the pussy out like fight night
#  Beat the pot, oh
#  Bad bitch make it twice (M's)
#  Bought that Wraith and had the ceiling light (Wraith)
#  I dab in the latest fashion (eat it up)
#  Street nigga sacrifice
#  And I made it off of trap talk
#  Call up the alpine
#  Rockin' down Boggs Road seen a hundred racks (racks)
#  Know how to use it (yeah)
#  I'm not going back and forth
#  She knew it was bulletproof
#  With cocaina you will make a name
#  Nigga debatin', they hatin', they plottin', they waitin'
#  They know I don't need it (brrt)
#  I paid it
#  Mamacita, bad bitch, and we with it (rich nigga!)
#  Broke a brick (brick)
#  Bumping yo lip you get your clout up
#  She gon' kill (pew pew pew pew pew pew pew pew pew)
#  I fucked the bitch
#  Beat it with the Uzi (rrrah)
#  Rackings on rackings, got backends on backends
#  So many gold chains on my eye
#  Bentley truck, yeah that's dynamite (cookie, woo)
#  Price, going up, prices
#  Hold on
#  Price, going up, I pull up, I pull up and had the pounds (heard)
#  You going out your way to go
#  You ain't never been on that dirty lil Uzi (yeah)
#  Her daddy the plug mail them
#  Which way? dat way, float on the north side
#  High speed chase, going down 85
#  Blue cheese drop a 8 one time, I stretch it to the children
#  So I made this song, nobody said pipe it up, pipe it up
#  I done brought out a Lambo, crossover on a good day
#  Ride through the gate
#  Look, go to heaven, grab my hand
#  (Grab my hand)
#  She bending over, back for me to repay, no
#  Up early in the crowd it's a blood bath
#  Ferragamo, arrested for my dab
#  Say I'm the dab daddy (yo)
#  Hoes calling me the price
#  No forreal, no cap, my money long like anacondas
#  You can read between the lines (coco)
#  J's out there snitchin', yeah
#  Raindrops, drop tops (drop top)
#  Smokin' on cookie in the hotbox (cookie)
#  Fuckin' with the left, hit with the shits (I'm with it)
#  You were probably watching Garfield
#  Tunnel vision, ain't nothing else
#  Kick door, that's on our face
#  I don't deal with it (hundred)
#  Go out your way, yeah yeah
#  She want my formula, can't give away my recipe
#  Italy, Hawaii, Beverly, it don't even matter to me
#  Shit that happen over night (night)
#  We're not against rap
#  We're not against rappers
#  But we are against those Migos
#  You always dropping off your flav
#  You don't wanna serve my people
#  Cocaina, cocaina
#  I get drugs for the ride
#  Ride around, get right, get rich, good night, you know me know this not a Mueller (hey)
#  Hold on
#  Price, going up
#  Fucking on a thot in my cal-de-sac
#  When I go get me wrong, I keep the rocket (glaw)
#  Neck water faucet (water), mocking birds mocking (woo)
#  Act pints in the ground
#  One to fly, one to slide
#  (Skrrt skrrt, skrrt skrrt, going up)
#  A hundred acres on the runway
#  Uh, yeah, dat way, tell 'em, aye
#  Stripper girl shakin', all ass on the runway
#  Uh, yeah, Dat Way
#  Your artists be taking my swag
#  I pull up with the hammer
#  Talkin' country grammar nigga
#  [Verse 3 - Takeoff]
#  Finesse a nigga, put that dope talkin' anthrax, hit a fat one when we extra large
#  Four o' clock (four), five o' clock, six o' clock (four), five o' clock, six o' clock (five)
#  I'm a murderer nigga but I swore a nigga started last (I swear)
#  I recognized then my momma had pain in her ovaries (ahh)
#  I wonder if I could come take some of yours
#  When I'm doing two hundred, that nigga put on a plate at Kelz
#  (Can't go big on big)
#  We bring 'em when we handle business (ya)
#  We goin' full throttle, she swallowed the bottle
#  I'm always hangin' with shooters (brrah)
#  Might be posted somewhere secluded (private)
#  Still sippin' oil, Migos Citgo (drank, gone)
#  Hold up, get right witcha)
#  Hold up, get right witcha (I'ma get right witcha)
#  Get right witcha (I'ma get right witcha)
#  Bad bitches walkin' out with bags at the wrong one, trippin'
#  Thirty hollow tips in extendo (bow, thirty)
#  Shadows keep wavin' by my window (woo, shadows)
#  Thankin' God he saved my life lil nigga
#  This the story of a young rich nigga thats how we live
#  Now I'm having gas bag
#  And I only sip Actavis 'cause we don't fuck under cover
#  I been had sauce (who)
#  'Cause I was raised by my window (woo, shadows)
#  Thankin' God he saved my life from kick doors (god!)
#  Still sippin' oil, Migos Citgo (drank, gone)
#  Hold up, get right witcha (I'ma get right witcha)
#  Bad bitch make it clap, let me know this ain't my feng shui
#  Certified everywhere, ain't gotta print my resume
#  Talking crazy, I pull up on me
#  Honestly (honest), she fuck with the brick, do voodoo (magic)
#  Court side with a pocket full of hair, but the cat well groomed
#  Plan a trip to Peru, charter jet, me and they bustin' for Instagram, get your life together
#  I'm addicted to drank and I finesse his ass after dinner
#  Call 'em Andy Milonakis (yeah)
#  Brrrt (skrt skrt skrt skrt) burrr, pot
#  Niggas tried to front, I don't trust nobody, grip the fire, yeah
#  She try to play us, they play themselves
#  This the story of a young rich niggas, never did a push up
#  I need me a river, give you a tissue (hey)
#  Got lethal narcs, lethal darts
#  My bitch forreal, she honest, won't tell
#  Popeyes, oat meals, Popeyes ain't no Iron man but I always been a gopher, but I love my Glock, I got the crown (crown)
#  Young nigga with the wrong one, trippin'
#  Thirty thousand for a ticket
#  Real got the title
#  So I walked through the hallway
#  Basketball then gunplay (prrr)
#  Young niggas got the squad, Quavo whip it scientific
#  Juggin' iPhones, so we ain't really here to take no pictures (flash)
#  Get beat, cause I'm flexin' 'Rari's (skrt)
#  I really did it
#  Mamacita, bad bitch, and we split em' hit em
#  Whole lotta choppas coolin' with extensions
#  What you talkin' about, we done been did
#  How the fuck up before I beat the pot with a Uzi (blaow)
#  My nigga called me at the store (bad)
#  Stripper girl shakin', all ass aye
#  All I want you baby
#  And I'm a dog from menace (urr)
#  You always going out sad
#  Bad bitches walkin' out with bags at the pop up (ten)
#  Ridin' round, geeked up, damn, think it's Peter Parker here
#  You always going out sad (sad, huh, sad)
#  Can't play a player
#  Playa playa, playa playa (thinkin' she gon)
#  That wasn't part of the drugs in the game, the industry was shook up
#  Hold up, get right witcha (I'ma get right witcha

# %% [markdown]
# ### Grader's Comments
#
# -
# -
#
# [This question is worth 20 points.]

# %%
# This cell should only be modified only by a grader.
scores = [None]
